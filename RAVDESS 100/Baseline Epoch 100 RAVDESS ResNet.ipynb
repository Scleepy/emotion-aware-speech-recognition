# %%
import pandas as pd
import numpy as np
import os
from IPython.display import Audio
import librosa
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU, Bidirectional, Conv1D, MaxPooling1D, Flatten, BatchNormalization, Activation, Masking, Input, InputLayer, Reshape
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.applications import ResNet50V2, ResNet101V2, ResNet152V2, VGG19, EfficientNetV2M, EfficientNetB0, EfficientNetB4
from tensorflow.python.keras import optimizers
from tensorflow.keras.optimizers import SGD

# %%
file_name_dataset = "RAVDESS"
dataset_ravdess_dir = "../Dataset/RAVDESS/"
ravdess_dir_list = os.listdir(dataset_ravdess_dir)

# %%
emotion_dict = {
    "01": "neutral",
    "02": "calm",
    "03": "happy",
    "04": "sad",
    "05": "angry",
    "06": "fearful",
    "07": "disgust",
    "08": "surprised"
}

# %%
emotion_list = []
path_list = []

for dir in ravdess_dir_list:
    for audio_file in os.listdir(dataset_ravdess_dir + dir):
        emotion_segment = audio_file.split("-")[2]

        if emotion_segment in emotion_dict:
            emotion_list.append(emotion_dict[emotion_segment])
        else:
            emotion_list.append("unknown")

        audio_file_path = os.path.join(dataset_ravdess_dir, dir, audio_file)
        path_list.append(audio_file_path)

ravdess_df = pd.DataFrame({'Emotion': emotion_list, 'Path': path_list})
ravdess_df.to_csv("ravdess_df.csv", index = False)
ravdess_df.head()
# Out:
#    Emotion                                               Path
# 0  neutral  ../Dataset/RAVDESS/Actor_01\03-01-01-01-01-01-...
# 1  neutral  ../Dataset/RAVDESS/Actor_01\03-01-01-01-01-02-...
# 2  neutral  ../Dataset/RAVDESS/Actor_01\03-01-01-01-02-01-...
# 3  neutral  ../Dataset/RAVDESS/Actor_01\03-01-01-01-02-02-...
# 4     calm  ../Dataset/RAVDESS/Actor_01\03-01-02-01-01-01-...

# %%
plt.figure(figsize=(12, 8))
plt.title('Count of Emotions')
sns.countplot(x = ravdess_df.Emotion)
plt.ylabel('Count')
plt.xlabel('Emotions')
sns.despine(top = True, right = True, left = False, bottom = False)
plt.show()

# %%
def noise(data):
  noise_amp = 0.04 * np.random.uniform() * np.amax(data)
  data = data + noise_amp * np.random.normal(size = data.shape[0])
  return data

def time_stretch(data, rate = 0.8):
  return librosa.effects.time_stretch(data, rate = rate)

def shift(data, steps_range = (-5, 5)):
  shift_range = int(np.random.uniform(steps_range[0], steps_range[1]) * 1000)
  return np.roll(data, shift_range)

def pitch_shift(data, sampling_rate, n_steps = 0.7):
  return librosa.effects.pitch_shift(data, sr = sampling_rate, n_steps = n_steps)

def random_time_stretch(data, stretch_factor_range = (0.8, 1.25)):
  random_stretch_factor = np.random.uniform(stretch_factor_range[0], stretch_factor_range[1])

  augmented_data = time_stretch(data, random_stretch_factor)

  if len(augmented_data) > len(data):
    augmented_data = augmented_data[:len(data)]
  else:
    padded_augmented_data = np.zeros_like(data)
    padded_augmented_data[:len(augmented_data)] = augmented_data
    augmented_data = padded_augmented_data

  return augmented_data

def random_pitch_shift(data, sampling_rate, steps_range=(-4, 4)):
  n_steps = np.random.randint(steps_range[0], steps_range[1] + 1)  
  return pitch_shift(data, sampling_rate, n_steps)

# %%
def extract_mel(data, sr, n_mels=128, fmax=8000):
    mel_spec = librosa.feature.melspectrogram(y=data, sr=sr, n_mels=n_mels, fmax=fmax)
    return mel_spec;

def extract_log_mel_spec(data, sr, n_mels=128, fmax=8000):
    log_mel_spec = librosa.power_to_db(extract_mel(data, sr, n_mels, fmax))
    return log_mel_spec;

def extract_mfcc(data, sr, n_mfcc=13):
    mfcc = librosa.feature.mfcc(y = data, sr = sr, n_mfcc=n_mfcc)
    return mfcc;

def extract_delta_mfcc(data, sr, n_mfcc=13):
    mfcc = extract_mfcc(data, sr, n_mfcc)
    delta_mfcc = librosa.feature.delta(mfcc)
    return delta_mfcc;

def extract_delta_delta_mfcc(data, sr, n_mfcc=13):
    mfcc = extract_mfcc(data, sr, n_mfcc)
    delta2_mfcc = librosa.feature.delta(mfcc, order=2)
    return delta2_mfcc;

def extract_zcr(data):
    zcr = librosa.feature.zero_crossing_rate(y=data)
    return zcr

def extract_rms(data):
    rms = librosa.feature.rms(y=data)
    return rms

# %%
# feature_extraction_techniques = ["MFCC", "Delta MFCC", "Delta Delta MFCC"]
# feature_extraction_techniques = ["MFCC Mean 40", "Delta MFCC Mean 40", "Delta Delta MFCC Mean 40"]
feature_extraction_techniques = ["MFCC Mean 40"]

file_name_feat_extract = " & ".join(feature_extraction_techniques)

def extract_features(data, sr, n_mfcc=40):
    # MEAN
    features = np.array([])
    mfcc = extract_mfcc(data, sr, n_mfcc).T
    delta_mfcc = extract_delta_mfcc(data, sr, n_mfcc).T
    delta_delta_mfcc = extract_delta_delta_mfcc(data, sr, n_mfcc).T
    mfcc_mean = np.mean(mfcc, axis=0)
    delta_mfcc_mean = np.mean(delta_mfcc, axis=0)
    delta_delta_mfcc_mean = np.mean(delta_delta_mfcc, axis=0)
    # mfcc_min = np.min(mfcc, axis=0)
    # mfcc_max = np.max(mfcc, axis=0)
    # mfcc_std = np.std(mfcc, axis=0)
    # zcr = np.mean(extract_zcr(data))
    # rms = np.mean(extract_rms(data))
    features = np.hstack((features, mfcc_mean))

    # ENTIRE FEATURE
    # mfcc = extract_mfcc(data, sr).T
    # delta_mfcc = extract_delta_mfcc(data, sr).T
    # delta_delta_mfcc = extract_delta_delta_mfcc(data, sr).T
    # features = np.concatenate((mfcc, delta_mfcc, delta_delta_mfcc), axis=1)
    
    return features

# %%
# data_augmentation_techniques = ["Noise", "Random Time Stretch", "Random Pitch Shift"]
# data_augmentation_techniques = ["Noise 0.04", "Low Speed 0.75", "Stretched 0.7", "High Speed 1.25", "Pitch Shift 0.7", "Shift (-5, 5)"]
data_augmentation_techniques = ["Noise 0.04", "Low Speed 0.75", "High Speed 1.25", "Pitch Shift 0.7", "Shift (-5, 5)"]

file_name_data_aug = " & ".join(data_augmentation_techniques)

def get_features(path):
    data, sampling_rate = librosa.load(path, duration=3, offset=0.5)

    noisy_data = noise(data)

    lowspeed_data = time_stretch(data, rate=0.75) #Ignore this
    stretched_data = time_stretch(data, rate=0.7) #Ignore this
    highspeed_data = time_stretch(data, rate=1.25) #Ignore this
    pitch_shift_data = pitch_shift(data, sampling_rate, n_steps=0.7) #Ignore this
    shift_data = shift(data, (-5, 5)) #Ignore this

    random_time_stretch_data = random_time_stretch(data, (0.8, 1.25))
    random_pitch_shift_data = random_pitch_shift(data, sampling_rate, (-4, 4))

    features = extract_features(data, sampling_rate)
    noisy_features = extract_features(noisy_data, sampling_rate)
    
    lowspeed_features = extract_features(lowspeed_data, sampling_rate) #Ignore this
    stretched_features = extract_features(stretched_data, sampling_rate) #Ignore this
    highspeed_features = extract_features(highspeed_data, sampling_rate) #Ignore this
    pitch_shift_features = extract_features(pitch_shift_data, sampling_rate) #Ignore this
    shift_features = extract_features(shift_data, sampling_rate) #Ignore this

    random_time_stretch_features = extract_features(random_time_stretch_data, sampling_rate)
    random_pitch_shift_features = extract_features(random_pitch_shift_data, sampling_rate)

    # result = np.vstack((features, noisy_features, random_time_stretch_features, random_pitch_shift_features))
    result = np.vstack((features, noisy_features, lowspeed_features, highspeed_features, pitch_shift_features, shift_features))

    return result

# %%
filename = file_name_dataset + " # " + file_name_feat_extract + " # " + file_name_data_aug

def create_feature_dataframe(dataframe):
    feature_list = []
    emotion_list = []

    for path, emotion in tqdm(zip(dataframe.Path, dataframe.Emotion), total=len(dataframe)):
        features = get_features(path)
        for elements in features:
            feature_list.append(elements)
            emotion_list.append(emotion)

    df = pd.DataFrame({'Emotion': emotion_list})
    df = pd.concat([df, pd.DataFrame(feature_list)], axis=1)
    df.to_csv(filename + '.csv', index=False)

    return df

# %%
file_exists = os.path.exists(filename + '.csv')

if file_exists:
    df = pd.read_csv(filename + '.csv')
else:
    df = create_feature_dataframe(ravdess_df)

df.head()
# Out:
#    Emotion           0          1         2          3         4         5
# 0  neutral -670.195435  65.063850  0.888954  14.715979  9.182164  0.660575  \
# 1  neutral -414.761523  21.981434  8.014797   7.191777  3.978840 -0.291529
# 2  neutral -691.445679  62.221443 -0.300504  14.352509  8.497726  0.746647
# 3  neutral -712.516907  66.194984  1.424330  16.236750  9.380598  1.506902
# 4  neutral -697.627258  62.472347 -1.029173  15.987646  7.447986 -0.467146
#
#           6         7          8  ...        30        31        32        33
# 0 -3.846836 -3.583946 -12.959006  ... -2.351098 -2.504727 -3.151507 -2.190899  \
# 1 -2.458150 -5.639966  -7.070693  ... -1.300621 -1.436600 -1.493561 -1.958838
# 2 -4.348557 -4.798969 -14.069670  ... -2.381158 -2.261819 -2.873888 -1.883212
# 3 -4.124938 -3.517112 -13.283334  ... -1.922169 -2.280859 -3.436191 -1.829611
# 4 -5.220094 -5.383532 -13.847498  ... -4.750515 -3.052244 -4.137149 -2.542254
#
#          34        35        36        37        38        39
# 0 -3.801760 -1.813088 -1.261222 -2.144954 -4.152173 -1.779615
# 1 -2.061660 -0.920873 -0.248039 -1.327291 -1.568317 -1.893178
# 2 -4.045451 -1.785669 -1.113154 -2.164787 -4.364875 -1.768830
# 3 -4.056078 -1.664588 -0.654646 -1.566690 -4.341530 -1.645019
# 4 -3.379075 -0.843549 -2.677613 -4.869622 -3.312335 -3.609416
#
# [5 rows x 41 columns]

# %%
X = df.iloc[:, 1:].values
Y = df['Emotion'].values

# %%
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
x_train, x_val_test, y_train, y_val_test = train_test_split(X, Y, test_size=0.2, random_state=42, shuffle=True)
x_validation, x_test, y_validation, y_test = train_test_split(x_val_test, y_val_test, test_size=0.5, random_state=42, shuffle=True)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_validation = scaler.transform(x_validation)
x_test = scaler.transform(x_test)

x_train.shape, y_train.shape, x_validation.shape, y_validation.shape, x_test.shape, y_test.shape
# Out:
# ((6912, 40), (6912, 8), (864, 40), (864, 8), (864, 40), (864, 8))

# %%
X_train = x_train.reshape(x_train.shape[0] , x_train.shape[1] , 1)
X_test = x_test.reshape(x_test.shape[0] , x_test.shape[1] , 1)
X_validation = x_validation.reshape(x_validation.shape[0] , x_validation.shape[1] , 1)
X_train.shape, y_train.shape, X_validation.shape, y_validation.shape, X_test.shape, y_test.shape
# Out:
# ((6912, 40, 1), (6912, 8), (864, 40, 1), (864, 8), (864, 40, 1), (864, 8))

# %%
def evaluate_model(model):
    loss, accuracy = model.evaluate(X_test, y_test, verbose=1)

    print(f'Test Loss: {loss}')
    print(f'Test Accuracy: {accuracy}')

# %%
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

# %%
def simplify_label(label):
    if 'angry' in label:
        return 'angry'
    elif 'disgust' in label:
        return 'disgust'
    elif 'fear' in label:
        return 'fear'
    elif 'happy' in label:
        return 'happy'
    elif 'sad' in label:
        return 'sad'
    elif 'surprise' in label:
        return 'surprise'
    elif 'neutral' in label:
        return 'neutral'
    else:
        return label

# %%
def create_model_summary(model_type):
    test_prediction = model_type.predict(X_test)

    prediction_actual_df = pd.DataFrame({
    'Predicted': encoder.inverse_transform(test_prediction).flatten(),
    'Actual': encoder.inverse_transform(y_test).flatten()
    })

    prediction_actual_df.head()

    modified_df = prediction_actual_df.copy()
    modified_df['Actual'] = modified_df['Actual'].apply(simplify_label)
    modified_df['Predicted'] = modified_df['Predicted'].apply(simplify_label)

    res_mat = confusion_matrix(modified_df['Actual'], modified_df['Predicted'])
    plt.figure(figsize=(10, 7))
    sns.heatmap(res_mat, annot=True, fmt='d', cmap='Blues',
                xticklabels=modified_df['Predicted'].unique(), 
                yticklabels=modified_df['Actual'].unique())
    plt.xlabel('Predicted Labels')
    plt.ylabel('Actual Labels')
    plt.title('Confusion Matrix')
    plt.show()

    print(classification_report(modified_df['Actual'], modified_df['Predicted']))

    accuracy = accuracy_score(modified_df['Actual'], modified_df['Predicted'])
    print(f"Accuracy: {round(accuracy * 100, 2)}%")

# %%
resnet50_weights_path = '../ResNet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5'
resnet101_weights_path = '../ResNet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5'
resnet152_weights_path = '../ResNet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5'

# %%
def create_resnet_model(model_type, epochs, filename):
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    input_layer = Input(shape=input_shape)

    model_map = {
        'ResNet50V2': ResNet50V2,
        'ResNet101V2': ResNet101V2,
        'ResNet152V2': ResNet152V2
    }

    if model_type == 'ResNet50V2':
        base_model = ResNet50V2(weights=None, include_top=False, input_tensor=input_layer, pooling='avg')
    elif model_type == 'ResNet101V2':
        base_model = ResNet101V2(weights=None, include_top=False, input_tensor=input_layer, pooling='avg')
    elif model_type == 'ResNet152V2':
        base_model = ResNet152V2(weights=None, include_top=False, input_tensor=input_layer, pooling='avg')

    if model_type not in model_map:
        raise ValueError("Invalid model_type provided. Please choose from ResNet50V2, ResNet101V2 or ResNet152V2")

    base_model = model_map[model_type](weights=None, include_top=False, input_tensor=input_layer, pooling='avg')

    x = base_model.output
    output_layer = Dense(8, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=output_layer)
    model.summary()
    
    sgd = SGD(lr = 0.01, decay = 1e-6, momentum = 0.9, nesterov = True)
    model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
        
    reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=3, min_lr=0.00001)
    checkpoint = ModelCheckpoint(filepath=filename + '_best.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    early_stop = EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True)

    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        validation_data=(X_validation, y_validation),
        callbacks=[reduce_lr, early_stop, checkpoint]
    )
    
    return model, history

# %%
model_types = ['ResNet50V2', 'ResNet101V2', 'ResNet152V2']

for model_type in model_types:
    print(f"Training model: {model_type}")
    model, history = create_resnet_model(model_type, 100, 'RAVDESS 100 ' + model_type)
    evaluate_model(model)
    plot_history(history)
    create_model_summary(model)
# Out:
# Training model: ResNet50V2
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 40, 1, 1)]   0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 46, 7, 1)     0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 20, 1, 64)    3200        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 22, 3, 64)    0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 10, 1, 64)    0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 10, 1, 64)   256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 10, 1, 64)   0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 10, 1, 64)    4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 10, 1, 64)   256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 10, 1, 64)   0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 12, 3, 64)   0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 10, 1, 64)    36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 10, 1, 64)   256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 10, 1, 64)   0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 10, 1, 256)   16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 10, 1, 256)   16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 10, 1, 256)   0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 10, 1, 256)  1024        ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 10, 1, 256)  0           ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 10, 1, 64)    16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 10, 1, 64)   256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 10, 1, 64)   0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 12, 3, 64)   0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 10, 1, 64)    36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 10, 1, 64)   256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 10, 1, 64)   0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 10, 1, 256)   16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 10, 1, 256)   0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 10, 1, 256)  1024        ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 10, 1, 256)  0           ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 10, 1, 64)    16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 10, 1, 64)   256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 10, 1, 64)   0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 12, 3, 64)   0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 5, 1, 64)     36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 5, 1, 64)    256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 5, 1, 64)    0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 5, 1, 256)   0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 5, 1, 256)    16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 5, 1, 256)    0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 5, 1, 256)   1024        ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 5, 1, 256)   0           ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 5, 1, 128)    32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 5, 1, 128)   512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 5, 1, 128)   0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 7, 3, 128)   0           ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 5, 1, 128)    147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 5, 1, 128)   512         ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 5, 1, 128)   0           ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 5, 1, 512)    131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 5, 1, 512)    66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 5, 1, 512)    0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 5, 1, 512)   2048        ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 5, 1, 512)   0           ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 5, 1, 128)    65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 5, 1, 128)   512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 5, 1, 128)   0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 7, 3, 128)   0           ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 5, 1, 128)    147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 5, 1, 128)   512         ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 5, 1, 128)   0           ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 5, 1, 512)    66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 5, 1, 512)    0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 5, 1, 512)   2048        ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 5, 1, 512)   0           ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 5, 1, 128)    65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 5, 1, 128)   512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 5, 1, 128)   0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 7, 3, 128)   0           ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 5, 1, 128)    147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 5, 1, 128)   512         ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 5, 1, 128)   0           ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 5, 1, 512)    66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 5, 1, 512)    0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 5, 1, 512)   2048        ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 5, 1, 512)   0           ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 5, 1, 128)    65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 5, 1, 128)   512         ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 5, 1, 128)   0           ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 7, 3, 128)   0           ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 3, 1, 128)    147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 3, 1, 128)   512         ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 3, 1, 128)   0           ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 3, 1, 512)   0           ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 3, 1, 512)    66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 3, 1, 512)    0           ['max_pooling2d_4[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 3, 1, 512)   2048        ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 3, 1, 512)   0           ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 3, 1, 256)    131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 3, 1, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 3, 1, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 5, 3, 256)   0           ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 3, 1, 256)    589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 3, 1, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 3, 1, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 3, 1, 1024)   525312      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 3, 1, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_out (Add)         (None, 3, 1, 1024)   0           ['conv4_block1_0_conv[0][0]',
#                                                                   'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 3, 1, 1024)  4096        ['conv4_block1_out[0][0]']
#  ormalization)
#
#  conv4_block2_preact_relu (Acti  (None, 3, 1, 1024)  0           ['conv4_block2_preact_bn[0][0]']
#  vation)
#
#  conv4_block2_1_conv (Conv2D)   (None, 3, 1, 256)    262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 3, 1, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 3, 1, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 5, 3, 256)   0           ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 3, 1, 256)    589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 3, 1, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 3, 1, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 3, 1, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_out (Add)         (None, 3, 1, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 3, 1, 1024)  4096        ['conv4_block2_out[0][0]']
#  ormalization)
#
#  conv4_block3_preact_relu (Acti  (None, 3, 1, 1024)  0           ['conv4_block3_preact_bn[0][0]']
#  vation)
#
#  conv4_block3_1_conv (Conv2D)   (None, 3, 1, 256)    262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 3, 1, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 3, 1, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 5, 3, 256)   0           ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 3, 1, 256)    589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 3, 1, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 3, 1, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 3, 1, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_out (Add)         (None, 3, 1, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 3, 1, 1024)  4096        ['conv4_block3_out[0][0]']
#  ormalization)
#
#  conv4_block4_preact_relu (Acti  (None, 3, 1, 1024)  0           ['conv4_block4_preact_bn[0][0]']
#  vation)
#
#  conv4_block4_1_conv (Conv2D)   (None, 3, 1, 256)    262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 3, 1, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 3, 1, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 5, 3, 256)   0           ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 3, 1, 256)    589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 3, 1, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 3, 1, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 3, 1, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_out (Add)         (None, 3, 1, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 3, 1, 1024)  4096        ['conv4_block4_out[0][0]']
#  ormalization)
#
#  conv4_block5_preact_relu (Acti  (None, 3, 1, 1024)  0           ['conv4_block5_preact_bn[0][0]']
#  vation)
#
#  conv4_block5_1_conv (Conv2D)   (None, 3, 1, 256)    262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 3, 1, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 3, 1, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 5, 3, 256)   0           ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 3, 1, 256)    589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 3, 1, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 3, 1, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 3, 1, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_out (Add)         (None, 3, 1, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 3, 1, 1024)  4096        ['conv4_block5_out[0][0]']
#  ormalization)
#
#  conv4_block6_preact_relu (Acti  (None, 3, 1, 1024)  0           ['conv4_block6_preact_bn[0][0]']
#  vation)
#
#  conv4_block6_1_conv (Conv2D)   (None, 3, 1, 256)    262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 3, 1, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 3, 1, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 5, 3, 256)   0           ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 2, 1, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 2, 1, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 2, 1, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 2, 1, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 2, 1, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 2, 1, 1024)   0           ['max_pooling2d_5[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 2, 1, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 2, 1, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 2, 1, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 2, 1, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 2, 1, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 4, 3, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 2, 1, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 2, 1, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 2, 1, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 2, 1, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 2, 1, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 2, 1, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 2, 1, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 2, 1, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 2, 1, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 2, 1, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 2, 1, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 4, 3, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 2, 1, 512)    2359296     ['conv5_block2_2_pad[0][0]']
# ...
#
#  conv5_block3_3_conv (Conv2D)   (None, 2, 1, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 2, 1, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 2, 1, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 2, 1, 2048)   0           ['post_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['post_relu[0][0]']
#  2D)
#
#  dense_2 (Dense)                (None, 8)            16392       ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 58,341,768
# Trainable params: 58,198,024
# Non-trainable params: 143,744
# __________________________________________________________________________________________________
# Epoch 1/100
# c:\Users\Daniel\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 216/216 [==============================] - ETA: 0s - loss: 2.1799 - accuracy: 0.2807
# Epoch 1: val_accuracy improved from -inf to 0.26736, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 73s 285ms/step - loss: 2.1799 - accuracy: 0.2807 - val_loss: 3.9877 - val_accuracy: 0.2674 - lr: 0.0100
# Epoch 2/100
# 216/216 [==============================] - ETA: 0s - loss: 1.7281 - accuracy: 0.3828
# Epoch 2: val_accuracy improved from 0.26736 to 0.43634, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 59s 272ms/step - loss: 1.7281 - accuracy: 0.3828 - val_loss: 1.5882 - val_accuracy: 0.4363 - lr: 0.0100
# Epoch 3/100
# 216/216 [==============================] - ETA: 0s - loss: 1.4639 - accuracy: 0.4672
# Epoch 3: val_accuracy improved from 0.43634 to 0.50231, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 59s 274ms/step - loss: 1.4639 - accuracy: 0.4672 - val_loss: 1.3776 - val_accuracy: 0.5023 - lr: 0.0100
# Epoch 4/100
# 216/216 [==============================] - ETA: 0s - loss: 1.2589 - accuracy: 0.5498
# Epoch 4: val_accuracy improved from 0.50231 to 0.61111, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 59s 274ms/step - loss: 1.2589 - accuracy: 0.5498 - val_loss: 1.0982 - val_accuracy: 0.6111 - lr: 0.0100
# Epoch 5/100
# 216/216 [==============================] - ETA: 0s - loss: 1.0487 - accuracy: 0.6143
# Epoch 5: val_accuracy improved from 0.61111 to 0.61343, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 58s 271ms/step - loss: 1.0487 - accuracy: 0.6143 - val_loss: 1.0462 - val_accuracy: 0.6134 - lr: 0.0100
# Epoch 6/100
# 216/216 [==============================] - ETA: 0s - loss: 0.8616 - accuracy: 0.6905
# Epoch 6: val_accuracy improved from 0.61343 to 0.67014, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 59s 271ms/step - loss: 0.8616 - accuracy: 0.6905 - val_loss: 0.8430 - val_accuracy: 0.6701 - lr: 0.0100
# Epoch 7/100
# 216/216 [==============================] - ETA: 0s - loss: 0.7198 - accuracy: 0.7458
# Epoch 7: val_accuracy improved from 0.67014 to 0.77199, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 59s 275ms/step - loss: 0.7198 - accuracy: 0.7458 - val_loss: 0.6932 - val_accuracy: 0.7720 - lr: 0.0100
# Epoch 8/100
# 216/216 [==============================] - ETA: 0s - loss: 0.6108 - accuracy: 0.7847
# Epoch 8: val_accuracy did not improve from 0.77199
# 216/216 [==============================] - 58s 268ms/step - loss: 0.6108 - accuracy: 0.7847 - val_loss: 0.7127 - val_accuracy: 0.7442 - lr: 0.0100
# Epoch 9/100
# 216/216 [==============================] - ETA: 0s - loss: 0.5273 - accuracy: 0.8080
# Epoch 9: val_accuracy improved from 0.77199 to 0.78356, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 59s 275ms/step - loss: 0.5273 - accuracy: 0.8080 - val_loss: 0.6069 - val_accuracy: 0.7836 - lr: 0.0100
# Epoch 10/100
# 216/216 [==============================] - ETA: 0s - loss: 0.4344 - accuracy: 0.8455
# Epoch 10: val_accuracy improved from 0.78356 to 0.83449, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 59s 273ms/step - loss: 0.4344 - accuracy: 0.8455 - val_loss: 0.4729 - val_accuracy: 0.8345 - lr: 0.0100
# Epoch 11/100
# 216/216 [==============================] - ETA: 0s - loss: 0.3980 - accuracy: 0.8568
# Epoch 11: val_accuracy improved from 0.83449 to 0.83565, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 60s 276ms/step - loss: 0.3980 - accuracy: 0.8568 - val_loss: 0.4515 - val_accuracy: 0.8356 - lr: 0.0100
# Epoch 12/100
# 216/216 [==============================] - ETA: 0s - loss: 0.3383 - accuracy: 0.8840
# Epoch 12: val_accuracy improved from 0.83565 to 0.85417, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 58s 271ms/step - loss: 0.3383 - accuracy: 0.8840 - val_loss: 0.4162 - val_accuracy: 0.8542 - lr: 0.0100
# Epoch 13/100
# 216/216 [==============================] - ETA: 0s - loss: 0.3138 - accuracy: 0.8913
# Epoch 13: val_accuracy did not improve from 0.85417
# 216/216 [==============================] - 57s 264ms/step - loss: 0.3138 - accuracy: 0.8913 - val_loss: 0.4507 - val_accuracy: 0.8507 - lr: 0.0100
# Epoch 14/100
# 216/216 [==============================] - ETA: 0s - loss: 0.3107 - accuracy: 0.8905
# Epoch 14: val_accuracy improved from 0.85417 to 0.86806, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 59s 271ms/step - loss: 0.3107 - accuracy: 0.8905 - val_loss: 0.4070 - val_accuracy: 0.8681 - lr: 0.0100
# Epoch 15/100
# 216/216 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.9009
# Epoch 15: val_accuracy improved from 0.86806 to 0.87616, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 59s 275ms/step - loss: 0.2767 - accuracy: 0.9009 - val_loss: 0.3702 - val_accuracy: 0.8762 - lr: 0.0100
# Epoch 16/100
# 216/216 [==============================] - ETA: 0s - loss: 0.2301 - accuracy: 0.9197
# Epoch 16: val_accuracy did not improve from 0.87616
# 216/216 [==============================] - 57s 266ms/step - loss: 0.2301 - accuracy: 0.9197 - val_loss: 0.4093 - val_accuracy: 0.8704 - lr: 0.0100
# Epoch 17/100
# 216/216 [==============================] - ETA: 0s - loss: 0.2192 - accuracy: 0.9230
# Epoch 17: val_accuracy improved from 0.87616 to 0.88079, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 59s 274ms/step - loss: 0.2192 - accuracy: 0.9230 - val_loss: 0.4589 - val_accuracy: 0.8808 - lr: 0.0100
# Epoch 18/100
# 216/216 [==============================] - ETA: 0s - loss: 0.2123 - accuracy: 0.9245
# Epoch 18: val_accuracy did not improve from 0.88079
# 216/216 [==============================] - 58s 267ms/step - loss: 0.2123 - accuracy: 0.9245 - val_loss: 0.4071 - val_accuracy: 0.8773 - lr: 0.0100
# Epoch 19/100
# 216/216 [==============================] - ETA: 0s - loss: 0.1941 - accuracy: 0.9307
# Epoch 19: val_accuracy did not improve from 0.88079
# 216/216 [==============================] - 57s 266ms/step - loss: 0.1941 - accuracy: 0.9307 - val_loss: 0.4672 - val_accuracy: 0.8727 - lr: 0.0100
# Epoch 20/100
# 216/216 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9324
# Epoch 20: val_accuracy did not improve from 0.88079
# 216/216 [==============================] - 57s 265ms/step - loss: 0.1883 - accuracy: 0.9324 - val_loss: 0.4413 - val_accuracy: 0.8519 - lr: 0.0100
# Epoch 21/100
# 216/216 [==============================] - ETA: 0s - loss: 0.1722 - accuracy: 0.9371
# Epoch 21: val_accuracy did not improve from 0.88079
# 216/216 [==============================] - 57s 264ms/step - loss: 0.1722 - accuracy: 0.9371 - val_loss: 0.5550 - val_accuracy: 0.8796 - lr: 0.0100
# Epoch 22/100
# 216/216 [==============================] - ETA: 0s - loss: 0.1527 - accuracy: 0.9465
# Epoch 22: val_accuracy did not improve from 0.88079
# 216/216 [==============================] - 57s 263ms/step - loss: 0.1527 - accuracy: 0.9465 - val_loss: 0.5897 - val_accuracy: 0.8762 - lr: 0.0100
# Epoch 23/100
# 216/216 [==============================] - ETA: 0s - loss: 0.1767 - accuracy: 0.9392
# Epoch 23: val_accuracy improved from 0.88079 to 0.88542, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 59s 275ms/step - loss: 0.1767 - accuracy: 0.9392 - val_loss: 0.5302 - val_accuracy: 0.8854 - lr: 0.0100
# Epoch 24/100
# 216/216 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9505
# Epoch 24: val_accuracy improved from 0.88542 to 0.90162, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 59s 275ms/step - loss: 0.1406 - accuracy: 0.9505 - val_loss: 0.4394 - val_accuracy: 0.9016 - lr: 0.0100
# Epoch 25/100
# 216/216 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9569
# Epoch 25: val_accuracy did not improve from 0.90162
# 216/216 [==============================] - 58s 266ms/step - loss: 0.1197 - accuracy: 0.9569 - val_loss: 0.3943 - val_accuracy: 0.8877 - lr: 0.0100
# Epoch 26/100
# 216/216 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9553
# Epoch 26: val_accuracy did not improve from 0.90162
# 216/216 [==============================] - 58s 267ms/step - loss: 0.1265 - accuracy: 0.9553 - val_loss: 0.3755 - val_accuracy: 0.8877 - lr: 0.0100
# Epoch 27/100
# 216/216 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9592
# Epoch 27: val_accuracy did not improve from 0.90162
# 216/216 [==============================] - 57s 266ms/step - loss: 0.1172 - accuracy: 0.9592 - val_loss: 0.3911 - val_accuracy: 0.8889 - lr: 0.0100
# Epoch 28/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0950 - accuracy: 0.9663
# Epoch 28: val_accuracy did not improve from 0.90162
# 216/216 [==============================] - 57s 266ms/step - loss: 0.0950 - accuracy: 0.9663 - val_loss: 0.4128 - val_accuracy: 0.8993 - lr: 0.0100
# Epoch 29/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9660
# Epoch 29: val_accuracy did not improve from 0.90162
# 216/216 [==============================] - 44s 204ms/step - loss: 0.0982 - accuracy: 0.9660 - val_loss: 0.6550 - val_accuracy: 0.8935 - lr: 0.0100
# Epoch 30/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9648
# Epoch 30: val_accuracy improved from 0.90162 to 0.90509, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 57s 265ms/step - loss: 0.0989 - accuracy: 0.9648 - val_loss: 0.3375 - val_accuracy: 0.9051 - lr: 0.0100
# Epoch 31/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9692
# Epoch 31: val_accuracy improved from 0.90509 to 0.90856, saving model to RAVDESS 100ResNet152V2_best.h5
# 216/216 [==============================] - 59s 272ms/step - loss: 0.0859 - accuracy: 0.9692 - val_loss: 0.3572 - val_accuracy: 0.9086 - lr: 0.0100
# Epoch 32/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9760
# Epoch 32: val_accuracy did not improve from 0.90856
# 216/216 [==============================] - 57s 264ms/step - loss: 0.0718 - accuracy: 0.9760 - val_loss: 0.5787 - val_accuracy: 0.9016 - lr: 0.0100
# Epoch 33/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9738
# Epoch 33: val_accuracy did not improve from 0.90856
# 216/216 [==============================] - 57s 264ms/step - loss: 0.0758 - accuracy: 0.9738 - val_loss: 0.4064 - val_accuracy: 0.9062 - lr: 0.0100
# Epoch 34/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9810
# Epoch 34: val_accuracy did not improve from 0.90856
# 216/216 [==============================] - 56s 261ms/step - loss: 0.0583 - accuracy: 0.9810 - val_loss: 0.5228 - val_accuracy: 0.9028 - lr: 0.0100
# Epoch 35/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9750
# Epoch 35: val_accuracy did not improve from 0.90856
# 216/216 [==============================] - 57s 265ms/step - loss: 0.0758 - accuracy: 0.9750 - val_loss: 0.4774 - val_accuracy: 0.8900 - lr: 0.0100
# Epoch 36/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.9690
# Epoch 36: val_accuracy did not improve from 0.90856
# 216/216 [==============================] - 57s 263ms/step - loss: 0.0945 - accuracy: 0.9690 - val_loss: 0.4237 - val_accuracy: 0.9039 - lr: 0.0100
# Epoch 37/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9716
# Epoch 37: val_accuracy did not improve from 0.90856
# 216/216 [==============================] - 56s 262ms/step - loss: 0.0817 - accuracy: 0.9716 - val_loss: 0.4685 - val_accuracy: 0.8796 - lr: 0.0100
# Epoch 38/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9883
# Epoch 38: val_accuracy did not improve from 0.90856
# 216/216 [==============================] - 57s 265ms/step - loss: 0.0353 - accuracy: 0.9883 - val_loss: 0.5093 - val_accuracy: 0.9086 - lr: 0.0050
# Epoch 39/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9945
# Epoch 39: val_accuracy did not improve from 0.90856
# 216/216 [==============================] - 56s 261ms/step - loss: 0.0198 - accuracy: 0.9945 - val_loss: 1.1498 - val_accuracy: 0.8924 - lr: 0.0050
# Epoch 40/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9933
# Epoch 40: val_accuracy did not improve from 0.90856
# 216/216 [==============================] - 57s 265ms/step - loss: 0.0223 - accuracy: 0.9933 - val_loss: 0.6975 - val_accuracy: 0.9051 - lr: 0.0050
# Epoch 41/100
# 216/216 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9967
# Epoch 41: val_accuracy did not improve from 0.90856
# 216/216 [==============================] - 58s 267ms/step - loss: 0.0147 - accuracy: 0.9967 - val_loss: 0.8778 - val_accuracy: 0.9062 - lr: 0.0050
# 27/27 [==============================] - 2s 77ms/step - loss: 0.4152 - accuracy: 0.8935
# Test Loss: 0.4151971638202667
# Test Accuracy: 0.8935185074806213
# 27/27 [==============================] - 4s 69ms/step
#               precision    recall  f1-score   support
#
#        angry       0.95      0.88      0.92       118
#         calm       0.97      0.94      0.96       109
#      disgust       0.83      0.96      0.89       116
#         fear       0.88      0.87      0.88       105
#        happy       0.86      0.83      0.85       115
#      neutral       0.71      0.85      0.77        46
#          sad       0.94      0.89      0.91       114
#     surprise       0.91      0.90      0.91       141
#
#     accuracy                           0.89       864
#    macro avg       0.88      0.89      0.89       864
# weighted avg       0.90      0.89      0.89       864
#
# Accuracy: 89.35%
