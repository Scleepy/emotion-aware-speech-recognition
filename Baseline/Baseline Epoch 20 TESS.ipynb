# %%
import pandas as pd
import numpy as np
import os
from IPython.display import Audio
import librosa
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU, Bidirectional, Conv1D, MaxPooling1D, Flatten, BatchNormalization, Activation, Masking
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping

# %%
file_name_dataset = "TESS"
dataset_tess_dir = "../Dataset/TESS/"
tess_dir_list = os.listdir(dataset_tess_dir)

# %%
emotion_list = []
path_list = []

for dir in tess_dir_list:
    for audio_file in os.listdir(dataset_tess_dir + dir):
        emotion_segment = audio_file.split("_")[2].split(".")[0]
        audio_file_path = os.path.join(dataset_tess_dir, dir, audio_file)
        
        if (emotion_segment == "ps"):
            emotion_list.append("surprise")
        else:
            emotion_list.append(emotion_segment)
        
        path_list.append(audio_file_path)

cremad_df = pd.DataFrame({'Emotion': emotion_list, 'Path': path_list})
cremad_df.to_csv("tess_df.csv", index = False)
cremad_df.head()
# Out:
#   Emotion                                          Path
# 0   angry  ../Dataset/TESS/OAF_angry\OAF_back_angry.wav
# 1   angry   ../Dataset/TESS/OAF_angry\OAF_bar_angry.wav
# 2   angry  ../Dataset/TESS/OAF_angry\OAF_base_angry.wav
# 3   angry  ../Dataset/TESS/OAF_angry\OAF_bath_angry.wav
# 4   angry  ../Dataset/TESS/OAF_angry\OAF_bean_angry.wav

# %%
plt.figure(figsize=(12, 8))
plt.title('Count of Emotions')
sns.countplot(x = cremad_df.Emotion, hue = cremad_df.Emotion)
plt.ylabel('Count')
plt.xlabel('Emotions')
sns.despine(top = True, right = True, left = False, bottom = False)
plt.show()

# %%
def waveplot(data, sr, emo):
  plt.figure(figsize = (6, 1))
  plt.title(f"{emo} audio waveplot")
  librosa.display.waveshow(data, sr = sr)

def spectrogram(data, sr, emo):
  X = librosa.stft(data)
  Xdb = librosa.amplitude_to_db(abs(X))
  plt.figure(figsize = (6, 1))
  plt.title(f"{emo} audio spectrogram")
  librosa.display.specshow(Xdb, sr = sr, x_axis = 'time', y_axis = 'hz')

# %%
emotion = 'happy'

audio_file_path = np.array(cremad_df.Path[cremad_df.Emotion.str.contains(emotion)])[1]
data, sampling_rate = librosa.load(audio_file_path)

waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(audio_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def noise(data):
  noise_amp = 0.04 * np.random.uniform() * np.amax(data)
  data = data + noise_amp * np.random.normal(size = data.shape[0])
  return data

def time_stretch(data, rate = 0.8):
  return librosa.effects.time_stretch(data, rate = rate)

def shift(data, steps_range = (-5, 5)):
  shift_range = int(np.random.uniform(steps_range[0], steps_range[1]) * 1000)
  return np.roll(data, shift_range)

def pitch_shift(data, sampling_rate, n_steps = 0.7):
  return librosa.effects.pitch_shift(data, sr = sampling_rate, n_steps = n_steps)

def random_time_stretch(data, stretch_factor_range = (0.8, 1.25)):
  random_stretch_factor = np.random.uniform(stretch_factor_range[0], stretch_factor_range[1])

  augmented_data = time_stretch(data, random_stretch_factor)

  if len(augmented_data) > len(data):
    augmented_data = augmented_data[:len(data)]
  else:
    padded_augmented_data = np.zeros_like(data)
    padded_augmented_data[:len(augmented_data)] = augmented_data
    augmented_data = padded_augmented_data

  return augmented_data

def random_pitch_shift(data, sampling_rate, steps_range=(-4, 4)):
  n_steps = np.random.randint(steps_range[0], steps_range[1] + 1)  
  return pitch_shift(data, sampling_rate, n_steps)

# %%
def extract_mel(data, sr, n_mels=128, fmax=8000):
    mel_spec = librosa.feature.melspectrogram(y=data, sr=sr, n_mels=n_mels, fmax=fmax)
    return mel_spec;

def extract_log_mel_spec(data, sr, n_mels=128, fmax=8000):
    log_mel_spec = librosa.power_to_db(extract_mel(data, sr, n_mels, fmax))
    return log_mel_spec;

def extract_mfcc(data, sr, n_mfcc=13):
    mfcc = librosa.feature.mfcc(y = data, sr = sr, n_mfcc=n_mfcc)
    return mfcc;

def extract_delta_mfcc(data, sr, n_mfcc=13):
    mfcc = extract_mfcc(data, sr, n_mfcc)
    delta_mfcc = librosa.feature.delta(mfcc)
    return delta_mfcc;

def extract_delta_delta_mfcc(data, sr, n_mfcc=13):
    mfcc = extract_mfcc(data, sr, n_mfcc)
    delta2_mfcc = librosa.feature.delta(mfcc, order=2)
    return delta2_mfcc;

def extract_zcr(data):
    zcr = librosa.feature.zero_crossing_rate(y=data)
    return zcr

def extract_rms(data):
    rms = librosa.feature.rms(y=data)
    return rms

# %%
mel = extract_mel(data, sampling_rate, 128, 8000)
plt.figure(figsize=(10, 2))
librosa.display.specshow(mel, x_axis='time', sr = sampling_rate)
plt.ylabel('Mel')
plt.colorbar()

log_mel_spec = extract_log_mel_spec(data, sampling_rate, 128, 8000)
plt.figure(figsize=(10, 2))
librosa.display.specshow(log_mel_spec, x_axis='time', sr = sampling_rate)
plt.ylabel('Log Mel Spectogram')
plt.colorbar()

# MFCC
mfcc = extract_mfcc(data, sampling_rate, 13)
plt.figure(figsize=(10, 2))
librosa.display.specshow(mfcc, x_axis='time', sr = sampling_rate)
plt.ylabel('MFCC')
plt.colorbar()

# ΔMFCC
delta_mfcc = extract_delta_mfcc(data, sampling_rate, 13)
plt.figure(figsize=(10, 2))
librosa.display.specshow(delta_mfcc, x_axis='time', sr = sampling_rate)
plt.ylabel('Delta MFCC')
plt.colorbar()

# ΔΔMFCC
delta_delta_mfcc = extract_delta_delta_mfcc(data, sampling_rate, 13)
plt.figure(figsize=(10, 2))
librosa.display.specshow(delta_delta_mfcc, x_axis='time', sr = sampling_rate)
plt.ylabel('Delta Delta MFCC')
plt.colorbar()
plt.show()

# MFCC-based approximate entropy
# MFCC-based spectral entropy
# Three-dimensional Mel-scale frequency cepstral coefficients

# %%
# feature_extraction_techniques = ["MFCC", "Delta MFCC", "Delta Delta MFCC"]
# feature_extraction_techniques = ["MFCC Mean 40", "Delta MFCC Mean 40", "Delta Delta MFCC Mean 40"]
feature_extraction_techniques = ["MFCC Mean 40"]

file_name_feat_extract = " & ".join(feature_extraction_techniques)

def extract_features(data, sr, n_mfcc=40):
    # MEAN
    features = np.array([])
    mfcc = extract_mfcc(data, sr, n_mfcc).T
    delta_mfcc = extract_delta_mfcc(data, sr, n_mfcc).T
    delta_delta_mfcc = extract_delta_delta_mfcc(data, sr, n_mfcc).T
    mfcc_mean = np.mean(mfcc, axis=0)
    delta_mfcc_mean = np.mean(delta_mfcc, axis=0)
    delta_delta_mfcc_mean = np.mean(delta_delta_mfcc, axis=0)
    # mfcc_min = np.min(mfcc, axis=0)
    # mfcc_max = np.max(mfcc, axis=0)
    # mfcc_std = np.std(mfcc, axis=0)
    # zcr = np.mean(extract_zcr(data))
    # rms = np.mean(extract_rms(data))
    features = np.hstack((features, mfcc_mean))

    # ENTIRE FEATURE
    # mfcc = extract_mfcc(data, sr).T
    # delta_mfcc = extract_delta_mfcc(data, sr).T
    # delta_delta_mfcc = extract_delta_delta_mfcc(data, sr).T
    # features = np.concatenate((mfcc, delta_mfcc, delta_delta_mfcc), axis=1)
    
    return features

# %%
# data_augmentation_techniques = ["Noise", "Random Time Stretch", "Random Pitch Shift"]
# data_augmentation_techniques = ["Noise 0.04", "Low Speed 0.75", "Stretched 0.7", "High Speed 1.25", "Pitch Shift 0.7", "Shift (-5, 5)"]
data_augmentation_techniques = ["Noise 0.04", "Low Speed 0.75", "High Speed 1.25", "Pitch Shift 0.7", "Shift (-5, 5)"]

file_name_data_aug = " & ".join(data_augmentation_techniques)

def get_features(path):
    data, sampling_rate = librosa.load(path, duration=3, offset=0.5)

    noisy_data = noise(data)

    lowspeed_data = time_stretch(data, rate=0.75) #Ignore this
    stretched_data = time_stretch(data, rate=0.7) #Ignore this
    highspeed_data = time_stretch(data, rate=1.25) #Ignore this
    pitch_shift_data = pitch_shift(data, sampling_rate, n_steps=0.7) #Ignore this
    shift_data = shift(data, (-5, 5)) #Ignore this

    random_time_stretch_data = random_time_stretch(data, (0.8, 1.25))
    random_pitch_shift_data = random_pitch_shift(data, sampling_rate, (-4, 4))

    features = extract_features(data, sampling_rate)
    noisy_features = extract_features(noisy_data, sampling_rate)
    
    lowspeed_features = extract_features(lowspeed_data, sampling_rate) #Ignore this
    stretched_features = extract_features(stretched_data, sampling_rate) #Ignore this
    highspeed_features = extract_features(highspeed_data, sampling_rate) #Ignore this
    pitch_shift_features = extract_features(pitch_shift_data, sampling_rate) #Ignore this
    shift_features = extract_features(shift_data, sampling_rate) #Ignore this

    random_time_stretch_features = extract_features(random_time_stretch_data, sampling_rate)
    random_pitch_shift_features = extract_features(random_pitch_shift_data, sampling_rate)

    # result = np.vstack((features, noisy_features, random_time_stretch_features, random_pitch_shift_features))
    result = np.vstack((features, noisy_features, lowspeed_features, highspeed_features, pitch_shift_features, shift_features))

    return result

# %%
filename = file_name_dataset + " # " + file_name_feat_extract + " # " + file_name_data_aug

def create_feature_dataframe(dataframe):
    feature_list = []
    emotion_list = []

    for path, emotion in tqdm(zip(dataframe.Path, dataframe.Emotion), total=len(dataframe)):
        features = get_features(path)
        for elements in features:
            feature_list.append(elements)
            emotion_list.append(emotion)

    df = pd.DataFrame({'Emotion': emotion_list})
    df = pd.concat([df, pd.DataFrame(feature_list)], axis=1)
    df.to_csv(filename + '.csv', index=False)

    return df

# %%
file_exists = os.path.exists(filename + '.csv')

if file_exists:
    df = pd.read_csv(filename + '.csv')
else:
    df = create_feature_dataframe(cremad_df)

df.head()
# Out:
# 100%|██████████| 2800/2800 [09:42<00:00,  4.81it/s]
#   Emotion           0          1          2          3         4          5
# 0   angry -396.986206  77.440536 -19.592791 -21.666689 -2.112756  10.075363  \
# 1   angry -247.071592  33.463982  -7.295828 -16.066172 -3.376882   3.219309
# 2   angry -426.047760  85.507446 -24.529745 -25.422735 -3.307063   9.809677
# 3   angry -399.662506  91.117203 -24.754166 -31.168427 -5.269245   9.252103
# 4   angry -416.410034  76.802986 -27.972919 -27.546099 -0.274697   7.172493
#
#            6         7         8  ...        30         31        32
# 0 -20.366707 -6.092449 -7.212283  ...  0.394722   5.111315  9.568739  \
# 1  -6.410109 -6.072338 -3.855772  ... -1.340019   1.743890  4.093841
# 2 -22.808109 -6.996094 -7.489722  ...  0.609156   5.465265  9.626096
# 3 -25.043127 -9.973287 -9.687059  ... -1.059549   4.778024  9.809315
# 4 -22.715885 -3.497336 -5.517387  ...  2.263394  11.962938  5.335030
#
#          33        34        35         36         37        38        39
# 0  5.454868  2.509964 -1.823907   4.868962   9.313924  2.089150 -1.906491
# 1  1.620116 -2.689258 -2.581905   2.257128   4.926492  2.474761 -3.422867
# 2  5.728091  2.343131 -1.868277   5.339450  11.257667  2.096411 -2.566468
# 3  6.002034  2.350018 -3.155525   4.814306  10.128219  2.874032 -2.716506
# 4  3.204281  0.528458  5.607913  10.100718   2.098508 -6.221065 -1.150442
#
# [5 rows x 41 columns]

# %%
X = df.iloc[:, 1:].values
Y = df['Emotion'].values

# %%
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state = 42, shuffle = True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((13440, 40), (13440, 7), (3360, 40), (3360, 7))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((13440, 40), (13440, 7), (3360, 40), (3360, 7))

# %%
X_train = x_train.reshape(x_train.shape[0] , x_train.shape[1] , 1)
X_test = x_test.reshape(x_test.shape[0] , x_test.shape[1] , 1)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((13440, 40, 1), (13440, 7), (3360, 40, 1), (3360, 7))

# %%
def create_model(model_type, epochs):
    model = Sequential()
    
    if model_type == 'GRU':
        model.add(GRU(128, input_shape=(X_train.shape[1],1), return_sequences=True))
        model.add(Dropout(0.3))
        model.add(GRU(128, return_sequences=True))
        model.add(GRU(128))
    elif model_type == 'LSTM':
        model.add(LSTM(128, input_shape=(X_train.shape[1],1), return_sequences=True))
        model.add(Dropout(0.3))
        model.add(LSTM(128, return_sequences=True))
        model.add(LSTM(128))
    elif model_type == 'BiGRU':
        model.add(Bidirectional(GRU(128, return_sequences=True), input_shape=(X_train.shape[1],1)))
        model.add(Dropout(0.3))
        model.add(Bidirectional(GRU(128, return_sequences=True)))
        model.add(Bidirectional(GRU(128)))
    elif model_type == 'BiLSTM':
        model.add(Bidirectional(LSTM(128, return_sequences=True), input_shape=(X_train.shape[1],1)))
        model.add(Dropout(0.3))
        model.add(Bidirectional(LSTM(128, return_sequences=True)))
        model.add(Bidirectional(LSTM(128)))
    elif model_type == 'CNN':
        model.add(Conv1D(64, 3, activation='relu', input_shape=(X_train.shape[1],1)))
        model.add(MaxPooling1D(2))
        model.add(Conv1D(128, 3, activation='relu'))
        model.add(MaxPooling1D(2))
        model.add(Conv1D(256, 3, activation='relu'))
        model.add(MaxPooling1D(2))
        model.add(Flatten())
        model.add(Dense(128, activation='relu'))
    else:
        raise ValueError("Invalid RNN model. Choose from 'GRU', 'LSTM', 'BiGRU', 'BiLSTM', or 'CNN'.")

    model.add(Dense(y_train.shape[1], activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, verbose=0, patience=3, min_lr=0.00001)
    checkpoint = ModelCheckpoint(model_type + " # " + filename + ' # Epoch 20.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    early_stop = EarlyStopping(monitor='val_accuracy', mode='auto', patience=10, restore_best_weights=True)

    history = model.fit(X_train, y_train, batch_size=64, epochs=epochs, validation_data=(X_test, y_test), callbacks=[reduce_lr, early_stop, checkpoint])

    model.save(model_type + ' # Epoch 20.h5')    
    
    return model, history

# %%
def evaluate_model(model):
    loss, accuracy = model.evaluate(X_test, y_test, verbose=1)

    print(f'Test Loss: {loss}')
    print(f'Test Accuracy: {accuracy}')

# %%
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

# %%
def simplify_label(label):
    if 'angry' in label:
        return 'angry'
    elif 'disgust' in label:
        return 'disgust'
    elif 'fear' in label:
        return 'fear'
    elif 'happy' in label:
        return 'happy'
    elif 'sad' in label:
        return 'sad'
    elif 'surprise' in label:
        return 'surprise'
    elif 'neutral' in label:
        return 'neutral'
    else:
        return label

# %%
def create_model_summary(model_type):
    test_prediction = model_type.predict(X_test)

    prediction_actual_df = pd.DataFrame({
    'Predicted': encoder.inverse_transform(test_prediction).flatten(),
    'Actual': encoder.inverse_transform(y_test).flatten()
    })

    prediction_actual_df.head()

    modified_df = prediction_actual_df.copy()
    modified_df['Actual'] = modified_df['Actual'].apply(simplify_label)
    modified_df['Predicted'] = modified_df['Predicted'].apply(simplify_label)

    res_mat = confusion_matrix(modified_df['Actual'], modified_df['Predicted'])
    plt.figure(figsize=(10, 7))
    sns.heatmap(res_mat, annot=True, fmt='d', cmap='Blues',
                xticklabels=modified_df['Predicted'].unique(), 
                yticklabels=modified_df['Actual'].unique())
    plt.xlabel('Predicted Labels')
    plt.ylabel('Actual Labels')
    plt.title('Confusion Matrix')
    plt.show()

    print(classification_report(modified_df['Actual'], modified_df['Predicted']))

    accuracy = accuracy_score(modified_df['Actual'], modified_df['Predicted'])
    print(f"Accuracy: {round(accuracy * 100, 2)}%")

# %%
model_lstm, history_lstm = create_model("LSTM", 20)
model_gru, history_gru = create_model("GRU", 20)
model_bilstm, history_bilstm = create_model("BiLSTM", 20)
model_bigru, history_bigru = create_model("BiGRU", 20)
model_cnn, history_cnn = create_model("CNN", 20)
# Out:
# Epoch 1/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.4237 - accuracy: 0.8476
# Epoch 1: val_accuracy improved from -inf to 0.92738, saving model to LSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 11s 33ms/step - loss: 0.4226 - accuracy: 0.8481 - val_loss: 0.2073 - val_accuracy: 0.9274 - lr: 0.0010
# Epoch 2/20
# 210/210 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9524
# Epoch 2: val_accuracy improved from 0.92738 to 0.95298, saving model to LSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 6s 28ms/step - loss: 0.1373 - accuracy: 0.9524 - val_loss: 0.1410 - val_accuracy: 0.9530 - lr: 0.0010
# Epoch 3/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.1071 - accuracy: 0.9615
# Epoch 3: val_accuracy improved from 0.95298 to 0.95923, saving model to LSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 6s 28ms/step - loss: 0.1068 - accuracy: 0.9617 - val_loss: 0.1076 - val_accuracy: 0.9592 - lr: 0.0010
# Epoch 4/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9706
# Epoch 4: val_accuracy improved from 0.95923 to 0.97649, saving model to LSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 6s 28ms/step - loss: 0.0849 - accuracy: 0.9706 - val_loss: 0.0691 - val_accuracy: 0.9765 - lr: 0.0010
# Epoch 5/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0669 - accuracy: 0.9782
# Epoch 5: val_accuracy did not improve from 0.97649
# 210/210 [==============================] - 6s 28ms/step - loss: 0.0666 - accuracy: 0.9783 - val_loss: 0.0857 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 6/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0583 - accuracy: 0.9802
# Epoch 6: val_accuracy did not improve from 0.97649
# 210/210 [==============================] - 6s 28ms/step - loss: 0.0583 - accuracy: 0.9801 - val_loss: 0.0820 - val_accuracy: 0.9720 - lr: 0.0010
# Epoch 7/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0548 - accuracy: 0.9818
# Epoch 7: val_accuracy improved from 0.97649 to 0.98185, saving model to LSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 6s 28ms/step - loss: 0.0547 - accuracy: 0.9817 - val_loss: 0.0552 - val_accuracy: 0.9818 - lr: 0.0010
# Epoch 8/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0477 - accuracy: 0.9848
# Epoch 8: val_accuracy did not improve from 0.98185
# 210/210 [==============================] - 6s 28ms/step - loss: 0.0474 - accuracy: 0.9849 - val_loss: 0.0624 - val_accuracy: 0.9750 - lr: 0.0010
# Epoch 9/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0395 - accuracy: 0.9865
# Epoch 9: val_accuracy did not improve from 0.98185
# 210/210 [==============================] - 6s 28ms/step - loss: 0.0393 - accuracy: 0.9865 - val_loss: 0.0547 - val_accuracy: 0.9815 - lr: 0.0010
# Epoch 10/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9836
# Epoch 10: val_accuracy did not improve from 0.98185
# 210/210 [==============================] - 6s 27ms/step - loss: 0.0453 - accuracy: 0.9836 - val_loss: 0.0669 - val_accuracy: 0.9774 - lr: 0.0010
# Epoch 11/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0304 - accuracy: 0.9903
# Epoch 11: val_accuracy improved from 0.98185 to 0.98512, saving model to LSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 6s 28ms/step - loss: 0.0306 - accuracy: 0.9903 - val_loss: 0.0479 - val_accuracy: 0.9851 - lr: 0.0010
# Epoch 12/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0361 - accuracy: 0.9874
# Epoch 12: val_accuracy did not improve from 0.98512
# 210/210 [==============================] - 6s 27ms/step - loss: 0.0359 - accuracy: 0.9875 - val_loss: 0.0600 - val_accuracy: 0.9786 - lr: 0.0010
# Epoch 13/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0325 - accuracy: 0.9891
# Epoch 13: val_accuracy improved from 0.98512 to 0.98869, saving model to LSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 6s 28ms/step - loss: 0.0324 - accuracy: 0.9891 - val_loss: 0.0340 - val_accuracy: 0.9887 - lr: 0.0010
# Epoch 14/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0211 - accuracy: 0.9936
# Epoch 14: val_accuracy did not improve from 0.98869
# 210/210 [==============================] - 6s 27ms/step - loss: 0.0212 - accuracy: 0.9935 - val_loss: 0.0655 - val_accuracy: 0.9774 - lr: 0.0010
# Epoch 15/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9914
# Epoch 15: val_accuracy did not improve from 0.98869
# 210/210 [==============================] - 6s 27ms/step - loss: 0.0245 - accuracy: 0.9914 - val_loss: 0.1076 - val_accuracy: 0.9690 - lr: 0.0010
# Epoch 16/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9918
# Epoch 16: val_accuracy did not improve from 0.98869
# 210/210 [==============================] - 6s 27ms/step - loss: 0.0223 - accuracy: 0.9918 - val_loss: 0.0537 - val_accuracy: 0.9827 - lr: 0.0010
# Epoch 17/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9952
# Epoch 17: val_accuracy did not improve from 0.98869
# 210/210 [==============================] - 6s 27ms/step - loss: 0.0151 - accuracy: 0.9952 - val_loss: 0.0337 - val_accuracy: 0.9884 - lr: 0.0010
# Epoch 18/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0286 - accuracy: 0.9892
# Epoch 18: val_accuracy did not improve from 0.98869
# 210/210 [==============================] - 6s 27ms/step - loss: 0.0285 - accuracy: 0.9892 - val_loss: 0.0443 - val_accuracy: 0.9866 - lr: 0.0010
# Epoch 19/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9900
# Epoch 19: val_accuracy did not improve from 0.98869
# 210/210 [==============================] - 6s 27ms/step - loss: 0.0287 - accuracy: 0.9900 - val_loss: 0.0393 - val_accuracy: 0.9881 - lr: 0.0010
# Epoch 20/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9885
# Epoch 20: val_accuracy did not improve from 0.98869
# 210/210 [==============================] - 6s 27ms/step - loss: 0.0319 - accuracy: 0.9885 - val_loss: 0.0423 - val_accuracy: 0.9863 - lr: 0.0010
# Epoch 1/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.4874 - accuracy: 0.8192
# Epoch 1: val_accuracy improved from -inf to 0.94583, saving model to GRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 8s 25ms/step - loss: 0.4855 - accuracy: 0.8199 - val_loss: 0.1689 - val_accuracy: 0.9458 - lr: 0.0010
# Epoch 2/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.1287 - accuracy: 0.9558
# Epoch 2: val_accuracy improved from 0.94583 to 0.96607, saving model to GRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 5s 23ms/step - loss: 0.1298 - accuracy: 0.9555 - val_loss: 0.1065 - val_accuracy: 0.9661 - lr: 0.0010
# Epoch 3/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0999 - accuracy: 0.9661
# Epoch 3: val_accuracy improved from 0.96607 to 0.96905, saving model to GRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0999 - accuracy: 0.9661 - val_loss: 0.0851 - val_accuracy: 0.9690 - lr: 0.0010
# Epoch 4/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0798 - accuracy: 0.9723
# Epoch 4: val_accuracy improved from 0.96905 to 0.97292, saving model to GRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0799 - accuracy: 0.9722 - val_loss: 0.0693 - val_accuracy: 0.9729 - lr: 0.0010
# Epoch 5/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0709 - accuracy: 0.9736
# Epoch 5: val_accuracy did not improve from 0.97292
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0709 - accuracy: 0.9735 - val_loss: 0.0694 - val_accuracy: 0.9729 - lr: 0.0010
# Epoch 6/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0571 - accuracy: 0.9804
# Epoch 6: val_accuracy improved from 0.97292 to 0.98542, saving model to GRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0573 - accuracy: 0.9804 - val_loss: 0.0471 - val_accuracy: 0.9854 - lr: 0.0010
# Epoch 7/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0473 - accuracy: 0.9842
# Epoch 7: val_accuracy did not improve from 0.98542
# 210/210 [==============================] - 5s 22ms/step - loss: 0.0473 - accuracy: 0.9843 - val_loss: 0.0479 - val_accuracy: 0.9807 - lr: 0.0010
# Epoch 8/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0443 - accuracy: 0.9856
# Epoch 8: val_accuracy improved from 0.98542 to 0.98988, saving model to GRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0442 - accuracy: 0.9856 - val_loss: 0.0363 - val_accuracy: 0.9899 - lr: 0.0010
# Epoch 9/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9845
# Epoch 9: val_accuracy did not improve from 0.98988
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0464 - accuracy: 0.9845 - val_loss: 0.0438 - val_accuracy: 0.9863 - lr: 0.0010
# Epoch 10/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9865
# Epoch 10: val_accuracy did not improve from 0.98988
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0380 - accuracy: 0.9865 - val_loss: 0.0424 - val_accuracy: 0.9848 - lr: 0.0010
# Epoch 11/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9907
# Epoch 11: val_accuracy did not improve from 0.98988
# 210/210 [==============================] - 5s 22ms/step - loss: 0.0269 - accuracy: 0.9907 - val_loss: 0.0493 - val_accuracy: 0.9839 - lr: 0.0010
# Epoch 12/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0304 - accuracy: 0.9905
# Epoch 12: val_accuracy improved from 0.98988 to 0.99464, saving model to GRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 5s 22ms/step - loss: 0.0304 - accuracy: 0.9905 - val_loss: 0.0217 - val_accuracy: 0.9946 - lr: 0.0010
# Epoch 13/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0240 - accuracy: 0.9921
# Epoch 13: val_accuracy did not improve from 0.99464
# 210/210 [==============================] - 5s 22ms/step - loss: 0.0242 - accuracy: 0.9921 - val_loss: 0.0198 - val_accuracy: 0.9940 - lr: 0.0010
# Epoch 14/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0214 - accuracy: 0.9930
# Epoch 14: val_accuracy improved from 0.99464 to 0.99554, saving model to GRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0214 - accuracy: 0.9930 - val_loss: 0.0174 - val_accuracy: 0.9955 - lr: 0.0010
# Epoch 15/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0173 - accuracy: 0.9946
# Epoch 15: val_accuracy did not improve from 0.99554
# 210/210 [==============================] - 5s 22ms/step - loss: 0.0176 - accuracy: 0.9945 - val_loss: 0.0487 - val_accuracy: 0.9821 - lr: 0.0010
# Epoch 16/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0212 - accuracy: 0.9919
# Epoch 16: val_accuracy did not improve from 0.99554
# 210/210 [==============================] - 5s 22ms/step - loss: 0.0212 - accuracy: 0.9919 - val_loss: 0.0263 - val_accuracy: 0.9923 - lr: 0.0010
# Epoch 17/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9942
# Epoch 17: val_accuracy did not improve from 0.99554
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0171 - accuracy: 0.9942 - val_loss: 0.0217 - val_accuracy: 0.9929 - lr: 0.0010
# Epoch 18/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9923
# Epoch 18: val_accuracy did not improve from 0.99554
# 210/210 [==============================] - 5s 21ms/step - loss: 0.0228 - accuracy: 0.9923 - val_loss: 0.0213 - val_accuracy: 0.9923 - lr: 0.0010
# Epoch 19/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9955
# Epoch 19: val_accuracy did not improve from 0.99554
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.0179 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 20/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9982
# Epoch 20: val_accuracy did not improve from 0.99554
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0073 - accuracy: 0.9982 - val_loss: 0.0187 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 1/20
# 210/210 [==============================] - ETA: 0s - loss: 0.3392 - accuracy: 0.8826
# Epoch 1: val_accuracy improved from -inf to 0.95655, saving model to BiLSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 21s 77ms/step - loss: 0.3392 - accuracy: 0.8826 - val_loss: 0.1373 - val_accuracy: 0.9565 - lr: 0.0010
# Epoch 2/20
# 210/210 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9583
# Epoch 2: val_accuracy improved from 0.95655 to 0.95744, saving model to BiLSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 15s 70ms/step - loss: 0.1224 - accuracy: 0.9583 - val_loss: 0.1096 - val_accuracy: 0.9574 - lr: 0.0010
# Epoch 3/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0934 - accuracy: 0.9667
# Epoch 3: val_accuracy improved from 0.95744 to 0.96071, saving model to BiLSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 14s 69ms/step - loss: 0.0934 - accuracy: 0.9667 - val_loss: 0.1121 - val_accuracy: 0.9607 - lr: 0.0010
# Epoch 4/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9809
# Epoch 4: val_accuracy improved from 0.96071 to 0.97768, saving model to BiLSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 14s 68ms/step - loss: 0.0570 - accuracy: 0.9809 - val_loss: 0.0707 - val_accuracy: 0.9777 - lr: 0.0010
# Epoch 5/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9789
# Epoch 5: val_accuracy improved from 0.97768 to 0.97946, saving model to BiLSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 15s 70ms/step - loss: 0.0593 - accuracy: 0.9789 - val_loss: 0.0584 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 6/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.9862
# Epoch 6: val_accuracy did not improve from 0.97946
# 210/210 [==============================] - 16s 78ms/step - loss: 0.0398 - accuracy: 0.9862 - val_loss: 0.0599 - val_accuracy: 0.9780 - lr: 0.0010
# Epoch 7/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9875
# Epoch 7: val_accuracy improved from 0.97946 to 0.98512, saving model to BiLSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 15s 70ms/step - loss: 0.0390 - accuracy: 0.9875 - val_loss: 0.0423 - val_accuracy: 0.9851 - lr: 0.0010
# Epoch 8/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9909
# Epoch 8: val_accuracy improved from 0.98512 to 0.99286, saving model to BiLSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 14s 69ms/step - loss: 0.0284 - accuracy: 0.9909 - val_loss: 0.0223 - val_accuracy: 0.9929 - lr: 0.0010
# Epoch 9/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9908
# Epoch 9: val_accuracy did not improve from 0.99286
# 210/210 [==============================] - 16s 75ms/step - loss: 0.0247 - accuracy: 0.9908 - val_loss: 0.0345 - val_accuracy: 0.9872 - lr: 0.0010
# Epoch 10/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9949
# Epoch 10: val_accuracy did not improve from 0.99286
# 210/210 [==============================] - 15s 70ms/step - loss: 0.0159 - accuracy: 0.9949 - val_loss: 0.0312 - val_accuracy: 0.9902 - lr: 0.0010
# Epoch 11/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9942
# Epoch 11: val_accuracy improved from 0.99286 to 0.99315, saving model to BiLSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 16s 76ms/step - loss: 0.0180 - accuracy: 0.9942 - val_loss: 0.0252 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 12/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9951
# Epoch 12: val_accuracy did not improve from 0.99315
# 210/210 [==============================] - 15s 72ms/step - loss: 0.0150 - accuracy: 0.9951 - val_loss: 0.0258 - val_accuracy: 0.9911 - lr: 0.0010
# Epoch 13/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9941
# Epoch 13: val_accuracy did not improve from 0.99315
# 210/210 [==============================] - 15s 71ms/step - loss: 0.0194 - accuracy: 0.9941 - val_loss: 0.0314 - val_accuracy: 0.9875 - lr: 0.0010
# Epoch 14/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9966
# Epoch 14: val_accuracy did not improve from 0.99315
# 210/210 [==============================] - 15s 72ms/step - loss: 0.0129 - accuracy: 0.9966 - val_loss: 0.0352 - val_accuracy: 0.9863 - lr: 0.0010
# Epoch 15/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9955
# Epoch 15: val_accuracy did not improve from 0.99315
# 210/210 [==============================] - 15s 71ms/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.0222 - val_accuracy: 0.9929 - lr: 0.0010
# Epoch 16/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9969
# Epoch 16: val_accuracy did not improve from 0.99315
# 210/210 [==============================] - 16s 77ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0374 - val_accuracy: 0.9896 - lr: 0.0010
# Epoch 17/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9933
# Epoch 17: val_accuracy did not improve from 0.99315
# 210/210 [==============================] - 16s 74ms/step - loss: 0.0204 - accuracy: 0.9933 - val_loss: 0.0265 - val_accuracy: 0.9899 - lr: 0.0010
# Epoch 18/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9963
# Epoch 18: val_accuracy improved from 0.99315 to 0.99375, saving model to BiLSTM # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 15s 71ms/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.0153 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 19/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9975
# Epoch 19: val_accuracy did not improve from 0.99375
# 210/210 [==============================] - 15s 72ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0190 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 20/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9964
# Epoch 20: val_accuracy did not improve from 0.99375
# 210/210 [==============================] - 15s 73ms/step - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.0273 - val_accuracy: 0.9926 - lr: 0.0010
# Epoch 1/20
# 210/210 [==============================] - ETA: 0s - loss: 0.3125 - accuracy: 0.8847
# Epoch 1: val_accuracy improved from -inf to 0.96637, saving model to BiGRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 17s 56ms/step - loss: 0.3125 - accuracy: 0.8847 - val_loss: 0.0909 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 2/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0816 - accuracy: 0.9723
# Epoch 2: val_accuracy improved from 0.96637 to 0.97708, saving model to BiGRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 10s 47ms/step - loss: 0.0817 - accuracy: 0.9722 - val_loss: 0.0607 - val_accuracy: 0.9771 - lr: 0.0010
# Epoch 3/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0585 - accuracy: 0.9809
# Epoch 3: val_accuracy improved from 0.97708 to 0.98363, saving model to BiGRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 10s 49ms/step - loss: 0.0585 - accuracy: 0.9808 - val_loss: 0.0462 - val_accuracy: 0.9836 - lr: 0.0010
# Epoch 4/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.9849
# Epoch 4: val_accuracy improved from 0.98363 to 0.98839, saving model to BiGRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 12s 59ms/step - loss: 0.0429 - accuracy: 0.9849 - val_loss: 0.0332 - val_accuracy: 0.9884 - lr: 0.0010
# Epoch 5/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9904
# Epoch 5: val_accuracy did not improve from 0.98839
# 210/210 [==============================] - 15s 69ms/step - loss: 0.0282 - accuracy: 0.9904 - val_loss: 0.0347 - val_accuracy: 0.9884 - lr: 0.0010
# Epoch 6/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0231 - accuracy: 0.9925
# Epoch 6: val_accuracy improved from 0.98839 to 0.99375, saving model to BiGRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 14s 68ms/step - loss: 0.0231 - accuracy: 0.9925 - val_loss: 0.0159 - val_accuracy: 0.9937 - lr: 0.0010
# Epoch 7/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0207 - accuracy: 0.9931
# Epoch 7: val_accuracy did not improve from 0.99375
# 210/210 [==============================] - 11s 55ms/step - loss: 0.0207 - accuracy: 0.9931 - val_loss: 0.0296 - val_accuracy: 0.9875 - lr: 0.0010
# Epoch 8/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9952
# Epoch 8: val_accuracy improved from 0.99375 to 0.99494, saving model to BiGRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 11s 54ms/step - loss: 0.0161 - accuracy: 0.9952 - val_loss: 0.0147 - val_accuracy: 0.9949 - lr: 0.0010
# Epoch 9/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9951
# Epoch 9: val_accuracy did not improve from 0.99494
# 210/210 [==============================] - 15s 74ms/step - loss: 0.0146 - accuracy: 0.9951 - val_loss: 0.0150 - val_accuracy: 0.9949 - lr: 0.0010
# Epoch 10/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9961
# Epoch 10: val_accuracy did not improve from 0.99494
# 210/210 [==============================] - 11s 51ms/step - loss: 0.0107 - accuracy: 0.9961 - val_loss: 0.0400 - val_accuracy: 0.9848 - lr: 0.0010
# Epoch 11/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9930
# Epoch 11: val_accuracy did not improve from 0.99494
# 210/210 [==============================] - 10s 47ms/step - loss: 0.0208 - accuracy: 0.9930 - val_loss: 0.0176 - val_accuracy: 0.9943 - lr: 0.0010
# Epoch 12/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9981
# Epoch 12: val_accuracy improved from 0.99494 to 0.99583, saving model to BiGRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 10s 46ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.0110 - val_accuracy: 0.9958 - lr: 0.0010
# Epoch 13/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9994
# Epoch 13: val_accuracy did not improve from 0.99583
# 210/210 [==============================] - 10s 49ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0137 - val_accuracy: 0.9949 - lr: 0.0010
# Epoch 14/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9945
# Epoch 14: val_accuracy did not improve from 0.99583
# 210/210 [==============================] - 10s 46ms/step - loss: 0.0177 - accuracy: 0.9945 - val_loss: 0.0608 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 15/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9931
# Epoch 15: val_accuracy improved from 0.99583 to 0.99673, saving model to BiGRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 11s 52ms/step - loss: 0.0230 - accuracy: 0.9931 - val_loss: 0.0096 - val_accuracy: 0.9967 - lr: 0.0010
# Epoch 16/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9977
# Epoch 16: val_accuracy did not improve from 0.99673
# 210/210 [==============================] - 10s 48ms/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 0.0191 - val_accuracy: 0.9935 - lr: 0.0010
# Epoch 17/20
# 210/210 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9998
# Epoch 17: val_accuracy did not improve from 0.99673
# 210/210 [==============================] - 10s 45ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.0067 - val_accuracy: 0.9967 - lr: 5.0000e-04
# Epoch 18/20
# 209/210 [============================>.] - ETA: 0s - loss: 5.6456e-04 - accuracy: 1.0000
# Epoch 18: val_accuracy improved from 0.99673 to 0.99762, saving model to BiGRU # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 10s 46ms/step - loss: 5.6841e-04 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9976 - lr: 5.0000e-04
# Epoch 19/20
# 210/210 [==============================] - ETA: 0s - loss: 4.4072e-04 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.99762
# 210/210 [==============================] - 10s 46ms/step - loss: 4.4072e-04 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9976 - lr: 5.0000e-04
# Epoch 20/20
# 209/210 [============================>.] - ETA: 0s - loss: 3.4799e-04 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.99762
# 210/210 [==============================] - 10s 45ms/step - loss: 3.4716e-04 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 0.9973 - lr: 5.0000e-04
# Epoch 1/20
# 209/210 [============================>.] - ETA: 0s - loss: 0.2271 - accuracy: 0.9246
# Epoch 1: val_accuracy improved from -inf to 0.97262, saving model to CNN # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 3s 8ms/step - loss: 0.2264 - accuracy: 0.9249 - val_loss: 0.0951 - val_accuracy: 0.9726 - lr: 0.0010
# Epoch 2/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0433 - accuracy: 0.9853
# Epoch 2: val_accuracy improved from 0.97262 to 0.99018, saving model to CNN # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 1s 6ms/step - loss: 0.0434 - accuracy: 0.9853 - val_loss: 0.0342 - val_accuracy: 0.9902 - lr: 0.0010
# Epoch 3/20
# 200/210 [===========================>..] - ETA: 0s - loss: 0.0228 - accuracy: 0.9919
# Epoch 3: val_accuracy improved from 0.99018 to 0.99226, saving model to CNN # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 1s 6ms/step - loss: 0.0231 - accuracy: 0.9918 - val_loss: 0.0268 - val_accuracy: 0.9923 - lr: 0.0010
# Epoch 4/20
# 200/210 [===========================>..] - ETA: 0s - loss: 0.0139 - accuracy: 0.9953
# Epoch 4: val_accuracy improved from 0.99226 to 0.99524, saving model to CNN # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 1s 6ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.0146 - val_accuracy: 0.9952 - lr: 0.0010
# Epoch 5/20
# 206/210 [============================>.] - ETA: 0s - loss: 0.0121 - accuracy: 0.9966
# Epoch 5: val_accuracy improved from 0.99524 to 0.99673, saving model to CNN # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 1s 6ms/step - loss: 0.0119 - accuracy: 0.9967 - val_loss: 0.0106 - val_accuracy: 0.9967 - lr: 0.0010
# Epoch 6/20
# 206/210 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9992
# Epoch 6: val_accuracy improved from 0.99673 to 0.99732, saving model to CNN # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 1s 7ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0087 - val_accuracy: 0.9973 - lr: 0.0010
# Epoch 7/20
# 204/210 [============================>.] - ETA: 0s - loss: 0.0157 - accuracy: 0.9953
# Epoch 7: val_accuracy did not improve from 0.99732
# 210/210 [==============================] - 1s 7ms/step - loss: 0.0153 - accuracy: 0.9954 - val_loss: 0.0161 - val_accuracy: 0.9949 - lr: 0.0010
# Epoch 8/20
# 208/210 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 0.9971
# Epoch 8: val_accuracy did not improve from 0.99732
# 210/210 [==============================] - 1s 6ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.0111 - val_accuracy: 0.9958 - lr: 0.0010
# Epoch 9/20
# 205/210 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.9988
# Epoch 9: val_accuracy did not improve from 0.99732
# 210/210 [==============================] - 1s 6ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.0137 - val_accuracy: 0.9952 - lr: 0.0010
# Epoch 10/20
# 205/210 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 10: val_accuracy did not improve from 0.99732
# 210/210 [==============================] - 1s 6ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0107 - val_accuracy: 0.9964 - lr: 5.0000e-04
# Epoch 11/20
# 208/210 [============================>.] - ETA: 0s - loss: 2.8321e-04 - accuracy: 1.0000
# Epoch 11: val_accuracy improved from 0.99732 to 0.99762, saving model to CNN # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 1s 6ms/step - loss: 2.8214e-04 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9976 - lr: 5.0000e-04
# Epoch 12/20
# 208/210 [============================>.] - ETA: 0s - loss: 1.7733e-04 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.99762
# 210/210 [==============================] - 1s 6ms/step - loss: 1.7886e-04 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9976 - lr: 5.0000e-04
# Epoch 13/20
# 203/210 [============================>.] - ETA: 0s - loss: 1.3982e-04 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.99762
# 210/210 [==============================] - 1s 6ms/step - loss: 1.3764e-04 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9976 - lr: 5.0000e-04
# Epoch 14/20
# 209/210 [============================>.] - ETA: 0s - loss: 1.1016e-04 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.99762
# 210/210 [==============================] - 1s 6ms/step - loss: 1.0970e-04 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9973 - lr: 5.0000e-04
# Epoch 15/20
# 208/210 [============================>.] - ETA: 0s - loss: 9.0268e-05 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.99762
# 210/210 [==============================] - 1s 6ms/step - loss: 9.3527e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9976 - lr: 5.0000e-04
# Epoch 16/20
# 208/210 [============================>.] - ETA: 0s - loss: 7.6710e-05 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.99762
# 210/210 [==============================] - 1s 6ms/step - loss: 7.6212e-05 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 0.9976 - lr: 2.5000e-04
# Epoch 17/20
# 202/210 [===========================>..] - ETA: 0s - loss: 6.9894e-05 - accuracy: 1.0000
# Epoch 17: val_accuracy improved from 0.99762 to 0.99851, saving model to CNN # TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 210/210 [==============================] - 1s 6ms/step - loss: 7.0063e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9985 - lr: 2.5000e-04
# Epoch 18/20
# 209/210 [============================>.] - ETA: 0s - loss: 6.5031e-05 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.99851
# 210/210 [==============================] - 1s 7ms/step - loss: 6.4777e-05 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 0.9979 - lr: 2.5000e-04
# Epoch 19/20
# 209/210 [============================>.] - ETA: 0s - loss: 5.9548e-05 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.99851
# 210/210 [==============================] - 1s 7ms/step - loss: 5.9288e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9979 - lr: 2.5000e-04
# Epoch 20/20
# 205/210 [============================>.] - ETA: 0s - loss: 5.4544e-05 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.99851
# 210/210 [==============================] - 1s 6ms/step - loss: 5.4294e-05 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9979 - lr: 1.2500e-04

# %%
evaluate_model(model_gru)
plot_history(history_gru)
# Out:
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0187 - accuracy: 0.9937
# Test Loss: 0.018680371344089508
# Test Accuracy: 0.9937499761581421

# %%
create_model_summary(model_gru)
# Out:
# 105/105 [==============================] - 2s 8ms/step
#               precision    recall  f1-score   support
#
#        angry       0.99      1.00      0.99       489
#      disgust       0.99      0.98      0.99       504
#         fear       1.00      1.00      1.00       460
#        happy       0.99      1.00      0.99       464
#      neutral       1.00      1.00      1.00       475
#          sad       1.00      0.99      0.99       494
#     surprise       0.98      0.99      0.99       474
#
#     accuracy                           0.99      3360
#    macro avg       0.99      0.99      0.99      3360
# weighted avg       0.99      0.99      0.99      3360
#
# Accuracy: 99.38%

# %%
evaluate_model(model_lstm)
plot_history(history_lstm)
# Out:
# 105/105 [==============================] - 1s 13ms/step - loss: 0.0423 - accuracy: 0.9863
# Test Loss: 0.04234488308429718
# Test Accuracy: 0.9863095283508301

# %%
create_model_summary(model_lstm)
# Out:
# 105/105 [==============================] - 2s 8ms/step
#               precision    recall  f1-score   support
#
#        angry       0.99      0.98      0.99       489
#      disgust       0.99      0.95      0.97       504
#         fear       1.00      1.00      1.00       460
#        happy       0.97      0.99      0.98       464
#      neutral       1.00      1.00      1.00       475
#          sad       0.97      1.00      0.98       494
#     surprise       0.99      0.99      0.99       474
#
#     accuracy                           0.99      3360
#    macro avg       0.99      0.99      0.99      3360
# weighted avg       0.99      0.99      0.99      3360
#
# Accuracy: 98.63%

# %%
evaluate_model(model_bilstm)
plot_history(history_bilstm)
# Out:
# 105/105 [==============================] - 2s 22ms/step - loss: 0.0273 - accuracy: 0.9926
# Test Loss: 0.02728058584034443
# Test Accuracy: 0.992559552192688

# %%
create_model_summary(model_bilstm)
# Out:
# 105/105 [==============================] - 4s 19ms/step
#               precision    recall  f1-score   support
#
#        angry       0.99      0.99      0.99       489
#      disgust       0.98      0.99      0.99       504
#         fear       1.00      1.00      1.00       460
#        happy       0.99      1.00      0.99       464
#      neutral       1.00      1.00      1.00       475
#          sad       1.00      0.99      0.99       494
#     surprise       0.99      0.98      0.99       474
#
#     accuracy                           0.99      3360
#    macro avg       0.99      0.99      0.99      3360
# weighted avg       0.99      0.99      0.99      3360
#
# Accuracy: 99.26%

# %%
evaluate_model(model_bigru)
plot_history(history_bigru)
# Out:
# 105/105 [==============================] - 1s 13ms/step - loss: 0.0056 - accuracy: 0.9973
# Test Loss: 0.00555280689150095
# Test Accuracy: 0.9973214268684387

# %%
create_model_summary(model_bigru)
# Out:
# 105/105 [==============================] - 3s 13ms/step
#               precision    recall  f1-score   support
#
#        angry       0.99      1.00      1.00       489
#      disgust       1.00      1.00      1.00       504
#         fear       1.00      1.00      1.00       460
#        happy       1.00      1.00      1.00       464
#      neutral       1.00      1.00      1.00       475
#          sad       1.00      1.00      1.00       494
#     surprise       1.00      0.99      1.00       474
#
#     accuracy                           1.00      3360
#    macro avg       1.00      1.00      1.00      3360
# weighted avg       1.00      1.00      1.00      3360
#
# Accuracy: 99.73%

# %%
evaluate_model(model_cnn)
plot_history(history_cnn)
# Out:
# 105/105 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 0.9979
# Test Loss: 0.006945024710148573
# Test Accuracy: 0.9979166388511658

# %%
create_model_summary(model_cnn)
# Out:
# 105/105 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#        angry       1.00      1.00      1.00       489
#      disgust       1.00      1.00      1.00       504
#         fear       1.00      1.00      1.00       460
#        happy       0.99      1.00      1.00       464
#      neutral       1.00      1.00      1.00       475
#          sad       1.00      1.00      1.00       494
#     surprise       1.00      0.99      1.00       474
#
#     accuracy                           1.00      3360
#    macro avg       1.00      1.00      1.00      3360
# weighted avg       1.00      1.00      1.00      3360
#
# Accuracy: 99.79%
