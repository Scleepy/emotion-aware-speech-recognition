# %%
import pandas as pd
import numpy as np
import os
from IPython.display import Audio
import librosa
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU, Bidirectional, Conv1D, MaxPooling1D, Flatten, BatchNormalization, Activation, Masking
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping

# %%
file_name_dataset = "CREMAD"
dataset_cremad_dir = "../Dataset/CREMAD/AudioWAV"
crema_dir_list = os.listdir(dataset_cremad_dir)
print(len(crema_dir_list))
# Out:
# 7442

# %%
emotion_dict = {
    "ANG": "angry",
    "DIS": "disgust",
    "FEA": "fear",
    "HAP": "happy",
    "NEU": "neutral",
    "SAD": "sad"
}

# %%
emotion_list = []
path_list = []

for audio_file in crema_dir_list:
    emotion_segment = audio_file.split("_")[2]

    audio_file_path = os.path.join(dataset_cremad_dir, audio_file);

    path_list.append(audio_file_path)
    
    if emotion_segment in emotion_dict:
        emotion_list.append(emotion_dict[emotion_segment])
    else:
        emotion_list.append("unknown")

cremad_df = pd.DataFrame({'Emotion': emotion_list, 'Path': path_list})
cremad_df.to_csv("crema_df.csv", index = False)
cremad_df.head()
# Out:
#    Emotion                                            Path
# 0    angry  ../Dataset/CREMAD/AudioWAV\1001_DFA_ANG_XX.wav
# 1  disgust  ../Dataset/CREMAD/AudioWAV\1001_DFA_DIS_XX.wav
# 2     fear  ../Dataset/CREMAD/AudioWAV\1001_DFA_FEA_XX.wav
# 3    happy  ../Dataset/CREMAD/AudioWAV\1001_DFA_HAP_XX.wav
# 4  neutral  ../Dataset/CREMAD/AudioWAV\1001_DFA_NEU_XX.wav

# %%
file_name_dataset += " RAVDESS"
dataset_ravdess_dir = "../Dataset/RAVDESS/"
ravdess_dir_list = os.listdir(dataset_ravdess_dir)

# %%
emotion_dict = {
    "01": "neutral",
    "02": "neutral",
    "03": "happy",
    "04": "sad",
    "05": "angry",
    "06": "fear",
    "07": "disgust",
    "08": "surprise"
}

# %%
emotion_list = []
path_list = []

for dir in ravdess_dir_list:
    for audio_file in os.listdir(dataset_ravdess_dir + dir):
        emotion_segment = audio_file.split("-")[2]

        if emotion_segment in emotion_dict:
            emotion_list.append(emotion_dict[emotion_segment])
        else:
            emotion_list.append("unknown")

        audio_file_path = os.path.join(dataset_ravdess_dir, dir, audio_file)
        path_list.append(audio_file_path)

ravdess_df = pd.DataFrame({'Emotion': emotion_list, 'Path': path_list})
ravdess_df.to_csv("tess_df.csv", index = False)
ravdess_df.head()
# Out:
#    Emotion                                               Path
# 0  neutral  ../Dataset/RAVDESS/Actor_01\03-01-01-01-01-01-...
# 1  neutral  ../Dataset/RAVDESS/Actor_01\03-01-01-01-01-02-...
# 2  neutral  ../Dataset/RAVDESS/Actor_01\03-01-01-01-02-01-...
# 3  neutral  ../Dataset/RAVDESS/Actor_01\03-01-01-01-02-02-...
# 4  neutral  ../Dataset/RAVDESS/Actor_01\03-01-02-01-01-01-...

# %%
file_name_dataset += " TESS"
dataset_tess_dir = "../Dataset/TESS/"
tess_dir_list = os.listdir(dataset_tess_dir)

# %%
emotion_list = []
path_list = []

for dir in tess_dir_list:
    for audio_file in os.listdir(dataset_tess_dir + dir):
        emotion_segment = audio_file.split("_")[2].split(".")[0]
        audio_file_path = os.path.join(dataset_tess_dir, dir, audio_file)
        
        if (emotion_segment == "ps"):
            emotion_list.append("surprise")
        else:
            emotion_list.append(emotion_segment)
        
        path_list.append(audio_file_path)

tess_df = pd.DataFrame({'Emotion': emotion_list, 'Path': path_list})
tess_df.to_csv("tess_df.csv", index = False)
tess_df.head()
# Out:
#   Emotion                                          Path
# 0   angry  ../Dataset/TESS/OAF_angry\OAF_back_angry.wav
# 1   angry   ../Dataset/TESS/OAF_angry\OAF_bar_angry.wav
# 2   angry  ../Dataset/TESS/OAF_angry\OAF_base_angry.wav
# 3   angry  ../Dataset/TESS/OAF_angry\OAF_bath_angry.wav
# 4   angry  ../Dataset/TESS/OAF_angry\OAF_bean_angry.wav

# %%
hybrid_df = pd.concat([tess_df, ravdess_df, cremad_df], ignore_index=True)
hybrid_df.head()
# Out:
#   Emotion                                          Path
# 0   angry  ../Dataset/TESS/OAF_angry\OAF_back_angry.wav
# 1   angry   ../Dataset/TESS/OAF_angry\OAF_bar_angry.wav
# 2   angry  ../Dataset/TESS/OAF_angry\OAF_base_angry.wav
# 3   angry  ../Dataset/TESS/OAF_angry\OAF_bath_angry.wav
# 4   angry  ../Dataset/TESS/OAF_angry\OAF_bean_angry.wav

# %%
plt.figure(figsize=(12, 8))
plt.title('Count of Emotions')
sns.countplot(x = hybrid_df.Emotion, hue = hybrid_df.Emotion)
plt.ylabel('Count')
plt.xlabel('Emotions')
sns.despine(top = True, right = True, left = False, bottom = False)
plt.show()

# %%
def waveplot(data, sr, emo):
  plt.figure(figsize = (6, 1))
  plt.title(f"{emo} audio waveplot")
  librosa.display.waveshow(data, sr = sr)

def spectrogram(data, sr, emo):
  X = librosa.stft(data)
  Xdb = librosa.amplitude_to_db(abs(X))
  plt.figure(figsize = (6, 1))
  plt.title(f"{emo} audio spectrogram")
  librosa.display.specshow(Xdb, sr = sr, x_axis = 'time', y_axis = 'hz')

# %%
emotion = 'happy'

audio_file_path = np.array(hybrid_df.Path[hybrid_df.Emotion.str.contains(emotion)])[1]
data, sampling_rate = librosa.load(audio_file_path)

waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(audio_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def noise(data):
  noise_amp = 0.04 * np.random.uniform() * np.amax(data)
  data = data + noise_amp * np.random.normal(size = data.shape[0])
  return data

def time_stretch(data, rate = 0.8):
  return librosa.effects.time_stretch(data, rate = rate)

def shift(data, steps_range = (-5, 5)):
  shift_range = int(np.random.uniform(steps_range[0], steps_range[1]) * 1000)
  return np.roll(data, shift_range)

def pitch_shift(data, sampling_rate, n_steps = 0.7):
  return librosa.effects.pitch_shift(data, sr = sampling_rate, n_steps = n_steps)

def random_time_stretch(data, stretch_factor_range = (0.8, 1.25)):
  random_stretch_factor = np.random.uniform(stretch_factor_range[0], stretch_factor_range[1])

  augmented_data = time_stretch(data, random_stretch_factor)

  if len(augmented_data) > len(data):
    augmented_data = augmented_data[:len(data)]
  else:
    padded_augmented_data = np.zeros_like(data)
    padded_augmented_data[:len(augmented_data)] = augmented_data
    augmented_data = padded_augmented_data

  return augmented_data

def random_pitch_shift(data, sampling_rate, steps_range=(-4, 4)):
  n_steps = np.random.randint(steps_range[0], steps_range[1] + 1)  
  return pitch_shift(data, sampling_rate, n_steps)

# %%
def extract_mel(data, sr, n_mels=128, fmax=8000):
    mel_spec = librosa.feature.melspectrogram(y=data, sr=sr, n_mels=n_mels, fmax=fmax)
    return mel_spec;

def extract_log_mel_spec(data, sr, n_mels=128, fmax=8000):
    log_mel_spec = librosa.power_to_db(extract_mel(data, sr, n_mels, fmax))
    return log_mel_spec;

def extract_mfcc(data, sr, n_mfcc=13):
    mfcc = librosa.feature.mfcc(y = data, sr = sr, n_mfcc=n_mfcc)
    return mfcc;

def extract_delta_mfcc(data, sr, n_mfcc=13):
    mfcc = extract_mfcc(data, sr, n_mfcc)
    delta_mfcc = librosa.feature.delta(mfcc)
    return delta_mfcc;

def extract_delta_delta_mfcc(data, sr, n_mfcc=13):
    mfcc = extract_mfcc(data, sr, n_mfcc)
    delta2_mfcc = librosa.feature.delta(mfcc, order=2)
    return delta2_mfcc;

def extract_zcr(data):
    zcr = librosa.feature.zero_crossing_rate(y=data)
    return zcr

def extract_rms(data):
    rms = librosa.feature.rms(y=data)
    return rms

# %%
mel = extract_mel(data, sampling_rate, 128, 8000)
plt.figure(figsize=(10, 2))
librosa.display.specshow(mel, x_axis='time', sr = sampling_rate)
plt.ylabel('Mel')
plt.colorbar()

log_mel_spec = extract_log_mel_spec(data, sampling_rate, 128, 8000)
plt.figure(figsize=(10, 2))
librosa.display.specshow(log_mel_spec, x_axis='time', sr = sampling_rate)
plt.ylabel('Log Mel Spectogram')
plt.colorbar()

# MFCC
mfcc = extract_mfcc(data, sampling_rate, 13)
plt.figure(figsize=(10, 2))
librosa.display.specshow(mfcc, x_axis='time', sr = sampling_rate)
plt.ylabel('MFCC')
plt.colorbar()

# ΔMFCC
delta_mfcc = extract_delta_mfcc(data, sampling_rate, 13)
plt.figure(figsize=(10, 2))
librosa.display.specshow(delta_mfcc, x_axis='time', sr = sampling_rate)
plt.ylabel('Delta MFCC')
plt.colorbar()

# ΔΔMFCC
delta_delta_mfcc = extract_delta_delta_mfcc(data, sampling_rate, 13)
plt.figure(figsize=(10, 2))
librosa.display.specshow(delta_delta_mfcc, x_axis='time', sr = sampling_rate)
plt.ylabel('Delta Delta MFCC')
plt.colorbar()
plt.show()

# MFCC-based approximate entropy
# MFCC-based spectral entropy
# Three-dimensional Mel-scale frequency cepstral coefficients

# %%
# feature_extraction_techniques = ["MFCC", "Delta MFCC", "Delta Delta MFCC"]
# feature_extraction_techniques = ["MFCC Mean 40", "Delta MFCC Mean 40", "Delta Delta MFCC Mean 40"]
feature_extraction_techniques = ["MFCC Mean 40"]

file_name_feat_extract = " & ".join(feature_extraction_techniques)

def extract_features(data, sr, n_mfcc=40):
    # MEAN
    features = np.array([])
    mfcc = extract_mfcc(data, sr, n_mfcc).T
    delta_mfcc = extract_delta_mfcc(data, sr, n_mfcc).T
    delta_delta_mfcc = extract_delta_delta_mfcc(data, sr, n_mfcc).T
    mfcc_mean = np.mean(mfcc, axis=0)
    delta_mfcc_mean = np.mean(delta_mfcc, axis=0)
    delta_delta_mfcc_mean = np.mean(delta_delta_mfcc, axis=0)
    # mfcc_min = np.min(mfcc, axis=0)
    # mfcc_max = np.max(mfcc, axis=0)
    # mfcc_std = np.std(mfcc, axis=0)
    # zcr = np.mean(extract_zcr(data))
    # rms = np.mean(extract_rms(data))
    features = np.hstack((features, mfcc_mean))

    # ENTIRE FEATURE
    # mfcc = extract_mfcc(data, sr).T
    # delta_mfcc = extract_delta_mfcc(data, sr).T
    # delta_delta_mfcc = extract_delta_delta_mfcc(data, sr).T
    # features = np.concatenate((mfcc, delta_mfcc, delta_delta_mfcc), axis=1)
    
    return features

# %%
# data_augmentation_techniques = ["Noise", "Random Time Stretch", "Random Pitch Shift"]
# data_augmentation_techniques = ["Noise 0.04", "Low Speed 0.75", "Stretched 0.7", "High Speed 1.25", "Pitch Shift 0.7", "Shift (-5, 5)"]
data_augmentation_techniques = ["Noise 0.04", "Low Speed 0.75", "High Speed 1.25", "Pitch Shift 0.7", "Shift (-5, 5)"]

file_name_data_aug = " & ".join(data_augmentation_techniques)

def get_features(path):
    data, sampling_rate = librosa.load(path, duration=3, offset=0.5)

    noisy_data = noise(data)

    lowspeed_data = time_stretch(data, rate=0.75) #Ignore this
    stretched_data = time_stretch(data, rate=0.7) #Ignore this
    highspeed_data = time_stretch(data, rate=1.25) #Ignore this
    pitch_shift_data = pitch_shift(data, sampling_rate, n_steps=0.7) #Ignore this
    shift_data = shift(data, (-5, 5)) #Ignore this

    random_time_stretch_data = random_time_stretch(data, (0.8, 1.25))
    random_pitch_shift_data = random_pitch_shift(data, sampling_rate, (-4, 4))

    features = extract_features(data, sampling_rate)
    noisy_features = extract_features(noisy_data, sampling_rate)
    
    lowspeed_features = extract_features(lowspeed_data, sampling_rate) #Ignore this
    stretched_features = extract_features(stretched_data, sampling_rate) #Ignore this
    highspeed_features = extract_features(highspeed_data, sampling_rate) #Ignore this
    pitch_shift_features = extract_features(pitch_shift_data, sampling_rate) #Ignore this
    shift_features = extract_features(shift_data, sampling_rate) #Ignore this

    random_time_stretch_features = extract_features(random_time_stretch_data, sampling_rate)
    random_pitch_shift_features = extract_features(random_pitch_shift_data, sampling_rate)

    # result = np.vstack((features, noisy_features, random_time_stretch_features, random_pitch_shift_features))
    result = np.vstack((features, noisy_features, lowspeed_features, highspeed_features, pitch_shift_features, shift_features))

    return result

# %%
filename = file_name_dataset + " # " + file_name_feat_extract + " # " + file_name_data_aug

def create_feature_dataframe(dataframe):
    feature_list = []
    emotion_list = []

    for path, emotion in tqdm(zip(dataframe.Path, dataframe.Emotion), total=len(dataframe)):
        features = get_features(path)
        for elements in features:
            feature_list.append(elements)
            emotion_list.append(emotion)

    df = pd.DataFrame({'Emotion': emotion_list})
    df = pd.concat([df, pd.DataFrame(feature_list)], axis=1)
    df.to_csv(filename + '.csv', index=False)

    return df

# %%
file_exists = os.path.exists(filename + '.csv')

if file_exists:
    df = pd.read_csv(filename + '.csv')
else:
    df = create_feature_dataframe(hybrid_df)

df.head()
# Out:
# 100%|██████████| 11682/11682 [49:50<00:00,  3.91it/s]
#   Emotion           0          1          2          3         4          5
# 0   angry -396.986206  77.440536 -19.592791 -21.666689 -2.112756  10.075363  \
# 1   angry -234.736772  29.895229  -7.245361 -14.486003 -3.302411   1.666746
# 2   angry -426.047760  85.507446 -24.529745 -25.422735 -3.307063   9.809677
# 3   angry -399.662506  91.117203 -24.754166 -31.168427 -5.269245   9.252103
# 4   angry -416.410034  76.802986 -27.972919 -27.546099 -0.274697   7.172493
#
#            6         7         8  ...        30         31        32
# 0 -20.366707 -6.092449 -7.212283  ...  0.394722   5.111315  9.568739  \
# 1  -6.815186 -6.693529 -3.469599  ... -0.642680   1.134972  3.181533
# 2 -22.808109 -6.996094 -7.489722  ...  0.609156   5.465265  9.626096
# 3 -25.043127 -9.973287 -9.687059  ... -1.059549   4.778024  9.809315
# 4 -22.715885 -3.497336 -5.517387  ...  2.263394  11.962938  5.335030
#
#          33        34        35         36         37        38        39
# 0  5.454868  2.509964 -1.823907   4.868962   9.313924  2.089150 -1.906491
# 1  1.050743 -3.067794 -2.731035   2.962655   5.556666  2.404737 -3.127593
# 2  5.728091  2.343131 -1.868277   5.339450  11.257667  2.096411 -2.566468
# 3  6.002034  2.350018 -3.155525   4.814306  10.128219  2.874032 -2.716506
# 4  3.204281  0.528458  5.607913  10.100718   2.098508 -6.221065 -1.150442
#
# [5 rows x 41 columns]

# %%
X = df.iloc[:, 1:].values
Y = df['Emotion'].values

# %%
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state = 42, shuffle = True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((56073, 40), (56073, 7), (14019, 40), (14019, 7))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((56073, 40), (56073, 7), (14019, 40), (14019, 7))

# %%
X_train = x_train.reshape(x_train.shape[0] , x_train.shape[1] , 1)
X_test = x_test.reshape(x_test.shape[0] , x_test.shape[1] , 1)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((56073, 40, 1), (56073, 7), (14019, 40, 1), (14019, 7))

# %%
def create_model(model_type, epochs):
    model = Sequential()
    
    if model_type == 'GRU':
        model.add(GRU(128, input_shape=(X_train.shape[1],1), return_sequences=True))
        model.add(Dropout(0.3))
        model.add(GRU(128, return_sequences=True))
        model.add(GRU(128))
    elif model_type == 'LSTM':
        model.add(LSTM(128, input_shape=(X_train.shape[1],1), return_sequences=True))
        model.add(Dropout(0.3))
        model.add(LSTM(128, return_sequences=True))
        model.add(LSTM(128))
    elif model_type == 'BiGRU':
        model.add(Bidirectional(GRU(128, return_sequences=True), input_shape=(X_train.shape[1],1)))
        model.add(Dropout(0.3))
        model.add(Bidirectional(GRU(128, return_sequences=True)))
        model.add(Bidirectional(GRU(128)))
    elif model_type == 'BiLSTM':
        model.add(Bidirectional(LSTM(128, return_sequences=True), input_shape=(X_train.shape[1],1)))
        model.add(Dropout(0.3))
        model.add(Bidirectional(LSTM(128, return_sequences=True)))
        model.add(Bidirectional(LSTM(128)))
    elif model_type == 'CNN':
        model.add(Conv1D(64, 3, activation='relu', input_shape=(X_train.shape[1],1)))
        model.add(MaxPooling1D(2))
        model.add(Conv1D(128, 3, activation='relu'))
        model.add(MaxPooling1D(2))
        model.add(Conv1D(256, 3, activation='relu'))
        model.add(MaxPooling1D(2))
        model.add(Flatten())
        model.add(Dense(128, activation='relu'))
    else:
        raise ValueError("Invalid RNN model. Choose from 'GRU', 'LSTM', 'BiGRU', 'BiLSTM', or 'CNN'.")

    model.add(Dense(y_train.shape[1], activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, verbose=0, patience=3, min_lr=0.00001)
    checkpoint = ModelCheckpoint(model_type + " # " + filename + ' # Epoch 20.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    early_stop = EarlyStopping(monitor='val_accuracy', mode='auto', patience=10, restore_best_weights=True)

    history = model.fit(X_train, y_train, batch_size=64, epochs=epochs, validation_data=(X_test, y_test), callbacks=[reduce_lr, early_stop, checkpoint])

    model.save(model_type + ' # Epoch 20.h5')    
    
    return model, history

# %%
def evaluate_model(model):
    loss, accuracy = model.evaluate(X_test, y_test, verbose=1)

    print(f'Test Loss: {loss}')
    print(f'Test Accuracy: {accuracy}')

# %%
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

# %%
def simplify_label(label):
    if 'angry' in label:
        return 'angry'
    elif 'disgust' in label:
        return 'disgust'
    elif 'fear' in label:
        return 'fear'
    elif 'happy' in label:
        return 'happy'
    elif 'sad' in label:
        return 'sad'
    elif 'surprise' in label:
        return 'surprise'
    elif 'neutral' in label:
        return 'neutral'
    else:
        return label

# %%
def create_model_summary(model_type):
    test_prediction = model_type.predict(X_test)

    prediction_actual_df = pd.DataFrame({
    'Predicted': encoder.inverse_transform(test_prediction).flatten(),
    'Actual': encoder.inverse_transform(y_test).flatten()
    })

    prediction_actual_df.head()

    modified_df = prediction_actual_df.copy()
    modified_df['Actual'] = modified_df['Actual'].apply(simplify_label)
    modified_df['Predicted'] = modified_df['Predicted'].apply(simplify_label)

    res_mat = confusion_matrix(modified_df['Actual'], modified_df['Predicted'])
    plt.figure(figsize=(10, 7))
    sns.heatmap(res_mat, annot=True, fmt='d', cmap='Blues',
                xticklabels=modified_df['Predicted'].unique(), 
                yticklabels=modified_df['Actual'].unique())
    plt.xlabel('Predicted Labels')
    plt.ylabel('Actual Labels')
    plt.title('Confusion Matrix')
    plt.show()

    print(classification_report(modified_df['Actual'], modified_df['Predicted']))

    accuracy = accuracy_score(modified_df['Actual'], modified_df['Predicted'])
    print(f"Accuracy: {round(accuracy * 100, 2)}%")

# %%
model_lstm, history_lstm = create_model("LSTM", 20)
model_gru, history_gru = create_model("GRU", 20)
model_bilstm, history_bilstm = create_model("BiLSTM", 20)
model_bigru, history_bigru = create_model("BiGRU", 20)
model_cnn, history_cnn = create_model("CNN", 20)
# Out:
# Epoch 1/20
# 874/877 [============================>.] - ETA: 0s - loss: 1.3166 - accuracy: 0.4653
# Epoch 1: val_accuracy improved from -inf to 0.53249, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 30s 25ms/step - loss: 1.3165 - accuracy: 0.4653 - val_loss: 1.1764 - val_accuracy: 0.5325 - lr: 0.0010
# Epoch 2/20
# 876/877 [============================>.] - ETA: 0s - loss: 1.1605 - accuracy: 0.5304
# Epoch 2: val_accuracy improved from 0.53249 to 0.55361, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 21s 24ms/step - loss: 1.1604 - accuracy: 0.5304 - val_loss: 1.1136 - val_accuracy: 0.5536 - lr: 0.0010
# Epoch 3/20
# 876/877 [============================>.] - ETA: 0s - loss: 1.1077 - accuracy: 0.5533
# Epoch 3: val_accuracy improved from 0.55361 to 0.56152, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 20s 23ms/step - loss: 1.1077 - accuracy: 0.5533 - val_loss: 1.0972 - val_accuracy: 0.5615 - lr: 0.0010
# Epoch 4/20
# 876/877 [============================>.] - ETA: 0s - loss: 1.0636 - accuracy: 0.5727
# Epoch 4: val_accuracy improved from 0.56152 to 0.58742, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 22s 25ms/step - loss: 1.0635 - accuracy: 0.5727 - val_loss: 1.0298 - val_accuracy: 0.5874 - lr: 0.0010
# Epoch 5/20
# 874/877 [============================>.] - ETA: 0s - loss: 1.0185 - accuracy: 0.5927
# Epoch 5: val_accuracy improved from 0.58742 to 0.59113, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 19s 21ms/step - loss: 1.0186 - accuracy: 0.5926 - val_loss: 1.0351 - val_accuracy: 0.5911 - lr: 0.0010
# Epoch 6/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.9789 - accuracy: 0.6072
# Epoch 6: val_accuracy improved from 0.59113 to 0.60375, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 17s 19ms/step - loss: 0.9790 - accuracy: 0.6072 - val_loss: 0.9846 - val_accuracy: 0.6038 - lr: 0.0010
# Epoch 7/20
# 877/877 [==============================] - ETA: 0s - loss: 0.9358 - accuracy: 0.6281
# Epoch 7: val_accuracy improved from 0.60375 to 0.62608, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 22s 25ms/step - loss: 0.9358 - accuracy: 0.6281 - val_loss: 0.9432 - val_accuracy: 0.6261 - lr: 0.0010
# Epoch 8/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.8901 - accuracy: 0.6479
# Epoch 8: val_accuracy improved from 0.62608 to 0.64306, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 19s 22ms/step - loss: 0.8901 - accuracy: 0.6479 - val_loss: 0.8921 - val_accuracy: 0.6431 - lr: 0.0010
# Epoch 9/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.8374 - accuracy: 0.6717
# Epoch 9: val_accuracy improved from 0.64306 to 0.65297, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 19s 22ms/step - loss: 0.8375 - accuracy: 0.6716 - val_loss: 0.8763 - val_accuracy: 0.6530 - lr: 0.0010
# Epoch 10/20
# 877/877 [==============================] - ETA: 0s - loss: 0.7819 - accuracy: 0.6961
# Epoch 10: val_accuracy improved from 0.65297 to 0.66360, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 20s 22ms/step - loss: 0.7819 - accuracy: 0.6961 - val_loss: 0.8460 - val_accuracy: 0.6636 - lr: 0.0010
# Epoch 11/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.7344 - accuracy: 0.7185
# Epoch 11: val_accuracy improved from 0.66360 to 0.67722, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 19s 22ms/step - loss: 0.7344 - accuracy: 0.7185 - val_loss: 0.8260 - val_accuracy: 0.6772 - lr: 0.0010
# Epoch 12/20
# 874/877 [============================>.] - ETA: 0s - loss: 0.6814 - accuracy: 0.7408
# Epoch 12: val_accuracy improved from 0.67722 to 0.70897, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 17s 19ms/step - loss: 0.6813 - accuracy: 0.7409 - val_loss: 0.7620 - val_accuracy: 0.7090 - lr: 0.0010
# Epoch 13/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.6326 - accuracy: 0.7604
# Epoch 13: val_accuracy improved from 0.70897 to 0.71082, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 18s 20ms/step - loss: 0.6327 - accuracy: 0.7604 - val_loss: 0.7604 - val_accuracy: 0.7108 - lr: 0.0010
# Epoch 14/20
# 874/877 [============================>.] - ETA: 0s - loss: 0.5869 - accuracy: 0.7791
# Epoch 14: val_accuracy improved from 0.71082 to 0.73265, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 16s 18ms/step - loss: 0.5867 - accuracy: 0.7791 - val_loss: 0.7068 - val_accuracy: 0.7326 - lr: 0.0010
# Epoch 15/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.5456 - accuracy: 0.7969
# Epoch 15: val_accuracy improved from 0.73265 to 0.74756, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 17s 19ms/step - loss: 0.5455 - accuracy: 0.7969 - val_loss: 0.6799 - val_accuracy: 0.7476 - lr: 0.0010
# Epoch 16/20
# 877/877 [==============================] - ETA: 0s - loss: 0.4976 - accuracy: 0.8161
# Epoch 16: val_accuracy improved from 0.74756 to 0.76118, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 16s 18ms/step - loss: 0.4976 - accuracy: 0.8161 - val_loss: 0.6731 - val_accuracy: 0.7612 - lr: 0.0010
# Epoch 17/20
# 874/877 [============================>.] - ETA: 0s - loss: 0.4657 - accuracy: 0.8293
# Epoch 17: val_accuracy did not improve from 0.76118
# 877/877 [==============================] - 17s 19ms/step - loss: 0.4655 - accuracy: 0.8293 - val_loss: 0.6803 - val_accuracy: 0.7535 - lr: 0.0010
# Epoch 18/20
# 877/877 [==============================] - ETA: 0s - loss: 0.4295 - accuracy: 0.8458
# Epoch 18: val_accuracy improved from 0.76118 to 0.76760, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 21s 24ms/step - loss: 0.4295 - accuracy: 0.8458 - val_loss: 0.6557 - val_accuracy: 0.7676 - lr: 0.0010
# Epoch 19/20
# 877/877 [==============================] - ETA: 0s - loss: 0.3932 - accuracy: 0.8581
# Epoch 19: val_accuracy improved from 0.76760 to 0.78251, saving model to LSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 16s 18ms/step - loss: 0.3932 - accuracy: 0.8581 - val_loss: 0.6264 - val_accuracy: 0.7825 - lr: 0.0010
# Epoch 20/20
# 877/877 [==============================] - ETA: 0s - loss: 0.3705 - accuracy: 0.8670
# Epoch 20: val_accuracy did not improve from 0.78251
# 877/877 [==============================] - 15s 17ms/step - loss: 0.3705 - accuracy: 0.8670 - val_loss: 0.6411 - val_accuracy: 0.7822 - lr: 0.0010
# Epoch 1/20
# 875/877 [============================>.] - ETA: 0s - loss: 1.3863 - accuracy: 0.4287
# Epoch 1: val_accuracy improved from -inf to 0.49426, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 19s 18ms/step - loss: 1.3861 - accuracy: 0.4289 - val_loss: 1.2440 - val_accuracy: 0.4943 - lr: 0.0010
# Epoch 2/20
# 876/877 [============================>.] - ETA: 0s - loss: 1.1988 - accuracy: 0.5120
# Epoch 2: val_accuracy improved from 0.49426 to 0.54490, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 15s 17ms/step - loss: 1.1987 - accuracy: 0.5120 - val_loss: 1.1261 - val_accuracy: 0.5449 - lr: 0.0010
# Epoch 3/20
# 874/877 [============================>.] - ETA: 0s - loss: 1.1251 - accuracy: 0.5454
# Epoch 3: val_accuracy improved from 0.54490 to 0.55696, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 14s 16ms/step - loss: 1.1250 - accuracy: 0.5454 - val_loss: 1.1092 - val_accuracy: 0.5570 - lr: 0.0010
# Epoch 4/20
# 875/877 [============================>.] - ETA: 0s - loss: 1.0723 - accuracy: 0.5662
# Epoch 4: val_accuracy improved from 0.55696 to 0.56873, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 15s 17ms/step - loss: 1.0723 - accuracy: 0.5663 - val_loss: 1.0751 - val_accuracy: 0.5687 - lr: 0.0010
# Epoch 5/20
# 876/877 [============================>.] - ETA: 0s - loss: 1.0258 - accuracy: 0.5908
# Epoch 5: val_accuracy improved from 0.56873 to 0.60104, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 15s 17ms/step - loss: 1.0258 - accuracy: 0.5908 - val_loss: 0.9992 - val_accuracy: 0.6010 - lr: 0.0010
# Epoch 6/20
# 874/877 [============================>.] - ETA: 0s - loss: 0.9863 - accuracy: 0.6057
# Epoch 6: val_accuracy improved from 0.60104 to 0.61089, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 15s 17ms/step - loss: 0.9860 - accuracy: 0.6058 - val_loss: 0.9817 - val_accuracy: 0.6109 - lr: 0.0010
# Epoch 7/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.9398 - accuracy: 0.6288
# Epoch 7: val_accuracy improved from 0.61089 to 0.62472, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 15s 17ms/step - loss: 0.9399 - accuracy: 0.6287 - val_loss: 0.9451 - val_accuracy: 0.6247 - lr: 0.0010
# Epoch 8/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.8948 - accuracy: 0.6461
# Epoch 8: val_accuracy improved from 0.62472 to 0.63771, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 15s 17ms/step - loss: 0.8948 - accuracy: 0.6462 - val_loss: 0.9205 - val_accuracy: 0.6377 - lr: 0.0010
# Epoch 9/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.8446 - accuracy: 0.6691
# Epoch 9: val_accuracy improved from 0.63771 to 0.65547, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 15s 17ms/step - loss: 0.8446 - accuracy: 0.6692 - val_loss: 0.8715 - val_accuracy: 0.6555 - lr: 0.0010
# Epoch 10/20
# 877/877 [==============================] - ETA: 0s - loss: 0.7986 - accuracy: 0.6885
# Epoch 10: val_accuracy improved from 0.65547 to 0.67680, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 15s 17ms/step - loss: 0.7986 - accuracy: 0.6885 - val_loss: 0.8275 - val_accuracy: 0.6768 - lr: 0.0010
# Epoch 11/20
# 877/877 [==============================] - ETA: 0s - loss: 0.7486 - accuracy: 0.7119
# Epoch 11: val_accuracy improved from 0.67680 to 0.67979, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 15s 17ms/step - loss: 0.7486 - accuracy: 0.7119 - val_loss: 0.8267 - val_accuracy: 0.6798 - lr: 0.0010
# Epoch 12/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.7026 - accuracy: 0.7305
# Epoch 12: val_accuracy improved from 0.67979 to 0.70290, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 14s 16ms/step - loss: 0.7027 - accuracy: 0.7304 - val_loss: 0.7727 - val_accuracy: 0.7029 - lr: 0.0010
# Epoch 13/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.6560 - accuracy: 0.7500
# Epoch 13: val_accuracy did not improve from 0.70290
# 877/877 [==============================] - 18s 20ms/step - loss: 0.6560 - accuracy: 0.7499 - val_loss: 0.7787 - val_accuracy: 0.6973 - lr: 0.0010
# Epoch 14/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.6126 - accuracy: 0.7692
# Epoch 14: val_accuracy improved from 0.70290 to 0.73079, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 16s 19ms/step - loss: 0.6126 - accuracy: 0.7692 - val_loss: 0.7178 - val_accuracy: 0.7308 - lr: 0.0010
# Epoch 15/20
# 877/877 [==============================] - ETA: 0s - loss: 0.5705 - accuracy: 0.7869
# Epoch 15: val_accuracy improved from 0.73079 to 0.73101, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 15s 17ms/step - loss: 0.5705 - accuracy: 0.7869 - val_loss: 0.7152 - val_accuracy: 0.7310 - lr: 0.0010
# Epoch 16/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.5319 - accuracy: 0.8030
# Epoch 16: val_accuracy improved from 0.73101 to 0.73821, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 17s 19ms/step - loss: 0.5318 - accuracy: 0.8030 - val_loss: 0.7035 - val_accuracy: 0.7382 - lr: 0.0010
# Epoch 17/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.4957 - accuracy: 0.8166
# Epoch 17: val_accuracy improved from 0.73821 to 0.76361, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 17s 20ms/step - loss: 0.4957 - accuracy: 0.8166 - val_loss: 0.6494 - val_accuracy: 0.7636 - lr: 0.0010
# Epoch 18/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.4620 - accuracy: 0.8319
# Epoch 18: val_accuracy improved from 0.76361 to 0.76439, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 16s 18ms/step - loss: 0.4620 - accuracy: 0.8319 - val_loss: 0.6513 - val_accuracy: 0.7644 - lr: 0.0010
# Epoch 19/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.4349 - accuracy: 0.8416
# Epoch 19: val_accuracy improved from 0.76439 to 0.76475, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 22s 26ms/step - loss: 0.4349 - accuracy: 0.8416 - val_loss: 0.6564 - val_accuracy: 0.7647 - lr: 0.0010
# Epoch 20/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.4088 - accuracy: 0.8519
# Epoch 20: val_accuracy improved from 0.76475 to 0.77958, saving model to GRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 16s 18ms/step - loss: 0.4087 - accuracy: 0.8519 - val_loss: 0.6278 - val_accuracy: 0.7796 - lr: 0.0010
# Epoch 1/20
# 877/877 [==============================] - ETA: 0s - loss: 1.2403 - accuracy: 0.5018
# Epoch 1: val_accuracy improved from -inf to 0.54119, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 42s 40ms/step - loss: 1.2403 - accuracy: 0.5018 - val_loss: 1.1284 - val_accuracy: 0.5412 - lr: 0.0010
# Epoch 2/20
# 877/877 [==============================] - ETA: 0s - loss: 1.0944 - accuracy: 0.5603
# Epoch 2: val_accuracy improved from 0.54119 to 0.57529, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 31s 35ms/step - loss: 1.0944 - accuracy: 0.5603 - val_loss: 1.0633 - val_accuracy: 0.5753 - lr: 0.0010
# Epoch 3/20
# 876/877 [============================>.] - ETA: 0s - loss: 1.0251 - accuracy: 0.5888
# Epoch 3: val_accuracy improved from 0.57529 to 0.60489, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 32s 36ms/step - loss: 1.0251 - accuracy: 0.5888 - val_loss: 0.9943 - val_accuracy: 0.6049 - lr: 0.0010
# Epoch 4/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.9602 - accuracy: 0.6159
# Epoch 4: val_accuracy improved from 0.60489 to 0.62437, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 31s 36ms/step - loss: 0.9602 - accuracy: 0.6159 - val_loss: 0.9418 - val_accuracy: 0.6244 - lr: 0.0010
# Epoch 5/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.8941 - accuracy: 0.6440
# Epoch 5: val_accuracy improved from 0.62437 to 0.65090, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 32s 37ms/step - loss: 0.8941 - accuracy: 0.6440 - val_loss: 0.8878 - val_accuracy: 0.6509 - lr: 0.0010
# Epoch 6/20
# 877/877 [==============================] - ETA: 0s - loss: 0.8182 - accuracy: 0.6793
# Epoch 6: val_accuracy improved from 0.65090 to 0.66602, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 32s 37ms/step - loss: 0.8182 - accuracy: 0.6793 - val_loss: 0.8390 - val_accuracy: 0.6660 - lr: 0.0010
# Epoch 7/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.7384 - accuracy: 0.7126
# Epoch 7: val_accuracy improved from 0.66602 to 0.69199, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 30s 35ms/step - loss: 0.7384 - accuracy: 0.7126 - val_loss: 0.7911 - val_accuracy: 0.6920 - lr: 0.0010
# Epoch 8/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.6531 - accuracy: 0.7506
# Epoch 8: val_accuracy improved from 0.69199 to 0.72815, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 34s 39ms/step - loss: 0.6530 - accuracy: 0.7506 - val_loss: 0.7100 - val_accuracy: 0.7282 - lr: 0.0010
# Epoch 9/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.5676 - accuracy: 0.7862
# Epoch 9: val_accuracy improved from 0.72815 to 0.74684, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 37s 42ms/step - loss: 0.5676 - accuracy: 0.7863 - val_loss: 0.6667 - val_accuracy: 0.7468 - lr: 0.0010
# Epoch 10/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.4909 - accuracy: 0.8184
# Epoch 10: val_accuracy improved from 0.74684 to 0.76689, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 42s 47ms/step - loss: 0.4909 - accuracy: 0.8183 - val_loss: 0.6216 - val_accuracy: 0.7669 - lr: 0.0010
# Epoch 11/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.4218 - accuracy: 0.8466
# Epoch 11: val_accuracy improved from 0.76689 to 0.78729, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 40s 46ms/step - loss: 0.4218 - accuracy: 0.8466 - val_loss: 0.5824 - val_accuracy: 0.7873 - lr: 0.0010
# Epoch 12/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.3565 - accuracy: 0.8704
# Epoch 12: val_accuracy improved from 0.78729 to 0.79877, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 33s 38ms/step - loss: 0.3565 - accuracy: 0.8704 - val_loss: 0.5670 - val_accuracy: 0.7988 - lr: 0.0010
# Epoch 13/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.3098 - accuracy: 0.8888
# Epoch 13: val_accuracy improved from 0.79877 to 0.80434, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 35s 40ms/step - loss: 0.3098 - accuracy: 0.8888 - val_loss: 0.5636 - val_accuracy: 0.8043 - lr: 0.0010
# Epoch 14/20
# 877/877 [==============================] - ETA: 0s - loss: 0.2611 - accuracy: 0.9085
# Epoch 14: val_accuracy improved from 0.80434 to 0.81867, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 34s 38ms/step - loss: 0.2611 - accuracy: 0.9085 - val_loss: 0.5400 - val_accuracy: 0.8187 - lr: 0.0010
# Epoch 15/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.2297 - accuracy: 0.9194
# Epoch 15: val_accuracy improved from 0.81867 to 0.81932, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 35s 40ms/step - loss: 0.2298 - accuracy: 0.9194 - val_loss: 0.5484 - val_accuracy: 0.8193 - lr: 0.0010
# Epoch 16/20
# 877/877 [==============================] - ETA: 0s - loss: 0.2058 - accuracy: 0.9273
# Epoch 16: val_accuracy improved from 0.81932 to 0.82859, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 35s 40ms/step - loss: 0.2058 - accuracy: 0.9273 - val_loss: 0.5345 - val_accuracy: 0.8286 - lr: 0.0010
# Epoch 17/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.1758 - accuracy: 0.9399
# Epoch 17: val_accuracy improved from 0.82859 to 0.83280, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 34s 39ms/step - loss: 0.1759 - accuracy: 0.9399 - val_loss: 0.5350 - val_accuracy: 0.8328 - lr: 0.0010
# Epoch 18/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.1672 - accuracy: 0.9417
# Epoch 18: val_accuracy improved from 0.83280 to 0.83458, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 37s 42ms/step - loss: 0.1672 - accuracy: 0.9417 - val_loss: 0.5504 - val_accuracy: 0.8346 - lr: 0.0010
# Epoch 19/20
# 877/877 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9467
# Epoch 19: val_accuracy improved from 0.83458 to 0.84057, saving model to BiLSTM # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 41s 47ms/step - loss: 0.1530 - accuracy: 0.9467 - val_loss: 0.5341 - val_accuracy: 0.8406 - lr: 0.0010
# Epoch 20/20
# 877/877 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.9524
# Epoch 20: val_accuracy did not improve from 0.84057
# 877/877 [==============================] - 42s 48ms/step - loss: 0.1362 - accuracy: 0.9524 - val_loss: 0.5470 - val_accuracy: 0.8390 - lr: 0.0010
# Epoch 1/20
# 877/877 [==============================] - ETA: 0s - loss: 1.2344 - accuracy: 0.5054
# Epoch 1: val_accuracy improved from -inf to 0.54219, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 45s 41ms/step - loss: 1.2344 - accuracy: 0.5054 - val_loss: 1.1355 - val_accuracy: 0.5422 - lr: 0.0010
# Epoch 2/20
# 877/877 [==============================] - ETA: 0s - loss: 1.0818 - accuracy: 0.5682
# Epoch 2: val_accuracy improved from 0.54219 to 0.57301, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 33s 38ms/step - loss: 1.0818 - accuracy: 0.5682 - val_loss: 1.0428 - val_accuracy: 0.5730 - lr: 0.0010
# Epoch 3/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.9948 - accuracy: 0.6068
# Epoch 3: val_accuracy improved from 0.57301 to 0.61759, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 33s 38ms/step - loss: 0.9948 - accuracy: 0.6068 - val_loss: 0.9660 - val_accuracy: 0.6176 - lr: 0.0010
# Epoch 4/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.9016 - accuracy: 0.6480
# Epoch 4: val_accuracy improved from 0.61759 to 0.65511, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 30s 34ms/step - loss: 0.9017 - accuracy: 0.6480 - val_loss: 0.8800 - val_accuracy: 0.6551 - lr: 0.0010
# Epoch 5/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.7961 - accuracy: 0.6934
# Epoch 5: val_accuracy improved from 0.65511 to 0.69506, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 29s 33ms/step - loss: 0.7960 - accuracy: 0.6934 - val_loss: 0.8012 - val_accuracy: 0.6951 - lr: 0.0010
# Epoch 6/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.6846 - accuracy: 0.7442
# Epoch 6: val_accuracy improved from 0.69506 to 0.72730, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 30s 34ms/step - loss: 0.6847 - accuracy: 0.7441 - val_loss: 0.7188 - val_accuracy: 0.7273 - lr: 0.0010
# Epoch 7/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.5713 - accuracy: 0.7890
# Epoch 7: val_accuracy improved from 0.72730 to 0.75105, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 29s 33ms/step - loss: 0.5713 - accuracy: 0.7889 - val_loss: 0.6715 - val_accuracy: 0.7511 - lr: 0.0010
# Epoch 8/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.4729 - accuracy: 0.8292
# Epoch 8: val_accuracy improved from 0.75105 to 0.78593, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 30s 34ms/step - loss: 0.4729 - accuracy: 0.8292 - val_loss: 0.6069 - val_accuracy: 0.7859 - lr: 0.0010
# Epoch 9/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.3831 - accuracy: 0.8640
# Epoch 9: val_accuracy improved from 0.78593 to 0.79442, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 30s 34ms/step - loss: 0.3831 - accuracy: 0.8640 - val_loss: 0.5862 - val_accuracy: 0.7944 - lr: 0.0010
# Epoch 10/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.3145 - accuracy: 0.8889
# Epoch 10: val_accuracy improved from 0.79442 to 0.81054, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 30s 35ms/step - loss: 0.3144 - accuracy: 0.8890 - val_loss: 0.5559 - val_accuracy: 0.8105 - lr: 0.0010
# Epoch 11/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.2580 - accuracy: 0.9116
# Epoch 11: val_accuracy did not improve from 0.81054
# 877/877 [==============================] - 30s 35ms/step - loss: 0.2582 - accuracy: 0.9116 - val_loss: 0.5821 - val_accuracy: 0.8092 - lr: 0.0010
# Epoch 12/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.2231 - accuracy: 0.9231
# Epoch 12: val_accuracy improved from 0.81054 to 0.82039, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 32s 36ms/step - loss: 0.2230 - accuracy: 0.9232 - val_loss: 0.5676 - val_accuracy: 0.8204 - lr: 0.0010
# Epoch 13/20
# 877/877 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9355
# Epoch 13: val_accuracy improved from 0.82039 to 0.82410, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 30s 34ms/step - loss: 0.1889 - accuracy: 0.9355 - val_loss: 0.5769 - val_accuracy: 0.8241 - lr: 0.0010
# Epoch 14/20
# 877/877 [==============================] - ETA: 0s - loss: 0.1639 - accuracy: 0.9437
# Epoch 14: val_accuracy improved from 0.82410 to 0.83501, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 34s 38ms/step - loss: 0.1639 - accuracy: 0.9437 - val_loss: 0.5689 - val_accuracy: 0.8350 - lr: 0.0010
# Epoch 15/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.1492 - accuracy: 0.9490
# Epoch 15: val_accuracy did not improve from 0.83501
# 877/877 [==============================] - 32s 36ms/step - loss: 0.1492 - accuracy: 0.9489 - val_loss: 0.5925 - val_accuracy: 0.8302 - lr: 0.0010
# Epoch 16/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.1393 - accuracy: 0.9518
# Epoch 16: val_accuracy did not improve from 0.83501
# 877/877 [==============================] - 30s 34ms/step - loss: 0.1393 - accuracy: 0.9517 - val_loss: 0.6010 - val_accuracy: 0.8332 - lr: 0.0010
# Epoch 17/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.1251 - accuracy: 0.9570
# Epoch 17: val_accuracy did not improve from 0.83501
# 877/877 [==============================] - 28s 32ms/step - loss: 0.1251 - accuracy: 0.9571 - val_loss: 0.6212 - val_accuracy: 0.8307 - lr: 0.0010
# Epoch 18/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.1087 - accuracy: 0.9624
# Epoch 18: val_accuracy improved from 0.83501 to 0.83551, saving model to BiGRU # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 29s 33ms/step - loss: 0.1087 - accuracy: 0.9624 - val_loss: 0.6132 - val_accuracy: 0.8355 - lr: 0.0010
# Epoch 19/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.1187 - accuracy: 0.9580
# Epoch 19: val_accuracy did not improve from 0.83551
# 877/877 [==============================] - 28s 32ms/step - loss: 0.1186 - accuracy: 0.9581 - val_loss: 0.6269 - val_accuracy: 0.8342 - lr: 0.0010
# Epoch 20/20
# 877/877 [==============================] - ETA: 0s - loss: 0.1058 - accuracy: 0.9641
# Epoch 20: val_accuracy did not improve from 0.83551
# 877/877 [==============================] - 34s 39ms/step - loss: 0.1058 - accuracy: 0.9641 - val_loss: 0.6572 - val_accuracy: 0.8323 - lr: 0.0010
# Epoch 1/20
# 877/877 [==============================] - ETA: 0s - loss: 1.1968 - accuracy: 0.5252
# Epoch 1: val_accuracy improved from -inf to 0.58806, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 11s 8ms/step - loss: 1.1968 - accuracy: 0.5252 - val_loss: 1.0454 - val_accuracy: 0.5881 - lr: 0.0010
# Epoch 2/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.9669 - accuracy: 0.6193
# Epoch 2: val_accuracy improved from 0.58806 to 0.64363, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 7s 8ms/step - loss: 0.9669 - accuracy: 0.6193 - val_loss: 0.9175 - val_accuracy: 0.6436 - lr: 0.0010
# Epoch 3/20
# 872/877 [============================>.] - ETA: 0s - loss: 0.8378 - accuracy: 0.6739
# Epoch 3: val_accuracy improved from 0.64363 to 0.68700, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 7s 8ms/step - loss: 0.8374 - accuracy: 0.6741 - val_loss: 0.8166 - val_accuracy: 0.6870 - lr: 0.0010
# Epoch 4/20
# 873/877 [============================>.] - ETA: 0s - loss: 0.7251 - accuracy: 0.7210
# Epoch 4: val_accuracy improved from 0.68700 to 0.71125, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 7s 8ms/step - loss: 0.7249 - accuracy: 0.7210 - val_loss: 0.7545 - val_accuracy: 0.7112 - lr: 0.0010
# Epoch 5/20
# 874/877 [============================>.] - ETA: 0s - loss: 0.6212 - accuracy: 0.7636
# Epoch 5: val_accuracy improved from 0.71125 to 0.73821, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 7s 8ms/step - loss: 0.6210 - accuracy: 0.7637 - val_loss: 0.6947 - val_accuracy: 0.7382 - lr: 0.0010
# Epoch 6/20
# 877/877 [==============================] - ETA: 0s - loss: 0.5312 - accuracy: 0.8008
# Epoch 6: val_accuracy improved from 0.73821 to 0.75712, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 7s 8ms/step - loss: 0.5312 - accuracy: 0.8008 - val_loss: 0.6677 - val_accuracy: 0.7571 - lr: 0.0010
# Epoch 7/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.4509 - accuracy: 0.8317
# Epoch 7: val_accuracy improved from 0.75712 to 0.77103, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 7s 8ms/step - loss: 0.4509 - accuracy: 0.8317 - val_loss: 0.6262 - val_accuracy: 0.7710 - lr: 0.0010
# Epoch 8/20
# 877/877 [==============================] - ETA: 0s - loss: 0.3927 - accuracy: 0.8560
# Epoch 8: val_accuracy improved from 0.77103 to 0.79742, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 7s 7ms/step - loss: 0.3927 - accuracy: 0.8560 - val_loss: 0.5820 - val_accuracy: 0.7974 - lr: 0.0010
# Epoch 9/20
# 873/877 [============================>.] - ETA: 0s - loss: 0.3393 - accuracy: 0.8765
# Epoch 9: val_accuracy improved from 0.79742 to 0.80919, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 7s 7ms/step - loss: 0.3389 - accuracy: 0.8767 - val_loss: 0.5668 - val_accuracy: 0.8092 - lr: 0.0010
# Epoch 10/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.2922 - accuracy: 0.8925
# Epoch 10: val_accuracy improved from 0.80919 to 0.81204, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 6s 7ms/step - loss: 0.2922 - accuracy: 0.8925 - val_loss: 0.5783 - val_accuracy: 0.8120 - lr: 0.0010
# Epoch 11/20
# 869/877 [============================>.] - ETA: 0s - loss: 0.2592 - accuracy: 0.9048
# Epoch 11: val_accuracy improved from 0.81204 to 0.82089, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 7s 8ms/step - loss: 0.2597 - accuracy: 0.9045 - val_loss: 0.5739 - val_accuracy: 0.8209 - lr: 0.0010
# Epoch 12/20
# 877/877 [==============================] - ETA: 0s - loss: 0.2360 - accuracy: 0.9140
# Epoch 12: val_accuracy improved from 0.82089 to 0.82752, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 7s 8ms/step - loss: 0.2360 - accuracy: 0.9140 - val_loss: 0.5834 - val_accuracy: 0.8275 - lr: 0.0010
# Epoch 13/20
# 874/877 [============================>.] - ETA: 0s - loss: 0.2019 - accuracy: 0.9252
# Epoch 13: val_accuracy did not improve from 0.82752
# 877/877 [==============================] - 6s 7ms/step - loss: 0.2020 - accuracy: 0.9252 - val_loss: 0.6258 - val_accuracy: 0.8182 - lr: 0.0010
# Epoch 14/20
# 873/877 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9284
# Epoch 14: val_accuracy did not improve from 0.82752
# 877/877 [==============================] - 7s 8ms/step - loss: 0.1993 - accuracy: 0.9283 - val_loss: 0.6525 - val_accuracy: 0.8254 - lr: 0.0010
# Epoch 15/20
# 874/877 [============================>.] - ETA: 0s - loss: 0.1710 - accuracy: 0.9378
# Epoch 15: val_accuracy improved from 0.82752 to 0.82838, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 8s 9ms/step - loss: 0.1709 - accuracy: 0.9378 - val_loss: 0.6389 - val_accuracy: 0.8284 - lr: 0.0010
# Epoch 16/20
# 870/877 [============================>.] - ETA: 0s - loss: 0.1618 - accuracy: 0.9408
# Epoch 16: val_accuracy improved from 0.82838 to 0.83223, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 7s 8ms/step - loss: 0.1619 - accuracy: 0.9408 - val_loss: 0.6621 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 17/20
# 875/877 [============================>.] - ETA: 0s - loss: 0.1529 - accuracy: 0.9450
# Epoch 17: val_accuracy improved from 0.83223 to 0.83258, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 8s 9ms/step - loss: 0.1528 - accuracy: 0.9450 - val_loss: 0.6741 - val_accuracy: 0.8326 - lr: 0.0010
# Epoch 18/20
# 876/877 [============================>.] - ETA: 0s - loss: 0.1367 - accuracy: 0.9504
# Epoch 18: val_accuracy did not improve from 0.83258
# 877/877 [==============================] - 8s 10ms/step - loss: 0.1367 - accuracy: 0.9504 - val_loss: 0.7181 - val_accuracy: 0.8326 - lr: 0.0010
# Epoch 19/20
# 870/877 [============================>.] - ETA: 0s - loss: 0.1461 - accuracy: 0.9485
# Epoch 19: val_accuracy improved from 0.83258 to 0.83993, saving model to CNN # CREMAD RAVDESS TESS # MFCC Mean 40 # Noise 0.04 & Low Speed 0.75 & High Speed 1.25 & Pitch Shift 0.7 & Shift (-5, 5) # Epoch 20.h5
# 877/877 [==============================] - 8s 9ms/step - loss: 0.1462 - accuracy: 0.9484 - val_loss: 0.7238 - val_accuracy: 0.8399 - lr: 0.0010
# Epoch 20/20
# 871/877 [============================>.] - ETA: 0s - loss: 0.1165 - accuracy: 0.9587
# Epoch 20: val_accuracy did not improve from 0.83993
# 877/877 [==============================] - 7s 8ms/step - loss: 0.1169 - accuracy: 0.9586 - val_loss: 0.7627 - val_accuracy: 0.8297 - lr: 0.0010

# %%
evaluate_model(model_gru)
plot_history(history_gru)
# Out:
# 439/439 [==============================] - 3s 7ms/step - loss: 0.6278 - accuracy: 0.7796
# Test Loss: 0.6277790069580078
# Test Accuracy: 0.7795848250389099

# %%
create_model_summary(model_gru)
# Out:
# 439/439 [==============================] - 4s 6ms/step
#               precision    recall  f1-score   support
#
#        angry       0.87      0.85      0.86      2232
#      disgust       0.65      0.80      0.71      2162
#         fear       0.80      0.69      0.75      2256
#        happy       0.77      0.76      0.76      2223
#      neutral       0.80      0.75      0.77      2173
#          sad       0.78      0.78      0.78      2279
#     surprise       0.92      0.95      0.94       694
#
#     accuracy                           0.78     14019
#    macro avg       0.80      0.80      0.80     14019
# weighted avg       0.79      0.78      0.78     14019
#
# Accuracy: 77.96%

# %%
evaluate_model(model_lstm)
plot_history(history_lstm)
# Out:
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6411 - accuracy: 0.7822
# Test Loss: 0.6410723328590393
# Test Accuracy: 0.7821527719497681

# %%
create_model_summary(model_lstm)
# Out:
# 439/439 [==============================] - 5s 9ms/step
#               precision    recall  f1-score   support
#
#        angry       0.82      0.89      0.85      2232
#      disgust       0.68      0.75      0.71      2162
#         fear       0.78      0.71      0.75      2256
#        happy       0.80      0.74      0.77      2223
#      neutral       0.77      0.77      0.77      2173
#          sad       0.78      0.79      0.79      2279
#     surprise       0.95      0.94      0.94       694
#
#     accuracy                           0.78     14019
#    macro avg       0.80      0.80      0.80     14019
# weighted avg       0.78      0.78      0.78     14019
#
# Accuracy: 78.22%

# %%
evaluate_model(model_bilstm)
plot_history(history_bilstm)
# Out:
# 439/439 [==============================] - 6s 14ms/step - loss: 0.5470 - accuracy: 0.8390
# Test Loss: 0.5470039248466492
# Test Accuracy: 0.8390042185783386

# %%
create_model_summary(model_bilstm)
# Out:
# 439/439 [==============================] - 7s 13ms/step
#               precision    recall  f1-score   support
#
#        angry       0.91      0.88      0.89      2232
#      disgust       0.78      0.78      0.78      2162
#         fear       0.82      0.81      0.82      2256
#        happy       0.84      0.84      0.84      2223
#      neutral       0.82      0.85      0.83      2173
#          sad       0.83      0.84      0.84      2279
#     surprise       0.95      0.94      0.95       694
#
#     accuracy                           0.84     14019
#    macro avg       0.85      0.85      0.85     14019
# weighted avg       0.84      0.84      0.84     14019
#
# Accuracy: 83.9%

# %%
evaluate_model(model_bigru)
plot_history(history_bigru)
# Out:
# 439/439 [==============================] - 5s 10ms/step - loss: 0.6572 - accuracy: 0.8323
# Test Loss: 0.6571740508079529
# Test Accuracy: 0.832298994064331

# %%
create_model_summary(model_bigru)
# Out:
# 439/439 [==============================] - 6s 10ms/step
#               precision    recall  f1-score   support
#
#        angry       0.90      0.87      0.89      2232
#      disgust       0.80      0.77      0.78      2162
#         fear       0.80      0.81      0.80      2256
#        happy       0.82      0.83      0.83      2223
#      neutral       0.87      0.79      0.83      2173
#          sad       0.78      0.88      0.83      2279
#     surprise       0.97      0.96      0.96       694
#
#     accuracy                           0.83     14019
#    macro avg       0.85      0.84      0.85     14019
# weighted avg       0.83      0.83      0.83     14019
#
# Accuracy: 83.23%

# %%
evaluate_model(model_cnn)
plot_history(history_cnn)
# Out:
# 439/439 [==============================] - 2s 4ms/step - loss: 0.7627 - accuracy: 0.8297
# Test Loss: 0.7626575827598572
# Test Accuracy: 0.8296597599983215

# %%
create_model_summary(model_cnn)
# Out:
# 439/439 [==============================] - 2s 3ms/step
#               precision    recall  f1-score   support
#
#        angry       0.90      0.88      0.89      2232
#      disgust       0.78      0.81      0.80      2162
#         fear       0.77      0.83      0.80      2256
#        happy       0.81      0.83      0.82      2223
#      neutral       0.90      0.75      0.82      2173
#          sad       0.81      0.85      0.83      2279
#     surprise       0.96      0.94      0.95       694
#
#     accuracy                           0.83     14019
#    macro avg       0.85      0.84      0.84     14019
# weighted avg       0.83      0.83      0.83     14019
#
# Accuracy: 82.97%
