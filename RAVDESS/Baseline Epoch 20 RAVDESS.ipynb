# %%
import pandas as pd
import numpy as np
import os
from IPython.display import Audio
import librosa
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, GRU, Bidirectional, Conv1D, MaxPooling1D, Flatten, BatchNormalization, Activation, Masking
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping

# %%
file_name_dataset = "RAVDESS"
dataset_ravdess_dir = "../Dataset/RAVDESS/"
ravdess_dir_list = os.listdir(dataset_ravdess_dir)

# %%
emotion_dict = {
    "01": "neutral",
    "02": "calm",
    "03": "happy",
    "04": "sad",
    "05": "angry",
    "06": "fearful",
    "07": "disgust",
    "08": "surprised"
}

# %%
emotion_list = []
path_list = []

for dir in ravdess_dir_list:
    for audio_file in os.listdir(dataset_ravdess_dir + dir):
        emotion_segment = audio_file.split("-")[2]

        if emotion_segment in emotion_dict:
            emotion_list.append(emotion_dict[emotion_segment])
        else:
            emotion_list.append("unknown")

        audio_file_path = os.path.join(dataset_ravdess_dir, dir, audio_file)
        path_list.append(audio_file_path)

ravdess_df = pd.DataFrame({'Emotion': emotion_list, 'Path': path_list})
ravdess_df.to_csv("tess_df.csv", index = False)
ravdess_df.head()
# Out:
#    Emotion                                               Path
# 0  neutral  ../Dataset/RAVDESS/Actor_01\03-01-01-01-01-01-...
# 1  neutral  ../Dataset/RAVDESS/Actor_01\03-01-01-01-01-02-...
# 2  neutral  ../Dataset/RAVDESS/Actor_01\03-01-01-01-02-01-...
# 3  neutral  ../Dataset/RAVDESS/Actor_01\03-01-01-01-02-02-...
# 4     calm  ../Dataset/RAVDESS/Actor_01\03-01-02-01-01-01-...

# %%
plt.figure(figsize=(12, 8))
plt.title('Count of Emotions')
sns.countplot(x = ravdess_df.Emotion, hue = ravdess_df.Emotion)
plt.ylabel('Count')
plt.xlabel('Emotions')
sns.despine(top = True, right = True, left = False, bottom = False)
plt.show()

# %%
def waveplot(data, sr, emo):
  plt.figure(figsize = (6, 1))
  plt.title(f"{emo} audio waveplot")
  librosa.display.waveshow(data, sr = sr)

def spectrogram(data, sr, emo):
  X = librosa.stft(data)
  Xdb = librosa.amplitude_to_db(abs(X))
  plt.figure(figsize = (6, 1))
  plt.title(f"{emo} audio spectrogram")
  librosa.display.specshow(Xdb, sr = sr, x_axis = 'time', y_axis = 'hz')

# %%
emotion = 'happy'

audio_file_path = np.array(ravdess_df.Path[ravdess_df.Emotion.str.contains(emotion)])[1]
data, sampling_rate = librosa.load(audio_file_path)

waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(audio_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def noise(data):
  noise_amp = 0.04 * np.random.uniform() * np.amax(data)
  data = data + noise_amp * np.random.normal(size = data.shape[0])
  return data

def time_stretch(data, rate = 0.8):
  return librosa.effects.time_stretch(data, rate = rate)

def shift(data, steps_range = (-5, 5)):
  shift_range = int(np.random.uniform(steps_range[0], steps_range[1]) * 1000)
  return np.roll(data, shift_range)

def pitch_shift(data, sampling_rate, n_steps = 0.7):
  return librosa.effects.pitch_shift(data, sr = sampling_rate, n_steps = n_steps)

def random_time_stretch(data, stretch_factor_range = (0.8, 1.25)):
  random_stretch_factor = np.random.uniform(stretch_factor_range[0], stretch_factor_range[1])

  augmented_data = time_stretch(data, random_stretch_factor)

  if len(augmented_data) > len(data):
    augmented_data = augmented_data[:len(data)]
  else:
    padded_augmented_data = np.zeros_like(data)
    padded_augmented_data[:len(augmented_data)] = augmented_data
    augmented_data = padded_augmented_data

  return augmented_data

def random_pitch_shift(data, sampling_rate, steps_range=(-4, 4)):
  n_steps = np.random.randint(steps_range[0], steps_range[1] + 1)  
  return pitch_shift(data, sampling_rate, n_steps)

# %%
def extract_mel(data, sr, n_mels=128, fmax=8000):
    mel_spec = librosa.feature.melspectrogram(y=data, sr=sr, n_mels=n_mels, fmax=fmax)
    return mel_spec;

def extract_log_mel_spec(data, sr, n_mels=128, fmax=8000):
    log_mel_spec = librosa.power_to_db(extract_mel(data, sr, n_mels, fmax))
    return log_mel_spec;

def extract_mfcc(data, sr, n_mfcc=13):
    mfcc = librosa.feature.mfcc(y = data, sr = sr, n_mfcc=n_mfcc)
    return mfcc;

def extract_delta_mfcc(data, sr, n_mfcc=13):
    mfcc = extract_mfcc(data, sr, n_mfcc)
    delta_mfcc = librosa.feature.delta(mfcc)
    return delta_mfcc;

def extract_delta_delta_mfcc(data, sr, n_mfcc=13):
    mfcc = extract_mfcc(data, sr, n_mfcc)
    delta2_mfcc = librosa.feature.delta(mfcc, order=2)
    return delta2_mfcc;

def extract_zcr(data):
    zcr = librosa.feature.zero_crossing_rate(y=data)
    return zcr

def extract_rms(data):
    rms = librosa.feature.rms(y=data)
    return rms

# %%
mel = extract_mel(data, sampling_rate, 128, 8000)
plt.figure(figsize=(10, 2))
librosa.display.specshow(mel, x_axis='time', sr = sampling_rate)
plt.ylabel('Mel')
plt.colorbar()

log_mel_spec = extract_log_mel_spec(data, sampling_rate, 128, 8000)
plt.figure(figsize=(10, 2))
librosa.display.specshow(log_mel_spec, x_axis='time', sr = sampling_rate)
plt.ylabel('Log Mel Spectogram')
plt.colorbar()

# MFCC
mfcc = extract_mfcc(data, sampling_rate, 13)
plt.figure(figsize=(10, 2))
librosa.display.specshow(mfcc, x_axis='time', sr = sampling_rate)
plt.ylabel('MFCC')
plt.colorbar()

# ΔMFCC
delta_mfcc = extract_delta_mfcc(data, sampling_rate, 13)
plt.figure(figsize=(10, 2))
librosa.display.specshow(delta_mfcc, x_axis='time', sr = sampling_rate)
plt.ylabel('Delta MFCC')
plt.colorbar()

# ΔΔMFCC
delta_delta_mfcc = extract_delta_delta_mfcc(data, sampling_rate, 13)
plt.figure(figsize=(10, 2))
librosa.display.specshow(delta_delta_mfcc, x_axis='time', sr = sampling_rate)
plt.ylabel('Delta Delta MFCC')
plt.colorbar()
plt.show()

# MFCC-based approximate entropy
# MFCC-based spectral entropy
# Three-dimensional Mel-scale frequency cepstral coefficients

# %%
# feature_extraction_techniques = ["MFCC", "Delta MFCC", "Delta Delta MFCC"]
# feature_extraction_techniques = ["MFCC Mean 40", "Delta MFCC Mean 40", "Delta Delta MFCC Mean 40"]
feature_extraction_techniques = ["MFCC Mean 40"]

file_name_feat_extract = " & ".join(feature_extraction_techniques)

def extract_features(data, sr, n_mfcc=40):
    # MEAN
    features = np.array([])
    mfcc = extract_mfcc(data, sr, n_mfcc).T
    delta_mfcc = extract_delta_mfcc(data, sr, n_mfcc).T
    delta_delta_mfcc = extract_delta_delta_mfcc(data, sr, n_mfcc).T
    mfcc_mean = np.mean(mfcc, axis=0)
    delta_mfcc_mean = np.mean(delta_mfcc, axis=0)
    delta_delta_mfcc_mean = np.mean(delta_delta_mfcc, axis=0)
    # mfcc_min = np.min(mfcc, axis=0)
    # mfcc_max = np.max(mfcc, axis=0)
    # mfcc_std = np.std(mfcc, axis=0)
    # zcr = np.mean(extract_zcr(data))
    # rms = np.mean(extract_rms(data))
    features = np.hstack((features, mfcc_mean))

    # ENTIRE FEATURE
    # mfcc = extract_mfcc(data, sr).T
    # delta_mfcc = extract_delta_mfcc(data, sr).T
    # delta_delta_mfcc = extract_delta_delta_mfcc(data, sr).T
    # features = np.concatenate((mfcc, delta_mfcc, delta_delta_mfcc), axis=1)
    
    return features

# %%
# data_augmentation_techniques = ["Noise", "Random Time Stretch", "Random Pitch Shift"]
# data_augmentation_techniques = ["Noise 0.04", "Low Speed 0.75", "Stretched 0.7", "High Speed 1.25", "Pitch Shift 0.7", "Shift (-5, 5)"]
data_augmentation_techniques = ["Noise 0.04", "Low Speed 0.75", "High Speed 1.25", "Pitch Shift 0.7", "Shift (-5, 5)"]

file_name_data_aug = " & ".join(data_augmentation_techniques)

def get_features(path):
    data, sampling_rate = librosa.load(path, duration=3, offset=0.5)

    noisy_data = noise(data)

    lowspeed_data = time_stretch(data, rate=0.75) #Ignore this
    stretched_data = time_stretch(data, rate=0.7) #Ignore this
    highspeed_data = time_stretch(data, rate=1.25) #Ignore this
    pitch_shift_data = pitch_shift(data, sampling_rate, n_steps=0.7) #Ignore this
    shift_data = shift(data, (-5, 5)) #Ignore this

    random_time_stretch_data = random_time_stretch(data, (0.8, 1.25))
    random_pitch_shift_data = random_pitch_shift(data, sampling_rate, (-4, 4))

    features = extract_features(data, sampling_rate)
    noisy_features = extract_features(noisy_data, sampling_rate)
    
    lowspeed_features = extract_features(lowspeed_data, sampling_rate) #Ignore this
    stretched_features = extract_features(stretched_data, sampling_rate) #Ignore this
    highspeed_features = extract_features(highspeed_data, sampling_rate) #Ignore this
    pitch_shift_features = extract_features(pitch_shift_data, sampling_rate) #Ignore this
    shift_features = extract_features(shift_data, sampling_rate) #Ignore this

    random_time_stretch_features = extract_features(random_time_stretch_data, sampling_rate)
    random_pitch_shift_features = extract_features(random_pitch_shift_data, sampling_rate)

    # result = np.vstack((features, noisy_features, random_time_stretch_features, random_pitch_shift_features))
    result = np.vstack((features, noisy_features, lowspeed_features, highspeed_features, pitch_shift_features, shift_features))

    return result

# %%
filename = file_name_dataset + " # " + file_name_feat_extract + " # " + file_name_data_aug

def create_feature_dataframe(dataframe):
    feature_list = []
    emotion_list = []

    for path, emotion in tqdm(zip(dataframe.Path, dataframe.Emotion), total=len(dataframe)):
        features = get_features(path)
        for elements in features:
            feature_list.append(elements)
            emotion_list.append(emotion)

    df = pd.DataFrame({'Emotion': emotion_list})
    df = pd.concat([df, pd.DataFrame(feature_list)], axis=1)
    df.to_csv(filename + '.csv', index=False)

    return df

# %%
file_exists = os.path.exists(filename + '.csv')

if file_exists:
    df = pd.read_csv(filename + '.csv')
else:
    df = create_feature_dataframe(ravdess_df)

df.head()
# Out:
#    Emotion           0          1         2          3         4         5
# 0  neutral -670.195435  65.063850  0.888954  14.715979  9.182164  0.660575  \
# 1  neutral -437.411376  24.860678  7.356011   8.004017  5.143942  0.050777
# 2  neutral -691.445679  62.221443 -0.300504  14.352509  8.497726  0.746647
# 3  neutral -712.516907  66.194984  1.424330  16.236750  9.380598  1.506902
# 4  neutral -697.627258  62.472347 -1.029173  15.987646  7.447986 -0.467146
#
#           6         7          8  ...        30        31        32        33
# 0 -3.846836 -3.583946 -12.959006  ... -2.351098 -2.504727 -3.151507 -2.190899  \
# 1 -3.462119 -6.175004  -7.927267  ... -0.913083 -1.325904 -1.392386 -1.818780
# 2 -4.348557 -4.798969 -14.069670  ... -2.381158 -2.261819 -2.873888 -1.883212
# 3 -4.124938 -3.517112 -13.283334  ... -1.922169 -2.280859 -3.436191 -1.829611
# 4 -5.220094 -5.383532 -13.847498  ... -4.750515 -3.052244 -4.137149 -2.542254
#
#          34        35        36        37        38        39
# 0 -3.801760 -1.813088 -1.261222 -2.144954 -4.152173 -1.779615
# 1 -1.903436 -0.807370 -0.963922 -1.762706 -2.651064 -2.611878
# 2 -4.045451 -1.785669 -1.113154 -2.164787 -4.364875 -1.768830
# 3 -4.056078 -1.664588 -0.654646 -1.566690 -4.341530 -1.645019
# 4 -3.379075 -0.843549 -2.677613 -4.869622 -3.312335 -3.609416
#
# [5 rows x 41 columns]

# %%
X = df.iloc[:, 1:].values
Y = df['Emotion'].values

# %%
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
x_train, x_val_test, y_train, y_val_test = train_test_split(X, Y, test_size=0.2, random_state=42, shuffle=True)
x_validation, x_test, y_validation, y_test = train_test_split(x_val_test, y_val_test, test_size=0.5, random_state=42, shuffle=True)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_validation = scaler.transform(x_validation)
x_test = scaler.transform(x_test)

x_train.shape, y_train.shape, x_validation.shape, y_validation.shape, x_test.shape, y_test.shape
# Out:
# ((6912, 40), (6912, 8), (864, 40), (864, 8), (864, 40), (864, 8))

# %%
X_train = x_train.reshape(x_train.shape[0] , x_train.shape[1] , 1)
X_test = x_test.reshape(x_test.shape[0] , x_test.shape[1] , 1)
X_validation = x_validation.reshape(x_validation.shape[0] , x_validation.shape[1] , 1)
X_train.shape, y_train.shape, X_validation.shape, y_validation.shape, X_test.shape, y_test.shape
# Out:
# ((6912, 40, 1), (6912, 8), (864, 40, 1), (864, 8), (864, 40, 1), (864, 8))

# %%
def create_model(model_type, epochs, filename):
    model = Sequential()
    
    if model_type == 'GRU':
        model.add(GRU(128, input_shape=(X_train.shape[1],1), return_sequences=True))
        model.add(Dropout(0.3))
        model.add(GRU(128, return_sequences=True))
        model.add(GRU(128))
    elif model_type == 'LSTM':
        model.add(LSTM(128, input_shape=(X_train.shape[1],1), return_sequences=True))
        model.add(Dropout(0.3))
        model.add(LSTM(128, return_sequences=True))
        model.add(LSTM(128))
    elif model_type == 'BiGRU':
        model.add(Bidirectional(GRU(128, return_sequences=True), input_shape=(X_train.shape[1],1)))
        model.add(Dropout(0.3))
        model.add(Bidirectional(GRU(128, return_sequences=True)))
        model.add(Bidirectional(GRU(128)))
    elif model_type == 'BiLSTM':
        model.add(Bidirectional(LSTM(128, return_sequences=True), input_shape=(X_train.shape[1],1)))
        model.add(Dropout(0.3))
        model.add(Bidirectional(LSTM(128, return_sequences=True)))
        model.add(Bidirectional(LSTM(128)))
    elif model_type == 'CNN':
        model.add(Conv1D(64, 3, activation='relu', input_shape=(X_train.shape[1],1)))
        model.add(MaxPooling1D(2))
        model.add(Conv1D(128, 3, activation='relu'))
        model.add(MaxPooling1D(2))
        model.add(Conv1D(256, 3, activation='relu'))
        model.add(MaxPooling1D(2))
        model.add(Flatten())
        model.add(Dense(128, activation='relu'))
    else:
        raise ValueError("Invalid RNN model. Choose from 'GRU', 'LSTM', 'BiGRU', 'BiLSTM', or 'CNN'.")

    model.add(Dense(y_train.shape[1], activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, verbose=0, patience=3, min_lr=0.00001)
    checkpoint = ModelCheckpoint(filepath=filename + '_best.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    early_stop = EarlyStopping(monitor='val_accuracy', mode='auto', patience=10, restore_best_weights=True)

    history = model.fit(X_train, y_train, batch_size=64, epochs=epochs, validation_data=(X_validation, y_validation), callbacks=[reduce_lr, early_stop, checkpoint])

    #model.save(model_type + ' # Epoch 20.h5')    
    
    return model, history

# %%
def evaluate_model(model):
    loss, accuracy = model.evaluate(X_test, y_test, verbose=1)

    print(f'Test Loss: {loss}')
    print(f'Test Accuracy: {accuracy}')

# %%
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()

# %%
def simplify_label(label):
    if 'angry' in label:
        return 'angry'
    elif 'disgust' in label:
        return 'disgust'
    elif 'fear' in label:
        return 'fear'
    elif 'happy' in label:
        return 'happy'
    elif 'sad' in label:
        return 'sad'
    elif 'surprise' in label:
        return 'surprise'
    elif 'neutral' in label:
        return 'neutral'
    else:
        return label

# %%
def create_model_summary(model_type):
    test_prediction = model_type.predict(X_test)

    prediction_actual_df = pd.DataFrame({
    'Predicted': encoder.inverse_transform(test_prediction).flatten(),
    'Actual': encoder.inverse_transform(y_test).flatten()
    })

    prediction_actual_df.head()

    modified_df = prediction_actual_df.copy()
    modified_df['Actual'] = modified_df['Actual'].apply(simplify_label)
    modified_df['Predicted'] = modified_df['Predicted'].apply(simplify_label)

    res_mat = confusion_matrix(modified_df['Actual'], modified_df['Predicted'])
    plt.figure(figsize=(10, 7))
    sns.heatmap(res_mat, annot=True, fmt='d', cmap='Blues',
                xticklabels=modified_df['Predicted'].unique(), 
                yticklabels=modified_df['Actual'].unique())
    plt.xlabel('Predicted Labels')
    plt.ylabel('Actual Labels')
    plt.title('Confusion Matrix')
    plt.show()

    print(classification_report(modified_df['Actual'], modified_df['Predicted']))

    accuracy = accuracy_score(modified_df['Actual'], modified_df['Predicted'])
    print(f"Accuracy: {round(accuracy * 100, 2)}%")

# %%
model_lstm, history_lstm = create_model("LSTM", 20, 'RAVDESS LSTM')
model_gru, history_gru = create_model("GRU", 20, 'RAVDESS GRU')
model_bilstm, history_bilstm = create_model("BiLSTM", 20, 'RAVDESS BiLSTM')
model_bigru, history_bigru = create_model("BiGRU", 20, 'RAVDESS BiGRU')
model_cnn, history_cnn = create_model("CNN", 20, 'RAVDESS CNN')
# Out:
# Epoch 1/20
# 108/108 [==============================] - ETA: 0s - loss: 1.8987 - accuracy: 0.2652
# Epoch 1: val_accuracy improved from -inf to 0.28472, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 15s 91ms/step - loss: 1.8987 - accuracy: 0.2652 - val_loss: 1.8228 - val_accuracy: 0.2847 - lr: 0.0010
# Epoch 2/20
# 107/108 [============================>.] - ETA: 0s - loss: 1.7777 - accuracy: 0.3128
# Epoch 2: val_accuracy improved from 0.28472 to 0.30556, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 4s 39ms/step - loss: 1.7774 - accuracy: 0.3126 - val_loss: 1.7561 - val_accuracy: 0.3056 - lr: 0.0010
# Epoch 3/20
# 107/108 [============================>.] - ETA: 0s - loss: 1.7292 - accuracy: 0.3283
# Epoch 3: val_accuracy improved from 0.30556 to 0.32639, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 3s 32ms/step - loss: 1.7296 - accuracy: 0.3278 - val_loss: 1.7276 - val_accuracy: 0.3264 - lr: 0.0010
# Epoch 4/20
# 106/108 [============================>.] - ETA: 0s - loss: 1.6591 - accuracy: 0.3583
# Epoch 4: val_accuracy improved from 0.32639 to 0.34722, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 3s 31ms/step - loss: 1.6578 - accuracy: 0.3594 - val_loss: 1.6788 - val_accuracy: 0.3472 - lr: 0.0010
# Epoch 5/20
# 108/108 [==============================] - ETA: 0s - loss: 1.5922 - accuracy: 0.3832
# Epoch 5: val_accuracy improved from 0.34722 to 0.38657, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 4s 35ms/step - loss: 1.5922 - accuracy: 0.3832 - val_loss: 1.6304 - val_accuracy: 0.3866 - lr: 0.0010
# Epoch 6/20
# 108/108 [==============================] - ETA: 0s - loss: 1.5105 - accuracy: 0.4200
# Epoch 6: val_accuracy improved from 0.38657 to 0.38773, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 3s 31ms/step - loss: 1.5105 - accuracy: 0.4200 - val_loss: 1.5611 - val_accuracy: 0.3877 - lr: 0.0010
# Epoch 7/20
# 107/108 [============================>.] - ETA: 0s - loss: 1.3886 - accuracy: 0.4725
# Epoch 7: val_accuracy improved from 0.38773 to 0.43866, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 3s 32ms/step - loss: 1.3878 - accuracy: 0.4734 - val_loss: 1.4538 - val_accuracy: 0.4387 - lr: 0.0010
# Epoch 8/20
# 106/108 [============================>.] - ETA: 0s - loss: 1.2803 - accuracy: 0.5174
# Epoch 8: val_accuracy improved from 0.43866 to 0.49074, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 3s 31ms/step - loss: 1.2818 - accuracy: 0.5165 - val_loss: 1.3427 - val_accuracy: 0.4907 - lr: 0.0010
# Epoch 9/20
# 107/108 [============================>.] - ETA: 0s - loss: 1.1996 - accuracy: 0.5502
# Epoch 9: val_accuracy improved from 0.49074 to 0.53588, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 4s 41ms/step - loss: 1.2002 - accuracy: 0.5503 - val_loss: 1.2626 - val_accuracy: 0.5359 - lr: 0.0010
# Epoch 10/20
# 107/108 [============================>.] - ETA: 0s - loss: 1.1181 - accuracy: 0.5829
# Epoch 10: val_accuracy improved from 0.53588 to 0.54398, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 4s 40ms/step - loss: 1.1180 - accuracy: 0.5826 - val_loss: 1.1977 - val_accuracy: 0.5440 - lr: 0.0010
# Epoch 11/20
# 107/108 [============================>.] - ETA: 0s - loss: 1.0053 - accuracy: 0.6316
# Epoch 11: val_accuracy improved from 0.54398 to 0.61343, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 14s 128ms/step - loss: 1.0045 - accuracy: 0.6321 - val_loss: 1.0943 - val_accuracy: 0.6134 - lr: 0.0010
# Epoch 12/20
# 108/108 [==============================] - ETA: 0s - loss: 0.8960 - accuracy: 0.6787
# Epoch 12: val_accuracy improved from 0.61343 to 0.62500, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 4s 40ms/step - loss: 0.8960 - accuracy: 0.6787 - val_loss: 1.0487 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 13/20
# 108/108 [==============================] - ETA: 0s - loss: 0.8126 - accuracy: 0.7183
# Epoch 13: val_accuracy improved from 0.62500 to 0.65741, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 4s 39ms/step - loss: 0.8126 - accuracy: 0.7183 - val_loss: 1.0061 - val_accuracy: 0.6574 - lr: 0.0010
# Epoch 14/20
# 108/108 [==============================] - ETA: 0s - loss: 0.7518 - accuracy: 0.7325
# Epoch 14: val_accuracy did not improve from 0.65741
# 108/108 [==============================] - 4s 35ms/step - loss: 0.7518 - accuracy: 0.7325 - val_loss: 0.9586 - val_accuracy: 0.6574 - lr: 0.0010
# Epoch 15/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.6870 - accuracy: 0.7585
# Epoch 15: val_accuracy improved from 0.65741 to 0.68287, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 5s 44ms/step - loss: 0.6874 - accuracy: 0.7587 - val_loss: 0.8895 - val_accuracy: 0.6829 - lr: 0.0010
# Epoch 16/20
# 106/108 [============================>.] - ETA: 0s - loss: 0.6240 - accuracy: 0.7848
# Epoch 16: val_accuracy improved from 0.68287 to 0.71528, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 4s 36ms/step - loss: 0.6234 - accuracy: 0.7854 - val_loss: 0.8375 - val_accuracy: 0.7153 - lr: 0.0010
# Epoch 17/20
# 106/108 [============================>.] - ETA: 0s - loss: 0.5450 - accuracy: 0.8143
# Epoch 17: val_accuracy did not improve from 0.71528
# 108/108 [==============================] - 4s 34ms/step - loss: 0.5473 - accuracy: 0.8134 - val_loss: 0.8244 - val_accuracy: 0.7118 - lr: 0.0010
# Epoch 18/20
# 108/108 [==============================] - ETA: 0s - loss: 0.5040 - accuracy: 0.8307
# Epoch 18: val_accuracy improved from 0.71528 to 0.73727, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 4s 37ms/step - loss: 0.5040 - accuracy: 0.8307 - val_loss: 0.7833 - val_accuracy: 0.7373 - lr: 0.0010
# Epoch 19/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.4692 - accuracy: 0.8442
# Epoch 19: val_accuracy improved from 0.73727 to 0.73843, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 7s 61ms/step - loss: 0.4712 - accuracy: 0.8435 - val_loss: 0.7645 - val_accuracy: 0.7384 - lr: 0.0010
# Epoch 20/20
# 106/108 [============================>.] - ETA: 0s - loss: 0.4449 - accuracy: 0.8505
# Epoch 20: val_accuracy improved from 0.73843 to 0.74190, saving model to RAVDESS LSTM_best.h5
# 108/108 [==============================] - 5s 42ms/step - loss: 0.4450 - accuracy: 0.8501 - val_loss: 0.7584 - val_accuracy: 0.7419 - lr: 0.0010
# Epoch 1/20
# 108/108 [==============================] - ETA: 0s - loss: 1.9879 - accuracy: 0.2063
# Epoch 1: val_accuracy improved from -inf to 0.26620, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 8s 41ms/step - loss: 1.9879 - accuracy: 0.2063 - val_loss: 1.8797 - val_accuracy: 0.2662 - lr: 0.0010
# Epoch 2/20
# 108/108 [==============================] - ETA: 0s - loss: 1.8092 - accuracy: 0.3090
# Epoch 2: val_accuracy improved from 0.26620 to 0.28241, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 27ms/step - loss: 1.8092 - accuracy: 0.3090 - val_loss: 1.8424 - val_accuracy: 0.2824 - lr: 0.0010
# Epoch 3/20
# 106/108 [============================>.] - ETA: 0s - loss: 1.7458 - accuracy: 0.3342
# Epoch 3: val_accuracy improved from 0.28241 to 0.30556, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 31ms/step - loss: 1.7444 - accuracy: 0.3349 - val_loss: 1.7509 - val_accuracy: 0.3056 - lr: 0.0010
# Epoch 4/20
# 105/108 [============================>.] - ETA: 0s - loss: 1.6906 - accuracy: 0.3533
# Epoch 4: val_accuracy improved from 0.30556 to 0.35995, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 32ms/step - loss: 1.6897 - accuracy: 0.3540 - val_loss: 1.6850 - val_accuracy: 0.3600 - lr: 0.0010
# Epoch 5/20
# 106/108 [============================>.] - ETA: 0s - loss: 1.6178 - accuracy: 0.3871
# Epoch 5: val_accuracy improved from 0.35995 to 0.36343, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 29ms/step - loss: 1.6187 - accuracy: 0.3867 - val_loss: 1.6654 - val_accuracy: 0.3634 - lr: 0.0010
# Epoch 6/20
# 106/108 [============================>.] - ETA: 0s - loss: 1.5412 - accuracy: 0.4210
# Epoch 6: val_accuracy improved from 0.36343 to 0.40625, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 27ms/step - loss: 1.5385 - accuracy: 0.4222 - val_loss: 1.5604 - val_accuracy: 0.4062 - lr: 0.0010
# Epoch 7/20
# 106/108 [============================>.] - ETA: 0s - loss: 1.4340 - accuracy: 0.4661
# Epoch 7: val_accuracy improved from 0.40625 to 0.45139, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 4s 34ms/step - loss: 1.4329 - accuracy: 0.4669 - val_loss: 1.4379 - val_accuracy: 0.4514 - lr: 0.0010
# Epoch 8/20
# 105/108 [============================>.] - ETA: 0s - loss: 1.3422 - accuracy: 0.5049
# Epoch 8: val_accuracy improved from 0.45139 to 0.48727, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 27ms/step - loss: 1.3385 - accuracy: 0.5069 - val_loss: 1.3665 - val_accuracy: 0.4873 - lr: 0.0010
# Epoch 9/20
# 108/108 [==============================] - ETA: 0s - loss: 1.1981 - accuracy: 0.5618
# Epoch 9: val_accuracy improved from 0.48727 to 0.55556, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 2s 21ms/step - loss: 1.1981 - accuracy: 0.5618 - val_loss: 1.2395 - val_accuracy: 0.5556 - lr: 0.0010
# Epoch 10/20
# 106/108 [============================>.] - ETA: 0s - loss: 1.0910 - accuracy: 0.6095
# Epoch 10: val_accuracy improved from 0.55556 to 0.59606, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 24ms/step - loss: 1.0903 - accuracy: 0.6094 - val_loss: 1.1624 - val_accuracy: 0.5961 - lr: 0.0010
# Epoch 11/20
# 108/108 [==============================] - ETA: 0s - loss: 0.9829 - accuracy: 0.6460
# Epoch 11: val_accuracy improved from 0.59606 to 0.62269, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 24ms/step - loss: 0.9829 - accuracy: 0.6460 - val_loss: 1.0497 - val_accuracy: 0.6227 - lr: 0.0010
# Epoch 12/20
# 105/108 [============================>.] - ETA: 0s - loss: 0.8792 - accuracy: 0.6921
# Epoch 12: val_accuracy improved from 0.62269 to 0.66898, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 28ms/step - loss: 0.8777 - accuracy: 0.6936 - val_loss: 0.9727 - val_accuracy: 0.6690 - lr: 0.0010
# Epoch 13/20
# 106/108 [============================>.] - ETA: 0s - loss: 0.7697 - accuracy: 0.7329
# Epoch 13: val_accuracy improved from 0.66898 to 0.68519, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 30ms/step - loss: 0.7697 - accuracy: 0.7332 - val_loss: 0.9129 - val_accuracy: 0.6852 - lr: 0.0010
# Epoch 14/20
# 106/108 [============================>.] - ETA: 0s - loss: 0.6680 - accuracy: 0.7823
# Epoch 14: val_accuracy improved from 0.68519 to 0.69676, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 29ms/step - loss: 0.6662 - accuracy: 0.7824 - val_loss: 0.8444 - val_accuracy: 0.6968 - lr: 0.0010
# Epoch 15/20
# 108/108 [==============================] - ETA: 0s - loss: 0.5981 - accuracy: 0.8069
# Epoch 15: val_accuracy improved from 0.69676 to 0.73958, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 30ms/step - loss: 0.5981 - accuracy: 0.8069 - val_loss: 0.7876 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 16/20
# 108/108 [==============================] - ETA: 0s - loss: 0.5025 - accuracy: 0.8440
# Epoch 16: val_accuracy did not improve from 0.73958
# 108/108 [==============================] - 3s 29ms/step - loss: 0.5025 - accuracy: 0.8440 - val_loss: 0.7711 - val_accuracy: 0.7245 - lr: 0.0010
# Epoch 17/20
# 106/108 [============================>.] - ETA: 0s - loss: 0.4392 - accuracy: 0.8697
# Epoch 17: val_accuracy improved from 0.73958 to 0.76505, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 27ms/step - loss: 0.4391 - accuracy: 0.8695 - val_loss: 0.6909 - val_accuracy: 0.7650 - lr: 0.0010
# Epoch 18/20
# 105/108 [============================>.] - ETA: 0s - loss: 0.3718 - accuracy: 0.8927
# Epoch 18: val_accuracy improved from 0.76505 to 0.80324, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 25ms/step - loss: 0.3722 - accuracy: 0.8929 - val_loss: 0.6245 - val_accuracy: 0.8032 - lr: 0.0010
# Epoch 19/20
# 108/108 [==============================] - ETA: 0s - loss: 0.3203 - accuracy: 0.9089
# Epoch 19: val_accuracy improved from 0.80324 to 0.80440, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 31ms/step - loss: 0.3203 - accuracy: 0.9089 - val_loss: 0.5993 - val_accuracy: 0.8044 - lr: 0.0010
# Epoch 20/20
# 105/108 [============================>.] - ETA: 0s - loss: 0.2730 - accuracy: 0.9257
# Epoch 20: val_accuracy improved from 0.80440 to 0.82870, saving model to RAVDESS GRU_best.h5
# 108/108 [==============================] - 3s 29ms/step - loss: 0.2733 - accuracy: 0.9256 - val_loss: 0.5931 - val_accuracy: 0.8287 - lr: 0.0010
# Epoch 1/20
# 107/108 [============================>.] - ETA: 0s - loss: 1.8358 - accuracy: 0.2805
# Epoch 1: val_accuracy improved from -inf to 0.33681, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 15s 86ms/step - loss: 1.8343 - accuracy: 0.2808 - val_loss: 1.7516 - val_accuracy: 0.3368 - lr: 0.0010
# Epoch 2/20
# 108/108 [==============================] - ETA: 0s - loss: 1.6487 - accuracy: 0.3650
# Epoch 2: val_accuracy improved from 0.33681 to 0.35880, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 7s 68ms/step - loss: 1.6487 - accuracy: 0.3650 - val_loss: 1.6037 - val_accuracy: 0.3588 - lr: 0.0010
# Epoch 3/20
# 107/108 [============================>.] - ETA: 0s - loss: 1.4649 - accuracy: 0.4414
# Epoch 3: val_accuracy improved from 0.35880 to 0.47338, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 7s 63ms/step - loss: 1.4642 - accuracy: 0.4418 - val_loss: 1.4407 - val_accuracy: 0.4734 - lr: 0.0010
# Epoch 4/20
# 107/108 [============================>.] - ETA: 0s - loss: 1.3123 - accuracy: 0.5096
# Epoch 4: val_accuracy improved from 0.47338 to 0.49884, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 6s 58ms/step - loss: 1.3118 - accuracy: 0.5098 - val_loss: 1.3731 - val_accuracy: 0.4988 - lr: 0.0010
# Epoch 5/20
# 107/108 [============================>.] - ETA: 0s - loss: 1.1777 - accuracy: 0.5632
# Epoch 5: val_accuracy improved from 0.49884 to 0.54051, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 7s 65ms/step - loss: 1.1783 - accuracy: 0.5624 - val_loss: 1.2524 - val_accuracy: 0.5405 - lr: 0.0010
# Epoch 6/20
# 108/108 [==============================] - ETA: 0s - loss: 1.0299 - accuracy: 0.6249
# Epoch 6: val_accuracy improved from 0.54051 to 0.59838, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 8s 71ms/step - loss: 1.0299 - accuracy: 0.6249 - val_loss: 1.1108 - val_accuracy: 0.5984 - lr: 0.0010
# Epoch 7/20
# 108/108 [==============================] - ETA: 0s - loss: 0.9115 - accuracy: 0.6713
# Epoch 7: val_accuracy improved from 0.59838 to 0.64815, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 7s 66ms/step - loss: 0.9115 - accuracy: 0.6713 - val_loss: 0.9548 - val_accuracy: 0.6481 - lr: 0.0010
# Epoch 8/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.7916 - accuracy: 0.7188
# Epoch 8: val_accuracy improved from 0.64815 to 0.68403, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 8s 76ms/step - loss: 0.7912 - accuracy: 0.7186 - val_loss: 0.8768 - val_accuracy: 0.6840 - lr: 0.0010
# Epoch 9/20
# 108/108 [==============================] - ETA: 0s - loss: 0.6734 - accuracy: 0.7721
# Epoch 9: val_accuracy improved from 0.68403 to 0.70023, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 8s 74ms/step - loss: 0.6734 - accuracy: 0.7721 - val_loss: 0.8424 - val_accuracy: 0.7002 - lr: 0.0010
# Epoch 10/20
# 108/108 [==============================] - ETA: 0s - loss: 0.5723 - accuracy: 0.8041
# Epoch 10: val_accuracy improved from 0.70023 to 0.75231, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 8s 69ms/step - loss: 0.5723 - accuracy: 0.8041 - val_loss: 0.7275 - val_accuracy: 0.7523 - lr: 0.0010
# Epoch 11/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.4750 - accuracy: 0.8404
# Epoch 11: val_accuracy improved from 0.75231 to 0.77662, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 7s 68ms/step - loss: 0.4752 - accuracy: 0.8406 - val_loss: 0.6941 - val_accuracy: 0.7766 - lr: 0.0010
# Epoch 12/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.4157 - accuracy: 0.8667
# Epoch 12: val_accuracy did not improve from 0.77662
# 108/108 [==============================] - 7s 64ms/step - loss: 0.4157 - accuracy: 0.8665 - val_loss: 0.6864 - val_accuracy: 0.7639 - lr: 0.0010
# Epoch 13/20
# 108/108 [==============================] - ETA: 0s - loss: 0.3595 - accuracy: 0.8866
# Epoch 13: val_accuracy did not improve from 0.77662
# 108/108 [==============================] - 8s 73ms/step - loss: 0.3595 - accuracy: 0.8866 - val_loss: 0.7420 - val_accuracy: 0.7477 - lr: 0.0010
# Epoch 14/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.3323 - accuracy: 0.8941
# Epoch 14: val_accuracy improved from 0.77662 to 0.79398, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 8s 72ms/step - loss: 0.3318 - accuracy: 0.8940 - val_loss: 0.6077 - val_accuracy: 0.7940 - lr: 0.0010
# Epoch 15/20
# 108/108 [==============================] - ETA: 0s - loss: 0.2706 - accuracy: 0.9174
# Epoch 15: val_accuracy improved from 0.79398 to 0.81481, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 8s 69ms/step - loss: 0.2706 - accuracy: 0.9174 - val_loss: 0.5438 - val_accuracy: 0.8148 - lr: 0.0010
# Epoch 16/20
# 108/108 [==============================] - ETA: 0s - loss: 0.2240 - accuracy: 0.9327
# Epoch 16: val_accuracy improved from 0.81481 to 0.82060, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 7s 69ms/step - loss: 0.2240 - accuracy: 0.9327 - val_loss: 0.5327 - val_accuracy: 0.8206 - lr: 0.0010
# Epoch 17/20
# 108/108 [==============================] - ETA: 0s - loss: 0.1823 - accuracy: 0.9462
# Epoch 17: val_accuracy improved from 0.82060 to 0.83218, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 7s 68ms/step - loss: 0.1823 - accuracy: 0.9462 - val_loss: 0.5480 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 18/20
# 108/108 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9637
# Epoch 18: val_accuracy improved from 0.83218 to 0.84259, saving model to RAVDESS BiLSTM_best.h5
# 108/108 [==============================] - 8s 69ms/step - loss: 0.1425 - accuracy: 0.9637 - val_loss: 0.5023 - val_accuracy: 0.8426 - lr: 0.0010
# Epoch 19/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.1605 - accuracy: 0.9536
# Epoch 19: val_accuracy did not improve from 0.84259
# 108/108 [==============================] - 8s 71ms/step - loss: 0.1609 - accuracy: 0.9534 - val_loss: 0.5730 - val_accuracy: 0.8160 - lr: 0.0010
# Epoch 20/20
# 108/108 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9543
# Epoch 20: val_accuracy did not improve from 0.84259
# 108/108 [==============================] - 8s 69ms/step - loss: 0.1551 - accuracy: 0.9543 - val_loss: 0.5033 - val_accuracy: 0.8380 - lr: 0.0010
# Epoch 1/20
# 108/108 [==============================] - ETA: 0s - loss: 1.8399 - accuracy: 0.2694
# Epoch 1: val_accuracy improved from -inf to 0.35069, saving model to RAVDESS BiGRU_best.h5
# 108/108 [==============================] - 12s 59ms/step - loss: 1.8399 - accuracy: 0.2694 - val_loss: 1.7138 - val_accuracy: 0.3507 - lr: 0.0010
# Epoch 2/20
# 107/108 [============================>.] - ETA: 0s - loss: 1.5416 - accuracy: 0.4162
# Epoch 2: val_accuracy improved from 0.35069 to 0.42940, saving model to RAVDESS BiGRU_best.h5
# 108/108 [==============================] - 31s 287ms/step - loss: 1.5400 - accuracy: 0.4167 - val_loss: 1.4502 - val_accuracy: 0.4294 - lr: 0.0010
# Epoch 3/20
# 107/108 [============================>.] - ETA: 0s - loss: 1.3465 - accuracy: 0.4928
# Epoch 3: val_accuracy improved from 0.42940 to 0.51157, saving model to RAVDESS BiGRU_best.h5
# 108/108 [==============================] - 4s 38ms/step - loss: 1.3462 - accuracy: 0.4929 - val_loss: 1.2752 - val_accuracy: 0.5116 - lr: 0.0010
# Epoch 4/20
# 108/108 [==============================] - ETA: 0s - loss: 1.1647 - accuracy: 0.5674
# Epoch 4: val_accuracy improved from 0.51157 to 0.58796, saving model to RAVDESS BiGRU_best.h5
# 108/108 [==============================] - 4s 35ms/step - loss: 1.1647 - accuracy: 0.5674 - val_loss: 1.0919 - val_accuracy: 0.5880 - lr: 0.0010
# Epoch 5/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.9673 - accuracy: 0.6522
# Epoch 5: val_accuracy improved from 0.58796 to 0.68634, saving model to RAVDESS BiGRU_best.h5
# 108/108 [==============================] - 4s 34ms/step - loss: 0.9660 - accuracy: 0.6528 - val_loss: 0.9187 - val_accuracy: 0.6863 - lr: 0.0010
# Epoch 6/20
# 108/108 [==============================] - ETA: 0s - loss: 0.7609 - accuracy: 0.7344
# Epoch 6: val_accuracy improved from 0.68634 to 0.70949, saving model to RAVDESS BiGRU_best.h5
# 108/108 [==============================] - 4s 38ms/step - loss: 0.7609 - accuracy: 0.7344 - val_loss: 0.8071 - val_accuracy: 0.7095 - lr: 0.0010
# Epoch 7/20
# 108/108 [==============================] - ETA: 0s - loss: 0.5878 - accuracy: 0.8009
# Epoch 7: val_accuracy improved from 0.70949 to 0.77662, saving model to RAVDESS BiGRU_best.h5
# 108/108 [==============================] - 4s 34ms/step - loss: 0.5878 - accuracy: 0.8009 - val_loss: 0.6461 - val_accuracy: 0.7766 - lr: 0.0010
# Epoch 8/20
# 108/108 [==============================] - ETA: 0s - loss: 0.4552 - accuracy: 0.8533
# Epoch 8: val_accuracy improved from 0.77662 to 0.81944, saving model to RAVDESS BiGRU_best.h5
# 108/108 [==============================] - 4s 40ms/step - loss: 0.4552 - accuracy: 0.8533 - val_loss: 0.5423 - val_accuracy: 0.8194 - lr: 0.0010
# Epoch 9/20
# 108/108 [==============================] - ETA: 0s - loss: 0.3322 - accuracy: 0.9018
# Epoch 9: val_accuracy improved from 0.81944 to 0.84606, saving model to RAVDESS BiGRU_best.h5
# 108/108 [==============================] - 4s 39ms/step - loss: 0.3322 - accuracy: 0.9018 - val_loss: 0.4823 - val_accuracy: 0.8461 - lr: 0.0010
# Epoch 10/20
# 108/108 [==============================] - ETA: 0s - loss: 0.2513 - accuracy: 0.9278
# Epoch 10: val_accuracy improved from 0.84606 to 0.89120, saving model to RAVDESS BiGRU_best.h5
# 108/108 [==============================] - 4s 39ms/step - loss: 0.2513 - accuracy: 0.9278 - val_loss: 0.3900 - val_accuracy: 0.8912 - lr: 0.0010
# Epoch 11/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.1942 - accuracy: 0.9449
# Epoch 11: val_accuracy did not improve from 0.89120
# 108/108 [==============================] - 4s 40ms/step - loss: 0.1948 - accuracy: 0.9449 - val_loss: 0.3759 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 12/20
# 108/108 [==============================] - ETA: 0s - loss: 0.1457 - accuracy: 0.9614
# Epoch 12: val_accuracy did not improve from 0.89120
# 108/108 [==============================] - 4s 41ms/step - loss: 0.1457 - accuracy: 0.9614 - val_loss: 0.3767 - val_accuracy: 0.8808 - lr: 0.0010
# Epoch 13/20
# 108/108 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.9661
# Epoch 13: val_accuracy did not improve from 0.89120
# 108/108 [==============================] - 4s 39ms/step - loss: 0.1240 - accuracy: 0.9661 - val_loss: 0.3388 - val_accuracy: 0.8912 - lr: 0.0010
# Epoch 14/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.0817 - accuracy: 0.9815
# Epoch 14: val_accuracy did not improve from 0.89120
# 108/108 [==============================] - 5s 49ms/step - loss: 0.0813 - accuracy: 0.9816 - val_loss: 0.3480 - val_accuracy: 0.8900 - lr: 0.0010
# Epoch 15/20
# 108/108 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 0.9889
# Epoch 15: val_accuracy improved from 0.89120 to 0.89236, saving model to RAVDESS BiGRU_best.h5
# 108/108 [==============================] - 5s 43ms/step - loss: 0.0596 - accuracy: 0.9889 - val_loss: 0.3342 - val_accuracy: 0.8924 - lr: 0.0010
# Epoch 16/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.0544 - accuracy: 0.9888
# Epoch 16: val_accuracy did not improve from 0.89236
# 108/108 [==============================] - 4s 40ms/step - loss: 0.0544 - accuracy: 0.9889 - val_loss: 0.3657 - val_accuracy: 0.8900 - lr: 0.0010
# Epoch 17/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.0399 - accuracy: 0.9942
# Epoch 17: val_accuracy improved from 0.89236 to 0.89468, saving model to RAVDESS BiGRU_best.h5
# 108/108 [==============================] - 5s 43ms/step - loss: 0.0399 - accuracy: 0.9941 - val_loss: 0.3502 - val_accuracy: 0.8947 - lr: 0.0010
# Epoch 18/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 0.9985
# Epoch 18: val_accuracy improved from 0.89468 to 0.89815, saving model to RAVDESS BiGRU_best.h5
# 108/108 [==============================] - 5s 45ms/step - loss: 0.0226 - accuracy: 0.9986 - val_loss: 0.3621 - val_accuracy: 0.8981 - lr: 0.0010
# Epoch 19/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.0327 - accuracy: 0.9952
# Epoch 19: val_accuracy did not improve from 0.89815
# 108/108 [==============================] - 4s 39ms/step - loss: 0.0327 - accuracy: 0.9952 - val_loss: 0.4137 - val_accuracy: 0.8762 - lr: 0.0010
# Epoch 20/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.0353 - accuracy: 0.9940
# Epoch 20: val_accuracy did not improve from 0.89815
# 108/108 [==============================] - 4s 40ms/step - loss: 0.0353 - accuracy: 0.9941 - val_loss: 0.3753 - val_accuracy: 0.8924 - lr: 0.0010
# Epoch 1/20
# 107/108 [============================>.] - ETA: 0s - loss: 1.8321 - accuracy: 0.2972
# Epoch 1: val_accuracy improved from -inf to 0.34838, saving model to RAVDESS CNN_best.h5
# 108/108 [==============================] - 4s 12ms/step - loss: 1.8301 - accuracy: 0.2983 - val_loss: 1.6798 - val_accuracy: 0.3484 - lr: 0.0010
# Epoch 2/20
# 102/108 [===========================>..] - ETA: 0s - loss: 1.4120 - accuracy: 0.4753
# Epoch 2: val_accuracy improved from 0.34838 to 0.54282, saving model to RAVDESS CNN_best.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 1.4011 - accuracy: 0.4777 - val_loss: 1.2620 - val_accuracy: 0.5428 - lr: 0.0010
# Epoch 3/20
# 105/108 [============================>.] - ETA: 0s - loss: 1.0016 - accuracy: 0.6369
# Epoch 3: val_accuracy improved from 0.54282 to 0.67014, saving model to RAVDESS CNN_best.h5
# 108/108 [==============================] - 1s 10ms/step - loss: 0.9987 - accuracy: 0.6379 - val_loss: 0.9369 - val_accuracy: 0.6701 - lr: 0.0010
# Epoch 4/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.7083 - accuracy: 0.7503
# Epoch 4: val_accuracy improved from 0.67014 to 0.72685, saving model to RAVDESS CNN_best.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.7079 - accuracy: 0.7509 - val_loss: 0.7255 - val_accuracy: 0.7269 - lr: 0.0010
# Epoch 5/20
# 103/108 [===========================>..] - ETA: 0s - loss: 0.4699 - accuracy: 0.8444
# Epoch 5: val_accuracy improved from 0.72685 to 0.79282, saving model to RAVDESS CNN_best.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.4704 - accuracy: 0.8439 - val_loss: 0.5762 - val_accuracy: 0.7928 - lr: 0.0010
# Epoch 6/20
# 104/108 [===========================>..] - ETA: 0s - loss: 0.3364 - accuracy: 0.8917
# Epoch 6: val_accuracy improved from 0.79282 to 0.85301, saving model to RAVDESS CNN_best.h5
# 108/108 [==============================] - 1s 10ms/step - loss: 0.3341 - accuracy: 0.8919 - val_loss: 0.4247 - val_accuracy: 0.8530 - lr: 0.0010
# Epoch 7/20
# 103/108 [===========================>..] - ETA: 0s - loss: 0.2459 - accuracy: 0.9243
# Epoch 7: val_accuracy improved from 0.85301 to 0.86227, saving model to RAVDESS CNN_best.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.2488 - accuracy: 0.9225 - val_loss: 0.4218 - val_accuracy: 0.8623 - lr: 0.0010
# Epoch 8/20
# 103/108 [===========================>..] - ETA: 0s - loss: 0.1902 - accuracy: 0.9370
# Epoch 8: val_accuracy did not improve from 0.86227
# 108/108 [==============================] - 1s 10ms/step - loss: 0.1915 - accuracy: 0.9365 - val_loss: 0.4725 - val_accuracy: 0.8472 - lr: 0.0010
# Epoch 9/20
# 106/108 [============================>.] - ETA: 0s - loss: 0.1461 - accuracy: 0.9540
# Epoch 9: val_accuracy improved from 0.86227 to 0.89005, saving model to RAVDESS CNN_best.h5
# 108/108 [==============================] - 1s 10ms/step - loss: 0.1472 - accuracy: 0.9537 - val_loss: 0.3776 - val_accuracy: 0.8900 - lr: 0.0010
# Epoch 10/20
# 104/108 [===========================>..] - ETA: 0s - loss: 0.1263 - accuracy: 0.9608
# Epoch 10: val_accuracy did not improve from 0.89005
# 108/108 [==============================] - 1s 9ms/step - loss: 0.1263 - accuracy: 0.9611 - val_loss: 0.3893 - val_accuracy: 0.8843 - lr: 0.0010
# Epoch 11/20
# 108/108 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9708
# Epoch 11: val_accuracy did not improve from 0.89005
# 108/108 [==============================] - 1s 10ms/step - loss: 0.0962 - accuracy: 0.9708 - val_loss: 0.3726 - val_accuracy: 0.8819 - lr: 0.0010
# Epoch 12/20
# 105/108 [============================>.] - ETA: 0s - loss: 0.0912 - accuracy: 0.9714
# Epoch 12: val_accuracy did not improve from 0.89005
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0919 - accuracy: 0.9714 - val_loss: 0.4010 - val_accuracy: 0.8843 - lr: 0.0010
# Epoch 13/20
# 106/108 [============================>.] - ETA: 0s - loss: 0.0675 - accuracy: 0.9808
# Epoch 13: val_accuracy did not improve from 0.89005
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0670 - accuracy: 0.9812 - val_loss: 0.3662 - val_accuracy: 0.8877 - lr: 0.0010
# Epoch 14/20
# 107/108 [============================>.] - ETA: 0s - loss: 0.0550 - accuracy: 0.9845
# Epoch 14: val_accuracy improved from 0.89005 to 0.89468, saving model to RAVDESS CNN_best.h5
# 108/108 [==============================] - 1s 10ms/step - loss: 0.0549 - accuracy: 0.9845 - val_loss: 0.3650 - val_accuracy: 0.8947 - lr: 0.0010
# Epoch 15/20
# 103/108 [===========================>..] - ETA: 0s - loss: 0.0420 - accuracy: 0.9900
# Epoch 15: val_accuracy improved from 0.89468 to 0.90741, saving model to RAVDESS CNN_best.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0420 - accuracy: 0.9900 - val_loss: 0.3134 - val_accuracy: 0.9074 - lr: 0.0010
# Epoch 16/20
# 108/108 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9919
# Epoch 16: val_accuracy did not improve from 0.90741
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0325 - accuracy: 0.9919 - val_loss: 0.3470 - val_accuracy: 0.9016 - lr: 0.0010
# Epoch 17/20
# 108/108 [==============================] - ETA: 0s - loss: 0.0791 - accuracy: 0.9750
# Epoch 17: val_accuracy did not improve from 0.90741
# 108/108 [==============================] - 1s 10ms/step - loss: 0.0791 - accuracy: 0.9750 - val_loss: 0.3981 - val_accuracy: 0.8796 - lr: 0.0010
# Epoch 18/20
# 102/108 [===========================>..] - ETA: 0s - loss: 0.0795 - accuracy: 0.9767
# Epoch 18: val_accuracy improved from 0.90741 to 0.90856, saving model to RAVDESS CNN_best.h5
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0783 - accuracy: 0.9767 - val_loss: 0.3287 - val_accuracy: 0.9086 - lr: 0.0010
# Epoch 19/20
# 106/108 [============================>.] - ETA: 0s - loss: 0.0366 - accuracy: 0.9900
# Epoch 19: val_accuracy improved from 0.90856 to 0.91088, saving model to RAVDESS CNN_best.h5
# 108/108 [==============================] - 1s 10ms/step - loss: 0.0361 - accuracy: 0.9902 - val_loss: 0.3644 - val_accuracy: 0.9109 - lr: 0.0010
# Epoch 20/20
# 105/108 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 0.9987
# Epoch 20: val_accuracy improved from 0.91088 to 0.91782, saving model to RAVDESS CNN_best.h5
# 108/108 [==============================] - 1s 10ms/step - loss: 0.0112 - accuracy: 0.9987 - val_loss: 0.3042 - val_accuracy: 0.9178 - lr: 5.0000e-04

# %%
evaluate_model(model_gru)
plot_history(history_gru)
# Out:
# 27/27 [==============================] - 0s 16ms/step - loss: 0.5805 - accuracy: 0.8171
# Test Loss: 0.5805453658103943
# Test Accuracy: 0.8171296119689941

# %%
create_model_summary(model_gru)
# Out:
# 27/27 [==============================] - 11s 355ms/step
#               precision    recall  f1-score   support
#
#        angry       0.85      0.88      0.86       118
#         calm       0.83      0.88      0.86       109
#      disgust       0.85      0.83      0.84       116
#         fear       0.83      0.76      0.80       105
#        happy       0.77      0.68      0.72       115
#      neutral       0.73      0.76      0.74        46
#          sad       0.76      0.83      0.79       114
#     surprise       0.85      0.87      0.86       141
#
#     accuracy                           0.82       864
#    macro avg       0.81      0.81      0.81       864
# weighted avg       0.82      0.82      0.82       864
#
# Accuracy: 81.71%

# %%
evaluate_model(model_lstm)
plot_history(history_lstm)
# Out:
# 27/27 [==============================] - 1s 24ms/step - loss: 0.7392 - accuracy: 0.7581
# Test Loss: 0.7391597032546997
# Test Accuracy: 0.7581018805503845

# %%
create_model_summary(model_lstm)
# Out:
# 27/27 [==============================] - 11s 21ms/step
#               precision    recall  f1-score   support
#
#        angry       0.78      0.78      0.78       118
#         calm       0.74      0.90      0.81       109
#      disgust       0.73      0.79      0.76       116
#         fear       0.76      0.79      0.78       105
#        happy       0.76      0.70      0.73       115
#      neutral       0.56      0.41      0.47        46
#          sad       0.78      0.72      0.75       114
#     surprise       0.81      0.77      0.79       141
#
#     accuracy                           0.76       864
#    macro avg       0.74      0.73      0.73       864
# weighted avg       0.76      0.76      0.76       864
#
# Accuracy: 75.81%

# %%
evaluate_model(model_bilstm)
plot_history(history_bilstm)
# Out:
# 27/27 [==============================] - 11s 439ms/step - loss: 0.5009 - accuracy: 0.8542
# Test Loss: 0.5008893609046936
# Test Accuracy: 0.8541666865348816

# %%
create_model_summary(model_bilstm)
# Out:
# 27/27 [==============================] - 11s 301ms/step
#               precision    recall  f1-score   support
#
#        angry       0.83      0.91      0.87       118
#         calm       0.92      0.85      0.89       109
#      disgust       0.86      0.92      0.89       116
#         fear       0.82      0.91      0.86       105
#        happy       0.90      0.71      0.80       115
#      neutral       0.70      0.83      0.76        46
#          sad       0.82      0.87      0.85       114
#     surprise       0.91      0.82      0.87       141
#
#     accuracy                           0.85       864
#    macro avg       0.85      0.85      0.85       864
# weighted avg       0.86      0.85      0.85       864
#
# Accuracy: 85.42%

# %%
evaluate_model(model_bigru)
plot_history(history_bigru)
# Out:
# 27/27 [==============================] - 11s 419ms/step - loss: 0.4476 - accuracy: 0.8692
# Test Loss: 0.4476453363895416
# Test Accuracy: 0.8692129850387573

# %%
create_model_summary(model_bigru)
# Out:
# 27/27 [==============================] - 11s 301ms/step
#               precision    recall  f1-score   support
#
#        angry       0.81      0.96      0.88       118
#         calm       0.88      0.92      0.90       109
#      disgust       0.82      0.89      0.85       116
#         fear       0.92      0.87      0.89       105
#        happy       0.84      0.81      0.82       115
#      neutral       0.86      0.78      0.82        46
#          sad       0.92      0.86      0.89       114
#     surprise       0.93      0.83      0.88       141
#
#     accuracy                           0.87       864
#    macro avg       0.87      0.86      0.87       864
# weighted avg       0.87      0.87      0.87       864
#
# Accuracy: 86.92%

# %%
evaluate_model(model_cnn)
plot_history(history_cnn)
# Out:
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2760 - accuracy: 0.9155
# Test Loss: 0.276027113199234
# Test Accuracy: 0.9155092835426331

# %%
create_model_summary(model_cnn)
# Out:
# 27/27 [==============================] - 0s 4ms/step
#               precision    recall  f1-score   support
#
#        angry       0.94      0.97      0.96       118
#         calm       0.93      0.92      0.93       109
#      disgust       0.95      0.91      0.93       116
#         fear       0.89      0.90      0.90       105
#        happy       0.91      0.88      0.89       115
#      neutral       0.91      0.91      0.91        46
#          sad       0.90      0.94      0.92       114
#     surprise       0.89      0.89      0.89       141
#
#     accuracy                           0.92       864
#    macro avg       0.92      0.92      0.92       864
# weighted avg       0.92      0.92      0.92       864
#
# Accuracy: 91.55%
